# %%
import math
import time
import sys
import os
import random
import pickle

import numpy as np

import tensorflow.keras
import tensorflow.keras.layers
import tensorflow.keras.applications
import tensorflow.keras.backend
import tensorflow.keras.preprocessing.image
import tensorflow.keras.utils
import tensorflow as tf

import cv2
import PIL
import PIL.Image
import matplotlib.pyplot as plt

import shutil

from tensorflow.keras import backend as K


# configurations

## seeding
os.environ['PYTHONHASHSEED'] = '3'
np.random.seed(3)
random.seed(3)
tf.random.set_seed(3)

## which gpu to use
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

## memory allocation
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
# config.gpu_options.per_process_gpu_memory_fraction = 0.5
session = tf.compat.v1.Session(config=config)
#K.set_session(session)
tf.compat.v1.keras.backend.set_session(session)
## data directory for CUB200 root
PATH_DATA_ROOT_CUB200 = "/content/drive/My Drive/Colab Notebooks/Cub-200_BCNN/CUB_200_2011/CUB_200_2011"

## network configurations
### number of output classes, 200 for CUB200
NO_CLASS = 200

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/Cub-200_BCNN/CUB_200_2011/CUB_200_2011"
# Out:
# attributes	    image_class_labels.txt  parts     train_test_split.txt
# bounding_boxes.txt  images		    README
# classes.txt	    images.txt		    splitted

# %%
from tensorflow.keras.initializers import glorot_normal
from keras.layers import Lambda

def outer_product(x):
    """
    calculate outer-products of 2 tensors

        args 
            x
                list of 2 tensors
                , assuming each of which has shape = (size_minibatch, total_pixels, size_filter)
    """
    return tensorflow.keras.backend.batch_dot(
                x[0]
                , x[1]
                , axes=[1,1]
            ) / x[0].get_shape().as_list()[1] 

def signed_sqrt(x):
    """
    calculate element-wise signed square root

        args
            x
                a tensor
    """
    return tensorflow.keras.backend.sign(x) * tensorflow.keras.backend.sqrt(tensorflow.keras.backend.abs(x) + 1e-9)

def L2_norm(x, axis=-1):
    """
    calculate L2-norm

        args 
            x
                a tensor
    """
    return tensorflow.keras.backend.l2_normalize(x, axis=axis)


def build_model(arryWeights_last
    ,size_heigth=448
    ,size_width=448
    ,no_class=200
    ,no_last_layer_backbone=17
    
    ,name_optimizer="sgd"
    ,rate_learning=1.0
    ,rate_decay_learning=0.0
    ,rate_decay_weight=0.0
    
    ,name_initializer="glorot_normal"
    ,name_activation_logits="softmax"
    ,name_loss="categorical_crossentropy"
    ,flg_debug=False
    ,**kwargs
):
    
    tensorflow.keras.backend.clear_session()
    
    # print("-------------------------------")
    # print("parameters:")
    # for key, val in locals().items():
    #     if not val == None and not key == "kwargs":
    #         print("\t", key, "=",  val)
    # print("-------------------------------")
    
    ### 
    ### load pre-trained model
    ###
    tensor_input = tensorflow.keras.layers.Input(shape=[size_heigth,size_width,3])
    model_detector = tensorflow.keras.applications.vgg16.VGG16(
                            input_tensor=tensor_input
                            , include_top=False
                            , weights='imagenet'
                        )
    
    # arryWeights_last_After =[]
    # for i in range(512):
    #   arryWeights_last_After.append(i)
    # for i in range(512):
    #   arryWeights_last_After[i]=1
    
    # arryWeights_last_After[filter_zero]=value_filter
    # print('filter' , filter_zero, "=", arryWeights_last_After[filter_zero])
    def custom_layer_last(tensor):
        return tensor * arryWeights_last
    lambda_layer = Lambda (custom_layer_last, name="lambda_New")

    model_detector = insert_intermediate_layer_in_keras (model_detector, 18, lambda_layer)
    # print('model detector')
    # model_detector.summary()
    ### 
    ### bi-linear pooling
    ###

    # extract features from detector
    x_detector = model_detector.layers[no_last_layer_backbone].output
    shape_detector = model_detector.layers[no_last_layer_backbone].output_shape
    # if flg_debug:
    #     print("shape_detector : {}".format(shape_detector))

    # extract features from extractor , same with detector for symmetry DxD model
    shape_extractor = shape_detector
    x_extractor = x_detector
    # if flg_debug:
    #     print("shape_extractor : {}".format(shape_extractor))
        
    
    # rehape to (minibatch_size, total_pixels, filter_size)
    x_detector = tensorflow.keras.layers.Reshape(
            [
                shape_detector[1] * shape_detector[2] , shape_detector[-1]
            ]
        )(x_detector)
    # if flg_debug:
    #     print("x_detector shape after rehsape ops : {}".format(x_detector.shape))
        
    x_extractor = tensorflow.keras.layers.Reshape(
            [
                shape_extractor[1] * shape_extractor[2] , shape_extractor[-1]
            ]
        )(x_extractor)
    # if flg_debug:
    #     print("x_extractor shape after rehsape ops : {}".format(x_extractor.shape))
        
        
    # outer products of features, output shape=(minibatch_size, filter_size_detector*filter_size_extractor)
    x = tensorflow.keras.layers.Lambda(outer_product)(
        [x_detector, x_extractor]
    )
    # if flg_debug:
    #     print("x shape after outer products ops : {}".format(x.shape))
        
        
    # rehape to (minibatch_size, filter_size_detector*filter_size_extractor)
    x = tensorflow.keras.layers.Reshape([shape_detector[-1]*shape_extractor[-1]])(x)
    # if flg_debug:
    #     print("x shape after rehsape ops : {}".format(x.shape))
        
        
    # signed square-root 
    x = tensorflow.keras.layers.Lambda(signed_sqrt)(x)
    # if flg_debug:
    #     print("x shape after signed-square-root ops : {}".format(x.shape))
        
    # L2 normalization
    x = tensorflow.keras.layers.Lambda(L2_norm)(x)
    # if flg_debug:
    #     print("x shape after L2-Normalization ops : {}".format(x.shape))



    ### 
    ### attach FC-Layer
    ###

    if name_initializer != None:
            name_initializer = eval(name_initializer+"()")
            
    x = tensorflow.keras.layers.Dense(
            units=no_class
            ,kernel_regularizer=tensorflow.keras.regularizers.l2(rate_decay_weight)
            ,kernel_initializer=name_initializer
        )(x)
    # if flg_debug:
    #     print("x shape after Dense ops : {}".format(x.shape))
    tensor_prediction = tensorflow.keras.layers.Activation(name_activation_logits)(x)
    # if flg_debug:
    #     print("prediction shape : {}".format(tensor_prediction.shape))

        

    ### 
    ### compile model
    ###
    model_bilinear = tensorflow.keras.models.Model(
                        inputs=[tensor_input]
                        , outputs=[tensor_prediction]
                    )
    
    
    # fix pre-trained weights
    for layer in model_detector.layers:
        layer.trainable = False
        
        
    # define optimizers
    opt_adam = tensorflow.keras.optimizers.Adam(
                    lr=rate_learning
                    , decay=rate_decay_learning
                )
    opt_rms = tensorflow.keras.optimizers.RMSprop(
                    lr=rate_learning
                    , decay=rate_decay_learning
                )
    opt_sgd = tensorflow.keras.optimizers.SGD(
                    lr=rate_learning
                    , decay=rate_decay_learning
                    , momentum=0.9
                    , nesterov=False
                )
    optimizers ={
        "adam":opt_adam
        ,"rmsprop":opt_rms
        ,"sgd":opt_sgd
    }
    
    model_bilinear.compile(
        loss=name_loss
        , optimizer=optimizers[name_optimizer]
        , metrics=["categorical_accuracy"]
    )
    
    
    
    # if flg_debug:
    #     model_bilinear.summary()
    
    return model_bilinear

# %%
def insert_intermediate_layer_in_keras(model, layer_id, new_layer):
    from keras.models import Model

    layers = [l for l in model.layers]

    x = layers[0].output
    for i in range(1, len(layers)):
        if i == layer_id:
            x = new_layer(x)
        x = layers[i](x)

    model = Model(inputs=layers[0].input, outputs=x) ### inputs instead of input in this version
    return model

# %%
arryWeights_last_After =[]
for i in range(512):
  arryWeights_last_After.append(i)
for i in range(512):
  arryWeights_last_After[i]=1
model = build_model(arryWeights_last_After
            # number of output classes, 200 for CUB200
            ,no_class = NO_CLASS

            # pretrained model specification, using VGG16
            # "block5_conv3 "
            ,no_last_layer_backbone = 18

            # training parametes
            ,rate_learning=1.0
            ,rate_decay_weight=1e-8
            ,flg_debug=True
        )

# model = build_model(
#             # number of output classes, 200 for CUB200
#             no_class = NO_CLASS

#             # pretrained model specification, using VGG16
#             # "block5_conv3 "
#             ,no_last_layer_backbone = 17           
#             # training parametes
#             ,rate_learning=1.0
#             ,rate_decay_weight=1e-8
#             ,flg_debug=True
#         )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
# now all layers are trainable
for layer in model.layers:
    layer.trainable = True

# change LR
opt_sgd = tensorflow.keras.optimizers.SGD(
                lr=1e-3
                , decay=1e-9
                , momentum=0.9
                , nesterov=False
            )
model.compile(
    loss="categorical_crossentropy"
    , optimizer=opt_sgd
    , metrics=["categorical_accuracy"]
)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
model.load_weights("/content/drive/My Drive/Colab Notebooks/Cub-200_BCNN/birds_200_weights.h5")

# %%
import os

birds_labels = set()

path= "/content/drive/My Drive/Colab Notebooks/Cub-200_BCNN/CUB_200_2011/CUB_200_2011/images"
for d in os.listdir(path):
    birds_labels.add(d)

len(birds_labels)

# print(birds_labels)
# Out:
# 200

# %%
birds_labels = list(birds_labels)
birds_labels.sort()
# birds_labels

# %%
import cv2
def load_and_preprocess_image(path):
    image = cv2.imread(path)
    image = cv2.resize(image, (448,448))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import numpy as np

def output(location, new_model):
    img = load_and_preprocess_image(location)
#     img = load_img(location, target_size = (224, 224, 3))
#     img = img_to_array(img)
#     img = img / 255
    img = np.expand_dims(img, axis=0)
    answer = new_model.predict(img)
    y_class = answer.argmax(axis = -1)
    
    top_3 = np.argsort(answer[0])[:-4:-1]
    # for i in range(3):
    #     print(" ({:.3})".format(answer[0][top_3[i]]))
    
    y = " ".join(str(x) for x in y_class)
    y = int(y)
    res = birds_labels[y]
    # print(res)
#     print(" ({:.3})".format(answer[0][top_3[0]]))
    pred_prob = answer[0][top_3[0]]
    return float(pred_prob), res

# %%
location = "/content/drive/My Drive/Colab Notebooks/Cub-200_BCNN/CUB_200_2011/CUB_200_2011/images/004.Groove_billed_Ani/Groove_Billed_Ani_0087_1765.jpg"
output(location, model)
# Out:
# (0.03362368419766426, '027.Shiny_Cowbird')

# %%
import ast
a_file = open("/content/drive/My Drive/Colab Notebooks/Cub-200_BCNN/Filt_Resp_Birds_BCNN.txt", "r")
# a_file = open("Gibbon_panda.txt", "r")
# a_file = open("Gimagenet_Test_2.txt", "r")


string_without_line_breaks = ""
for line in a_file:
    stripped_line = line.rstrip()
    string_without_line_breaks += stripped_line

import re
dict_Classes = ast.literal_eval(re.search('({.+})', string_without_line_breaks).group(0))

# for key, value in dict_Classes.items():
#     print ('classId', key)
#     print ('value', value)
a_file.close()
#print(dict_Classes)

# %%
import collections
od = collections.OrderedDict(sorted(dict_Classes.items()))
list_b=[]
for item in od:
    # print(item)
    list_b.append(item)

# %% [markdown]
# # Original **BCNN model**

# %%
import cv2
import os
from shutil import copyfile
from pathlib import Path
final_acc = 0
folder = "/content/drive/My Drive/Colab Notebooks/Cub-200_BCNN/CUB_200_2011/CUB_200_2011/images/"
print(len(os.listdir(folder + "001.Black_footed_Albatross")))
imagesFileNames = []
for filename in os.listdir(folder):    
    correct_count_By_folder=0
    print( len(os.listdir(folder+str(filename)) ))
    for img in os.listdir(folder+filename):
        if output(folder+filename+"/"+img, model)[1] ==  filename:
            correct_count_By_folder+=1
    final_accu_by_class = correct_count_By_folder/len(os.listdir(folder+filename))
    print('correctly classified : ' ,filename, correct_count_By_folder)
    print('accuracy for ' , filename , 'is ' , final_accu_by_class)
    final_acc += final_accu_by_class
    print('final_acc : ', final_acc/200) 

#images = load_images_from_folder(folder)
# Out:
# 60
# 60
# correctly classified :  001.Black_footed_Albatross 46
# accuracy for  001.Black_footed_Albatross is  0.7666666666666667
# final_acc :  0.0038333333333333336
# 60
# correctly classified :  002.Laysan_Albatross 49
# accuracy for  002.Laysan_Albatross is  0.8166666666666667
# final_acc :  0.007916666666666667
# 58
# correctly classified :  003.Sooty_Albatross 53
# accuracy for  003.Sooty_Albatross is  0.9137931034482759
# final_acc :  0.012485632183908047
# 60
# correctly classified :  004.Groove_billed_Ani 55
# accuracy for  004.Groove_billed_Ani is  0.9166666666666666
# final_acc :  0.01706896551724138
# 41
# correctly classified :  006.Least_Auklet 40
# accuracy for  006.Least_Auklet is  0.975609756097561
# final_acc :  0.021947014297729182
# 53
# correctly classified :  007.Parakeet_Auklet 53
# accuracy for  007.Parakeet_Auklet is  1.0
# final_acc :  0.026947014297729183
# 48
# correctly classified :  008.Rhinoceros_Auklet 33
# accuracy for  008.Rhinoceros_Auklet is  0.6875
# final_acc :  0.030384514297729183
# 59
# correctly classified :  009.Brewer_Blackbird 41
# accuracy for  009.Brewer_Blackbird is  0.6949152542372882
# final_acc :  0.033859090568915624
# 60
# correctly classified :  010.Red_winged_Blackbird 50
# accuracy for  010.Red_winged_Blackbird is  0.8333333333333334
# final_acc :  0.03802575723558229
# 60
# correctly classified :  011.Rusty_Blackbird 38
# accuracy for  011.Rusty_Blackbird is  0.6333333333333333
# final_acc :  0.041192423902248955
# 56
# correctly classified :  012.Yellow_headed_Blackbird 51
# accuracy for  012.Yellow_headed_Blackbird is  0.9107142857142857
# final_acc :  0.04574599533082039
# 60
# correctly classified :  013.Bobolink 48
# accuracy for  013.Bobolink is  0.8
# final_acc :  0.04974599533082039
# 60
# correctly classified :  014.Indigo_Bunting 53
# accuracy for  014.Indigo_Bunting is  0.8833333333333333
# final_acc :  0.05416266199748706
# 58
# correctly classified :  015.Lazuli_Bunting 52
# accuracy for  015.Lazuli_Bunting is  0.896551724137931
# final_acc :  0.05864542061817671
# 58
# correctly classified :  016.Painted_Bunting 53
# accuracy for  016.Painted_Bunting is  0.9137931034482759
# final_acc :  0.06321438613541809
# 57
# correctly classified :  017.Cardinal 56
# accuracy for  017.Cardinal is  0.9824561403508771
# final_acc :  0.06812666683717247
# 45
# correctly classified :  018.Spotted_Catbird 42
# accuracy for  018.Spotted_Catbird is  0.9333333333333333
# final_acc :  0.07279333350383914
# 59
# correctly classified :  020.Yellow_breasted_Chat 56
# accuracy for  020.Yellow_breasted_Chat is  0.9491525423728814
# final_acc :  0.07753909621570354
# 60
# correctly classified :  021.Eastern_Towhee 42
# accuracy for  021.Eastern_Towhee is  0.7
# final_acc :  0.08103909621570354
# 56
# correctly classified :  022.Chuck_will_Widow 41
# accuracy for  022.Chuck_will_Widow is  0.7321428571428571
# final_acc :  0.08469981050141782
# 59
# correctly classified :  023.Brandt_Cormorant 32
# accuracy for  023.Brandt_Cormorant is  0.5423728813559322
# final_acc :  0.08741167490819748
# 52
# correctly classified :  024.Red_faced_Cormorant 47
# accuracy for  024.Red_faced_Cormorant is  0.9038461538461539
# final_acc :  0.09193090567742825
# 60
# correctly classified :  025.Pelagic_Cormorant 36
# accuracy for  025.Pelagic_Cormorant is  0.6
# final_acc :  0.09493090567742826
# 60
# correctly classified :  026.Bronzed_Cowbird 45
# accuracy for  026.Bronzed_Cowbird is  0.75
# final_acc :  0.09868090567742825
# 60
# correctly classified :  027.Shiny_Cowbird 21
# accuracy for  027.Shiny_Cowbird is  0.35
# final_acc :  0.10043090567742827
# 59
# correctly classified :  028.Brown_Creeper 49
# accuracy for  028.Brown_Creeper is  0.8305084745762712
# final_acc :  0.10458344805030961
# 60
# correctly classified :  029.American_Crow 28
# accuracy for  029.American_Crow is  0.4666666666666667
# final_acc :  0.10691678138364294
# 60
# correctly classified :  030.Fish_Crow 24
# accuracy for  030.Fish_Crow is  0.4
# final_acc :  0.10891678138364293
# 60
# correctly classified :  031.Black_billed_Cuckoo 49
# accuracy for  031.Black_billed_Cuckoo is  0.8166666666666667
# final_acc :  0.11300011471697627
# 53
# correctly classified :  032.Mangrove_Cuckoo 35
# accuracy for  032.Mangrove_Cuckoo is  0.660377358490566
# final_acc :  0.1163020015094291
# 59
# correctly classified :  033.Yellow_billed_Cuckoo 48
# accuracy for  033.Yellow_billed_Cuckoo is  0.8135593220338984
# final_acc :  0.1203697981195986
# 60
# correctly classified :  035.Purple_Finch 55
# accuracy for  035.Purple_Finch is  0.9166666666666666
# final_acc :  0.12495313145293194
# 60
# correctly classified :  036.Northern_Flicker 56
# accuracy for  036.Northern_Flicker is  0.9333333333333333
# final_acc :  0.12961979811959862
# 59
# correctly classified :  037.Acadian_Flycatcher 37
# accuracy for  037.Acadian_Flycatcher is  0.6271186440677966
# final_acc :  0.13275539133993758
# 60
# correctly classified :  038.Great_Crested_Flycatcher 52
# accuracy for  038.Great_Crested_Flycatcher is  0.8666666666666667
# final_acc :  0.13708872467327093
# 59
# correctly classified :  039.Least_Flycatcher 26
# accuracy for  039.Least_Flycatcher is  0.4406779661016949
# final_acc :  0.1392921145037794
# 60
# correctly classified :  040.Olive_sided_Flycatcher 44
# accuracy for  040.Olive_sided_Flycatcher is  0.7333333333333333
# final_acc :  0.14295878117044608
# 60
# correctly classified :  041.Scissor_tailed_Flycatcher 49
# accuracy for  041.Scissor_tailed_Flycatcher is  0.8166666666666667
# final_acc :  0.1470421145037794
# 60
# correctly classified :  042.Vermilion_Flycatcher 46
# accuracy for  042.Vermilion_Flycatcher is  0.7666666666666667
# final_acc :  0.15087544783711274
# 59
# correctly classified :  043.Yellow_bellied_Flycatcher 28
# accuracy for  043.Yellow_bellied_Flycatcher is  0.4745762711864407
# final_acc :  0.15324832919304493
# 60
# correctly classified :  044.Frigatebird 47
# accuracy for  044.Frigatebird is  0.7833333333333333
# final_acc :  0.1571649958597116
# 60
# correctly classified :  045.Northern_Fulmar 41
# accuracy for  045.Northern_Fulmar is  0.6833333333333333
# final_acc :  0.16058166252637826
# 60
# correctly classified :  046.Gadwall 50
# accuracy for  046.Gadwall is  0.8333333333333334
# final_acc :  0.16474832919304494
# 60
# correctly classified :  047.American_Goldfinch 54
# accuracy for  047.American_Goldfinch is  0.9
# final_acc :  0.16924832919304492
# 60
# correctly classified :  048.European_Goldfinch 54
# accuracy for  048.European_Goldfinch is  0.9
# final_acc :  0.17374832919304492
# 60
# correctly classified :  049.Boat_tailed_Grackle 25
# accuracy for  049.Boat_tailed_Grackle is  0.4166666666666667
# final_acc :  0.17583166252637825
# 60
# correctly classified :  050.Eared_Grebe 51
# accuracy for  050.Eared_Grebe is  0.85
# final_acc :  0.18008166252637825
# 60
# correctly classified :  051.Horned_Grebe 52
# accuracy for  051.Horned_Grebe is  0.8666666666666667
# final_acc :  0.18441499585971158
# 60
# correctly classified :  052.Pied_billed_Grebe 51
# accuracy for  052.Pied_billed_Grebe is  0.85
# final_acc :  0.18866499585971158
# 60
# correctly classified :  053.Western_Grebe 56
# accuracy for  053.Western_Grebe is  0.9333333333333333
# final_acc :  0.19333166252637823
# 60
# correctly classified :  054.Blue_Grosbeak 47
# accuracy for  054.Blue_Grosbeak is  0.7833333333333333
# final_acc :  0.19724832919304489
# 60
# correctly classified :  055.Evening_Grosbeak 54
# accuracy for  055.Evening_Grosbeak is  0.9
# final_acc :  0.2017483291930449
# 60
# correctly classified :  056.Pine_Grosbeak 46
# accuracy for  056.Pine_Grosbeak is  0.7666666666666667
# final_acc :  0.20558166252637822
# 60
# correctly classified :  057.Rose_breasted_Grosbeak 57
# accuracy for  057.Rose_breasted_Grosbeak is  0.95
# final_acc :  0.21033166252637822
# 58
# correctly classified :  058.Pigeon_Guillemot 33
# accuracy for  058.Pigeon_Guillemot is  0.5689655172413793
# final_acc :  0.21317649011258513
# 60
# correctly classified :  059.California_Gull 46
# accuracy for  059.California_Gull is  0.7666666666666667
# final_acc :  0.21700982344591846
# 59
# correctly classified :  060.Glaucous_winged_Gull 41
# accuracy for  060.Glaucous_winged_Gull is  0.6949152542372882
# final_acc :  0.2204843997171049
# 60
# correctly classified :  061.Heermann_Gull 48
# accuracy for  061.Heermann_Gull is  0.8
# final_acc :  0.22448439971710488
# 60
# correctly classified :  062.Herring_Gull 38
# accuracy for  062.Herring_Gull is  0.6333333333333333
# final_acc :  0.22765106638377156
# 60
# correctly classified :  063.Ivory_Gull 54
# accuracy for  063.Ivory_Gull is  0.9
# final_acc :  0.23215106638377153
# 60
# correctly classified :  064.Ring_billed_Gull 38
# accuracy for  064.Ring_billed_Gull is  0.6333333333333333
# final_acc :  0.2353177330504382
# 50
# correctly classified :  065.Slaty_backed_Gull 33
# accuracy for  065.Slaty_backed_Gull is  0.66
# final_acc :  0.23861773305043818
# 60
# correctly classified :  066.Western_Gull 23
# accuracy for  066.Western_Gull is  0.38333333333333336
# final_acc :  0.24053439971710486
# 60
# correctly classified :  067.Anna_Hummingbird 38
# accuracy for  067.Anna_Hummingbird is  0.6333333333333333
# final_acc :  0.2437010663837715
# 60
# correctly classified :  068.Ruby_throated_Hummingbird 50
# accuracy for  068.Ruby_throated_Hummingbird is  0.8333333333333334
# final_acc :  0.2478677330504382
# 60
# correctly classified :  069.Rufous_Hummingbird 47
# accuracy for  069.Rufous_Hummingbird is  0.7833333333333333
# final_acc :  0.25178439971710487
# 60
# correctly classified :  070.Green_Violetear 58
# accuracy for  070.Green_Violetear is  0.9666666666666667
# final_acc :  0.2566177330504382
# 60
# correctly classified :  071.Long_tailed_Jaeger 34
# accuracy for  071.Long_tailed_Jaeger is  0.5666666666666667
# final_acc :  0.2594510663837715
# 60
# correctly classified :  072.Pomarine_Jaeger 35
# accuracy for  072.Pomarine_Jaeger is  0.5833333333333334
# final_acc :  0.2623677330504382
# 60
# correctly classified :  073.Blue_Jay 54
# accuracy for  073.Blue_Jay is  0.9
# final_acc :  0.2668677330504382
# 60
# correctly classified :  074.Florida_Jay 57
# accuracy for  074.Florida_Jay is  0.95
# final_acc :  0.27161773305043824
# 57
# correctly classified :  075.Green_Jay 50
# accuracy for  075.Green_Jay is  0.8771929824561403
# final_acc :  0.2760036979627189
# 60
# correctly classified :  076.Dark_eyed_Junco 47
# accuracy for  076.Dark_eyed_Junco is  0.7833333333333333
# final_acc :  0.2799203646293856
# 60
# correctly classified :  077.Tropical_Kingbird 56
# accuracy for  077.Tropical_Kingbird is  0.9333333333333333
# final_acc :  0.28458703129605223
# 59
# correctly classified :  078.Gray_Kingbird 48
# accuracy for  078.Gray_Kingbird is  0.8135593220338984
# final_acc :  0.2886548279062217
# 60
# correctly classified :  079.Belted_Kingfisher 50
# accuracy for  079.Belted_Kingfisher is  0.8333333333333334
# final_acc :  0.29282149457288836
# 60
# correctly classified :  080.Green_Kingfisher 50
# accuracy for  080.Green_Kingfisher is  0.8333333333333334
# final_acc :  0.29698816123955507
# 60
# correctly classified :  081.Pied_Kingfisher 54
# accuracy for  081.Pied_Kingfisher is  0.9
# final_acc :  0.3014881612395551
# 60
# correctly classified :  082.Ringed_Kingfisher 44
# accuracy for  082.Ringed_Kingfisher is  0.7333333333333333
# final_acc :  0.3051548279062217
# 60
# correctly classified :  083.White_breasted_Kingfisher 57
# accuracy for  083.White_breasted_Kingfisher is  0.95
# final_acc :  0.30990482790622176
# 53
# correctly classified :  084.Red_legged_Kittiwake 45
# accuracy for  084.Red_legged_Kittiwake is  0.8490566037735849
# final_acc :  0.31415011092508965
# 60
# correctly classified :  085.Horned_Lark 55
# accuracy for  085.Horned_Lark is  0.9166666666666666
# final_acc :  0.318733444258423
# 60
# correctly classified :  086.Pacific_Loon 54
# accuracy for  086.Pacific_Loon is  0.9
# final_acc :  0.323233444258423
# 60
# correctly classified :  087.Mallard 44
# accuracy for  087.Mallard is  0.7333333333333333
# final_acc :  0.3269001109250897
# 60
# correctly classified :  088.Western_Meadowlark 57
# accuracy for  088.Western_Meadowlark is  0.95
# final_acc :  0.33165011092508967
# 60
# correctly classified :  089.Hooded_Merganser 52
# accuracy for  089.Hooded_Merganser is  0.8666666666666667
# final_acc :  0.33598344425842297
# 60
# correctly classified :  090.Red_breasted_Merganser 50
# accuracy for  090.Red_breasted_Merganser is  0.8333333333333334
# final_acc :  0.3401501109250896
# 60
# correctly classified :  091.Mockingbird 39
# accuracy for  091.Mockingbird is  0.65
# final_acc :  0.34340011092508965
# 60
# correctly classified :  092.Nighthawk 50
# accuracy for  092.Nighthawk is  0.8333333333333334
# final_acc :  0.3475667775917563
# 60
# correctly classified :  093.Clark_Nutcracker 47
# accuracy for  093.Clark_Nutcracker is  0.7833333333333333
# final_acc :  0.351483444258423
# 60
# correctly classified :  094.White_breasted_Nuthatch 54
# accuracy for  094.White_breasted_Nuthatch is  0.9
# final_acc :  0.355983444258423
# 60
# correctly classified :  095.Baltimore_Oriole 55
# accuracy for  095.Baltimore_Oriole is  0.9166666666666666
# final_acc :  0.36056677759175637
# 60
# correctly classified :  096.Hooded_Oriole 43
# accuracy for  096.Hooded_Oriole is  0.7166666666666667
# final_acc :  0.3641501109250897
# 59
# correctly classified :  097.Orchard_Oriole 41
# accuracy for  097.Orchard_Oriole is  0.6949152542372882
# final_acc :  0.3676246871962761
# 60
# correctly classified :  098.Scott_Oriole 50
# accuracy for  098.Scott_Oriole is  0.8333333333333334
# final_acc :  0.37179135386294276
# 60
# correctly classified :  099.Ovenbird 54
# accuracy for  099.Ovenbird is  0.9
# final_acc :  0.3762913538629428
# 60
# correctly classified :  100.Brown_Pelican 47
# accuracy for  100.Brown_Pelican is  0.7833333333333333
# final_acc :  0.38020802052960945
# 50
# correctly classified :  101.White_Pelican 49
# accuracy for  101.White_Pelican is  0.98
# final_acc :  0.38510802052960946
# 60
# correctly classified :  102.Western_Wood_Pewee 45
# accuracy for  102.Western_Wood_Pewee is  0.75
# final_acc :  0.3888580205296095
# 60
# correctly classified :  103.Sayornis 44
# accuracy for  103.Sayornis is  0.7333333333333333
# final_acc :  0.39252468719627615
# 60
# correctly classified :  104.American_Pipit 50
# accuracy for  104.American_Pipit is  0.8333333333333334
# final_acc :  0.3966913538629428
# 49
# correctly classified :  105.Whip_poor_Will 29
# accuracy for  105.Whip_poor_Will is  0.5918367346938775
# final_acc :  0.39965053753641216
# 60
# correctly classified :  106.Horned_Puffin 54
# accuracy for  106.Horned_Puffin is  0.9
# final_acc :  0.40415053753641217
# 59
# correctly classified :  107.Common_Raven 5
# accuracy for  107.Common_Raven is  0.0847457627118644
# final_acc :  0.40457426634997146
# 60
# correctly classified :  108.White_necked_Raven 41
# accuracy for  108.White_necked_Raven is  0.6833333333333333
# final_acc :  0.4079909330166382
# 60
# correctly classified :  109.American_Redstart 50
# accuracy for  109.American_Redstart is  0.8333333333333334
# final_acc :  0.4121575996833048
# 60
# correctly classified :  110.Geococcyx 59
# accuracy for  110.Geococcyx is  0.9833333333333333
# final_acc :  0.41707426634997147
# 60
# correctly classified :  111.Loggerhead_Shrike 49
# accuracy for  111.Loggerhead_Shrike is  0.8166666666666667
# final_acc :  0.4211575996833048
# 60
# correctly classified :  112.Great_Grey_Shrike 42
# accuracy for  112.Great_Grey_Shrike is  0.7
# final_acc :  0.4246575996833048
# 50
# correctly classified :  113.Baird_Sparrow 45
# accuracy for  113.Baird_Sparrow is  0.9
# final_acc :  0.42915759968330486
# 60
# correctly classified :  114.Black_throated_Sparrow 48
# accuracy for  114.Black_throated_Sparrow is  0.8
# final_acc :  0.4331575996833048
# 59
# correctly classified :  115.Brewer_Sparrow 47
# accuracy for  115.Brewer_Sparrow is  0.7966101694915254
# final_acc :  0.43714065053076245
# 60
# correctly classified :  116.Chipping_Sparrow 33
# accuracy for  116.Chipping_Sparrow is  0.55
# final_acc :  0.4398906505307625
# 59
# correctly classified :  117.Clay_colored_Sparrow 39
# accuracy for  117.Clay_colored_Sparrow is  0.6610169491525424
# final_acc :  0.44319573527652517
# 60
# correctly classified :  118.House_Sparrow 37
# accuracy for  118.House_Sparrow is  0.6166666666666667
# final_acc :  0.44627906860985844
# 59
# correctly classified :  119.Field_Sparrow 42
# accuracy for  119.Field_Sparrow is  0.711864406779661
# final_acc :  0.4498383906437568
# 60
# correctly classified :  120.Fox_Sparrow 47
# accuracy for  120.Fox_Sparrow is  0.7833333333333333
# final_acc :  0.4537550573104234
# 60
# correctly classified :  121.Grasshopper_Sparrow 43
# accuracy for  121.Grasshopper_Sparrow is  0.7166666666666667
# final_acc :  0.4573383906437568
# 60
# correctly classified :  122.Harris_Sparrow 39
# accuracy for  122.Harris_Sparrow is  0.65
# final_acc :  0.46058839064375684
# 60
# correctly classified :  123.Henslow_Sparrow 33
# accuracy for  123.Henslow_Sparrow is  0.55
# final_acc :  0.4633383906437568
# 59
# correctly classified :  124.Le_Conte_Sparrow 52
# accuracy for  124.Le_Conte_Sparrow is  0.8813559322033898
# final_acc :  0.46774517030477375
# 59
# correctly classified :  125.Lincoln_Sparrow 40
# accuracy for  125.Lincoln_Sparrow is  0.6779661016949152
# final_acc :  0.4711350008132484
# 59
# correctly classified :  126.Nelson_Sharp_tailed_Sparrow 50
# accuracy for  126.Nelson_Sharp_tailed_Sparrow is  0.847457627118644
# final_acc :  0.4753722889488416
# 60
# correctly classified :  127.Savannah_Sparrow 39
# accuracy for  127.Savannah_Sparrow is  0.65
# final_acc :  0.4786222889488416
# 60
# correctly classified :  128.Seaside_Sparrow 50
# accuracy for  128.Seaside_Sparrow is  0.8333333333333334
# final_acc :  0.4827889556155083
# 60
# correctly classified :  129.Song_Sparrow 31
# accuracy for  129.Song_Sparrow is  0.5166666666666667
# final_acc :  0.4853722889488416
# 60
# correctly classified :  130.Tree_Sparrow 41
# accuracy for  130.Tree_Sparrow is  0.6833333333333333
# final_acc :  0.4887889556155083
# 60
# correctly classified :  131.Vesper_Sparrow 53
# accuracy for  131.Vesper_Sparrow is  0.8833333333333333
# final_acc :  0.49320562228217496
# 60
# correctly classified :  132.White_crowned_Sparrow 52
# accuracy for  132.White_crowned_Sparrow is  0.8666666666666667
# final_acc :  0.49753895561550826
# 60
# correctly classified :  133.White_throated_Sparrow 44
# accuracy for  133.White_throated_Sparrow is  0.7333333333333333
# final_acc :  0.5012056222821749
# 60
# correctly classified :  134.Cape_Glossy_Starling 53
# accuracy for  134.Cape_Glossy_Starling is  0.8833333333333333
# final_acc :  0.5056222889488416
# 59
# correctly classified :  135.Bank_Swallow 28
# accuracy for  135.Bank_Swallow is  0.4745762711864407
# final_acc :  0.5079951703047738
# 60
# correctly classified :  136.Barn_Swallow 41
# accuracy for  136.Barn_Swallow is  0.6833333333333333
# final_acc :  0.5114118369714405
# 60
# correctly classified :  137.Cliff_Swallow 34
# accuracy for  137.Cliff_Swallow is  0.5666666666666667
# final_acc :  0.5142451703047738
# 60
# correctly classified :  138.Tree_Swallow 48
# accuracy for  138.Tree_Swallow is  0.8
# final_acc :  0.5182451703047738
# 60
# correctly classified :  139.Scarlet_Tanager 56
# accuracy for  139.Scarlet_Tanager is  0.9333333333333333
# final_acc :  0.5229118369714405
# 60
# correctly classified :  140.Summer_Tanager 55
# accuracy for  140.Summer_Tanager is  0.9166666666666666
# final_acc :  0.5274951703047739
# 58
# correctly classified :  141.Artic_Tern 40
# accuracy for  141.Artic_Tern is  0.6896551724137931
# final_acc :  0.5309434461668429
# 60
# correctly classified :  142.Black_Tern 42
# accuracy for  142.Black_Tern is  0.7
# final_acc :  0.5344434461668428
# 60
# correctly classified :  143.Caspian_Tern 36
# accuracy for  143.Caspian_Tern is  0.6
# final_acc :  0.5374434461668428
# 60
# correctly classified :  144.Common_Tern 44
# accuracy for  144.Common_Tern is  0.7333333333333333
# final_acc :  0.5411101128335095
# 60
# correctly classified :  145.Elegant_Tern 35
# accuracy for  145.Elegant_Tern is  0.5833333333333334
# final_acc :  0.5440267795001761
# 60
# correctly classified :  146.Forsters_Tern 36
# accuracy for  146.Forsters_Tern is  0.6
# final_acc :  0.5470267795001761
# 60
# correctly classified :  147.Least_Tern 40
# accuracy for  147.Least_Tern is  0.6666666666666666
# final_acc :  0.5503601128335095
# 60
# correctly classified :  148.Green_tailed_Towhee 52
# accuracy for  148.Green_tailed_Towhee is  0.8666666666666667
# final_acc :  0.5546934461668428
# 59
# correctly classified :  149.Brown_Thrasher 52
# accuracy for  149.Brown_Thrasher is  0.8813559322033898
# final_acc :  0.5591002258278597
# 60
# correctly classified :  150.Sage_Thrasher 53
# accuracy for  150.Sage_Thrasher is  0.8833333333333333
# final_acc :  0.5635168924945264
# 51
# correctly classified :  151.Black_capped_Vireo 50
# accuracy for  151.Black_capped_Vireo is  0.9803921568627451
# final_acc :  0.5684188532788401
# 60
# correctly classified :  152.Blue_headed_Vireo 50
# accuracy for  152.Blue_headed_Vireo is  0.8333333333333334
# final_acc :  0.5725855199455068
# 59
# correctly classified :  153.Philadelphia_Vireo 45
# accuracy for  153.Philadelphia_Vireo is  0.7627118644067796
# final_acc :  0.5763990792675407
# 60
# correctly classified :  154.Red_eyed_Vireo 46
# accuracy for  154.Red_eyed_Vireo is  0.7666666666666667
# final_acc :  0.580232412600874
# 60
# correctly classified :  155.Warbling_Vireo 44
# accuracy for  155.Warbling_Vireo is  0.7333333333333333
# final_acc :  0.5838990792675407
# 60
# correctly classified :  156.White_eyed_Vireo 58
# accuracy for  156.White_eyed_Vireo is  0.9666666666666667
# final_acc :  0.588732412600874
# 59
# correctly classified :  157.Yellow_throated_Vireo 38
# accuracy for  157.Yellow_throated_Vireo is  0.6440677966101694
# final_acc :  0.5919527515839249
# 60
# correctly classified :  158.Bay_breasted_Warbler 44
# accuracy for  158.Bay_breasted_Warbler is  0.7333333333333333
# final_acc :  0.5956194182505916
# 60
# correctly classified :  159.Black_and_white_Warbler 56
# accuracy for  159.Black_and_white_Warbler is  0.9333333333333333
# final_acc :  0.6002860849172582
# 59
# correctly classified :  160.Black_throated_Blue_Warbler 46
# accuracy for  160.Black_throated_Blue_Warbler is  0.7796610169491526
# final_acc :  0.604184390002004
# 60
# correctly classified :  161.Blue_winged_Warbler 52
# accuracy for  161.Blue_winged_Warbler is  0.8666666666666667
# final_acc :  0.6085177233353373
# 60
# correctly classified :  162.Canada_Warbler 53
# accuracy for  162.Canada_Warbler is  0.8833333333333333
# final_acc :  0.612934390002004
# 60
# correctly classified :  163.Cape_May_Warbler 54
# accuracy for  163.Cape_May_Warbler is  0.9
# final_acc :  0.6174343900020041
# 60
# correctly classified :  164.Cerulean_Warbler 49
# accuracy for  164.Cerulean_Warbler is  0.8166666666666667
# final_acc :  0.6215177233353374
# 60
# correctly classified :  165.Chestnut_sided_Warbler 49
# accuracy for  165.Chestnut_sided_Warbler is  0.8166666666666667
# final_acc :  0.6256010566686707
# 59
# correctly classified :  166.Golden_winged_Warbler 51
# accuracy for  166.Golden_winged_Warbler is  0.864406779661017
# final_acc :  0.6299230905669757
# 60
# correctly classified :  167.Hooded_Warbler 48
# accuracy for  167.Hooded_Warbler is  0.8
# final_acc :  0.6339230905669757
# 59
# correctly classified :  168.Kentucky_Warbler 53
# accuracy for  168.Kentucky_Warbler is  0.8983050847457628
# final_acc :  0.6384146159907045
# 59
# correctly classified :  169.Magnolia_Warbler 55
# accuracy for  169.Magnolia_Warbler is  0.9322033898305084
# final_acc :  0.643075632939857
# 60
# correctly classified :  170.Mourning_Warbler 39
# accuracy for  170.Mourning_Warbler is  0.65
# final_acc :  0.6463256329398571
# 60
# correctly classified :  171.Myrtle_Warbler 50
# accuracy for  171.Myrtle_Warbler is  0.8333333333333334
# final_acc :  0.6504922996065239
# 60
# correctly classified :  172.Nashville_Warbler 55
# accuracy for  172.Nashville_Warbler is  0.9166666666666666
# final_acc :  0.6550756329398572
# 60
# correctly classified :  173.Orange_crowned_Warbler 50
# accuracy for  173.Orange_crowned_Warbler is  0.8333333333333334
# final_acc :  0.6592422996065238
# 60
# correctly classified :  174.Palm_Warbler 43
# accuracy for  174.Palm_Warbler is  0.7166666666666667
# final_acc :  0.6628256329398572
# 60
# correctly classified :  175.Pine_Warbler 48
# accuracy for  175.Pine_Warbler is  0.8
# final_acc :  0.6668256329398572
# 60
# correctly classified :  176.Prairie_Warbler 59
# accuracy for  176.Prairie_Warbler is  0.9833333333333333
# final_acc :  0.6717422996065239
# 60
# correctly classified :  177.Prothonotary_Warbler 59
# accuracy for  177.Prothonotary_Warbler is  0.9833333333333333
# final_acc :  0.6766589662731904
# 56
# correctly classified :  178.Swainson_Warbler 45
# accuracy for  178.Swainson_Warbler is  0.8035714285714286
# final_acc :  0.6806768234160475
# 59
# correctly classified :  179.Tennessee_Warbler 20
# accuracy for  179.Tennessee_Warbler is  0.3389830508474576
# final_acc :  0.6823717386702848
# 60
# correctly classified :  180.Wilson_Warbler 56
# accuracy for  180.Wilson_Warbler is  0.9333333333333333
# final_acc :  0.6870384053369514
# 59
# correctly classified :  181.Worm_eating_Warbler 50
# accuracy for  181.Worm_eating_Warbler is  0.847457627118644
# final_acc :  0.6912756934725447
# 60
# correctly classified :  182.Yellow_Warbler 55
# accuracy for  182.Yellow_Warbler is  0.9166666666666666
# final_acc :  0.695859026805878
# 60
# correctly classified :  183.Northern_Waterthrush 49
# accuracy for  183.Northern_Waterthrush is  0.8166666666666667
# final_acc :  0.6999423601392113
# 60
# correctly classified :  184.Louisiana_Waterthrush 45
# accuracy for  184.Louisiana_Waterthrush is  0.75
# final_acc :  0.7036923601392112
# 60
# correctly classified :  185.Bohemian_Waxwing 52
# accuracy for  185.Bohemian_Waxwing is  0.8666666666666667
# final_acc :  0.7080256934725446
# 60
# correctly classified :  186.Cedar_Waxwing 55
# accuracy for  186.Cedar_Waxwing is  0.9166666666666666
# final_acc :  0.7126090268058779
# 50
# correctly classified :  187.American_Three_toed_Woodpecker 33
# accuracy for  187.American_Three_toed_Woodpecker is  0.66
# final_acc :  0.7159090268058779
# 60
# correctly classified :  188.Pileated_Woodpecker 54
# accuracy for  188.Pileated_Woodpecker is  0.9
# final_acc :  0.7204090268058779
# 60
# correctly classified :  189.Red_bellied_Woodpecker 59
# accuracy for  189.Red_bellied_Woodpecker is  0.9833333333333333
# final_acc :  0.7253256934725445
# 58
# correctly classified :  190.Red_cockaded_Woodpecker 53
# accuracy for  190.Red_cockaded_Woodpecker is  0.9137931034482759
# final_acc :  0.7298946589897859
# 60
# correctly classified :  191.Red_headed_Woodpecker 45
# accuracy for  191.Red_headed_Woodpecker is  0.75
# final_acc :  0.7336446589897859
# 60
# correctly classified :  192.Downy_Woodpecker 51
# accuracy for  192.Downy_Woodpecker is  0.85
# final_acc :  0.7378946589897859
# 60
# correctly classified :  193.Bewick_Wren 46
# accuracy for  193.Bewick_Wren is  0.7666666666666667
# final_acc :  0.7417279923231193
# 60
# correctly classified :  194.Cactus_Wren 46
# accuracy for  194.Cactus_Wren is  0.7666666666666667
# final_acc :  0.7455613256564527
# 60
# correctly classified :  195.Carolina_Wren 38
# accuracy for  195.Carolina_Wren is  0.6333333333333333
# final_acc :  0.7487279923231194
# 59
# correctly classified :  196.House_Wren 38
# accuracy for  196.House_Wren is  0.6440677966101694
# final_acc :  0.7519483313061701
# 60
# correctly classified :  197.Marsh_Wren 31
# accuracy for  197.Marsh_Wren is  0.5166666666666667
# final_acc :  0.7545316646395035
# 60
# correctly classified :  198.Rock_Wren 45
# accuracy for  198.Rock_Wren is  0.75
# final_acc :  0.7582816646395035
# 60
# correctly classified :  199.Winter_Wren 49
# accuracy for  199.Winter_Wren is  0.8166666666666667
# final_acc :  0.7623649979728369
# 60
# correctly classified :  200.Common_Yellowthroat 58
# accuracy for  200.Common_Yellowthroat is  0.9666666666666667
# final_acc :  0.7671983313061702
# 59
# correctly classified :  019.Gray_Catbird 31
# accuracy for  019.Gray_Catbird is  0.5254237288135594
# final_acc :  0.769825449950238
# 44
# correctly classified :  005.Crested_Auklet 41
# accuracy for  005.Crested_Auklet is  0.9318181818181818
# final_acc :  0.7744845408593289
# 59
# correctly classified :  034.Gray_crowned_Rosy_Finch 48
# accuracy for  034.Gray_crowned_Rosy_Finch is  0.8135593220338984
# final_acc :  0.7785523374694985
