# %%
import math
import time
import sys
import os
import random
import pickle

import numpy as np

import tensorflow.keras
import tensorflow.keras.layers
import tensorflow.keras.applications
import tensorflow.keras.backend
import tensorflow.keras.preprocessing.image
import tensorflow.keras.utils
import tensorflow as tf

import cv2
import PIL
import PIL.Image
import matplotlib.pyplot as plt

import shutil

from tensorflow.keras import backend as K


# configurations

## seeding
os.environ['PYTHONHASHSEED'] = '3'
np.random.seed(3)
random.seed(3)
tf.random.set_seed(3)

## which gpu to use
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

## memory allocation
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
# config.gpu_options.per_process_gpu_memory_fraction = 0.5
session = tf.compat.v1.Session(config=config)
#K.set_session(session)
tf.compat.v1.keras.backend.set_session(session)
## data directory for CUB200 root
PATH_DATA_ROOT_CUB200 = "/kaggle/working/200-bird-species-with-11788-images/CUB_200_2011"

## network configurations
### number of output classes, 200 for CUB200
NO_CLASS = 200
# Out:
# 2022-01-08 16:25:52.725915: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-08 16:25:52.779934: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 16:25:52.869504: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 16:25:52.870444: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 16:25:54.651138: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 16:25:54.652252: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 16:25:54.653183: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 16:25:54.653956: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
import tarfile
import gzip
import shutil

def extract(tar_file, path):
    opened_tar = tarfile.open(tar_file)
     
    if tarfile.is_tarfile(tar_file):
        opened_tar.extractall(path)
    else:
        print("The tar file you entered is not a tar file")
        
extract('../input/200-bird-species-with-11788-images/CUB_200_2011.tgz', '/kaggle/working/200-bird-species-with-11788-images/')

# %%
from tensorflow.keras.initializers import glorot_normal
from keras.layers import Lambda

def outer_product(x):
    """
    calculate outer-products of 2 tensors

        args 
            x
                list of 2 tensors
                , assuming each of which has shape = (size_minibatch, total_pixels, size_filter)
    """
    return tensorflow.keras.backend.batch_dot(
                x[0]
                , x[1]
                , axes=[1,1]
            ) / x[0].get_shape().as_list()[1] 

def signed_sqrt(x):
    """
    calculate element-wise signed square root

        args
            x
                a tensor
    """
    return tensorflow.keras.backend.sign(x) * tensorflow.keras.backend.sqrt(tensorflow.keras.backend.abs(x) + 1e-9)

def L2_norm(x, axis=-1):
    """
    calculate L2-norm

        args 
            x
                a tensor
    """
    return tensorflow.keras.backend.l2_normalize(x, axis=axis)


def build_model(arryWeights_last
    ,size_heigth=448
    ,size_width=448
    ,no_class=200
    ,no_last_layer_backbone=17
    
    ,name_optimizer="sgd"
    ,rate_learning=1.0
    ,rate_decay_learning=0.0
    ,rate_decay_weight=0.0
    
    ,name_initializer="glorot_normal"
    ,name_activation_logits="softmax"
    ,name_loss="categorical_crossentropy"
    ,flg_debug=False
    ,**kwargs
):
    
    tensorflow.keras.backend.clear_session()
    
    # print("-------------------------------")
    # print("parameters:")
    # for key, val in locals().items():
    #     if not val == None and not key == "kwargs":
    #         print("\t", key, "=",  val)
    # print("-------------------------------")
    
    ### 
    ### load pre-trained model
    ###
    tensor_input = tensorflow.keras.layers.Input(shape=[size_heigth,size_width,3])
    model_detector = tensorflow.keras.applications.vgg16.VGG16(
                            input_tensor=tensor_input
                            , include_top=False
                            , weights='imagenet'
                        )
    
    # arryWeights_last_After =[]
    # for i in range(512):
    #   arryWeights_last_After.append(i)
    # for i in range(512):
    #   arryWeights_last_After[i]=1
    
    # arryWeights_last_After[filter_zero]=value_filter
    # print('filter' , filter_zero, "=", arryWeights_last_After[filter_zero])
    def custom_layer_last(tensor):
        return tensor * arryWeights_last
    lambda_layer = Lambda (custom_layer_last, name="lambda_New")

    model_detector = insert_intermediate_layer_in_keras (model_detector, 18, lambda_layer)
    # print('model detector')
    # model_detector.summary()
    ### 
    ### bi-linear pooling
    ###

    # extract features from detector
    x_detector = model_detector.layers[no_last_layer_backbone].output
    shape_detector = model_detector.layers[no_last_layer_backbone].output_shape
    # if flg_debug:
    #     print("shape_detector : {}".format(shape_detector))

    # extract features from extractor , same with detector for symmetry DxD model
    shape_extractor = shape_detector
    x_extractor = x_detector
    # if flg_debug:
    #     print("shape_extractor : {}".format(shape_extractor))
        
    
    # rehape to (minibatch_size, total_pixels, filter_size)
    x_detector = tensorflow.keras.layers.Reshape(
            [
                shape_detector[1] * shape_detector[2] , shape_detector[-1]
            ]
        )(x_detector)
    # if flg_debug:
    #     print("x_detector shape after rehsape ops : {}".format(x_detector.shape))
        
    x_extractor = tensorflow.keras.layers.Reshape(
            [
                shape_extractor[1] * shape_extractor[2] , shape_extractor[-1]
            ]
        )(x_extractor)
    # if flg_debug:
    #     print("x_extractor shape after rehsape ops : {}".format(x_extractor.shape))
        
        
    # outer products of features, output shape=(minibatch_size, filter_size_detector*filter_size_extractor)
    x = tensorflow.keras.layers.Lambda(outer_product)(
        [x_detector, x_extractor]
    )
    # if flg_debug:
    #     print("x shape after outer products ops : {}".format(x.shape))
        
        
    # rehape to (minibatch_size, filter_size_detector*filter_size_extractor)
    x = tensorflow.keras.layers.Reshape([shape_detector[-1]*shape_extractor[-1]])(x)
    # if flg_debug:
    #     print("x shape after rehsape ops : {}".format(x.shape))
        
        
    # signed square-root 
    x = tensorflow.keras.layers.Lambda(signed_sqrt)(x)
    # if flg_debug:
    #     print("x shape after signed-square-root ops : {}".format(x.shape))
        
    # L2 normalization
    x = tensorflow.keras.layers.Lambda(L2_norm)(x)
    # if flg_debug:
    #     print("x shape after L2-Normalization ops : {}".format(x.shape))



    ### 
    ### attach FC-Layer
    ###

    if name_initializer != None:
            name_initializer = eval(name_initializer+"()")
            
    x = tensorflow.keras.layers.Dense(
            units=no_class
            ,kernel_regularizer=tensorflow.keras.regularizers.l2(rate_decay_weight)
            ,kernel_initializer=name_initializer
        )(x)
    # if flg_debug:
    #     print("x shape after Dense ops : {}".format(x.shape))
    tensor_prediction = tensorflow.keras.layers.Activation(name_activation_logits)(x)
    # if flg_debug:
    #     print("prediction shape : {}".format(tensor_prediction.shape))

        

    ### 
    ### compile model
    ###
    model_bilinear = tensorflow.keras.models.Model(
                        inputs=[tensor_input]
                        , outputs=[tensor_prediction]
                    )
    
    
    # fix pre-trained weights
    for layer in model_detector.layers:
        layer.trainable = False
        
        
    # define optimizers
    opt_adam = tensorflow.keras.optimizers.Adam(
                    lr=rate_learning
                    , decay=rate_decay_learning
                )
    opt_rms = tensorflow.keras.optimizers.RMSprop(
                    lr=rate_learning
                    , decay=rate_decay_learning
                )
    opt_sgd = tensorflow.keras.optimizers.SGD(
                    lr=rate_learning
                    , decay=rate_decay_learning
                    , momentum=0.9
                    , nesterov=False
                )
    optimizers ={
        "adam":opt_adam
        ,"rmsprop":opt_rms
        ,"sgd":opt_sgd
    }
    
    model_bilinear.compile(
        loss=name_loss
        , optimizer=optimizers[name_optimizer]
        , metrics=["categorical_accuracy"]
    )
    
    
    
    # if flg_debug:
    #     model_bilinear.summary()
    
    return model_bilinear

# %%
def insert_intermediate_layer_in_keras(model, layer_id, new_layer):
    from keras.models import Model

    layers = [l for l in model.layers]

    x = layers[0].output
    for i in range(1, len(layers)):
        if i == layer_id:
            x = new_layer(x)
        x = layers[i](x)

    model = Model(inputs=layers[0].input, outputs=x) ### inputs instead of input in this version
    return model

# %%
arryWeights_last_After =[]
for i in range(512):
  arryWeights_last_After.append(i)
for i in range(512):
  arryWeights_last_After[i]=1
model = build_model(arryWeights_last_After
            # number of output classes, 200 for CUB200
            ,no_class = NO_CLASS

            # pretrained model specification, using VGG16
            # "block5_conv3 "
            ,no_last_layer_backbone = 18

            # training parametes
            ,rate_learning=1.0
            ,rate_decay_weight=1e-8
            ,flg_debug=True
        )

# model = build_model(
#             # number of output classes, 200 for CUB200
#             no_class = NO_CLASS

#             # pretrained model specification, using VGG16
#             # "block5_conv3 "
#             ,no_last_layer_backbone = 17           
#             # training parametes
#             ,rate_learning=1.0
#             ,rate_decay_weight=1e-8
#             ,flg_debug=True
#         )
# Out:
# 2022-01-08 16:26:45.113251: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 16:26:45.114070: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 16:26:45.114748: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 16:26:45.115639: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 16:26:45.116312: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 16:26:45.116893: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 16:26:45.117603: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 16:26:45.118244: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 16:26:45.118810: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# /opt/conda/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
# now all layers are trainable
for layer in model.layers:
    layer.trainable = True

# change LR
opt_sgd = tensorflow.keras.optimizers.SGD(
                lr=1e-3
                , decay=1e-9
                , momentum=0.9
                , nesterov=False
            )
model.compile(
    loss="categorical_crossentropy"
    , optimizer=opt_sgd
    , metrics=["categorical_accuracy"]
)

# %%
model.load_weights("../input/birds-weights/birds_200_weights.h5")

# %%
import os

birds_labels = set()

path= "./200-bird-species-with-11788-images/CUB_200_2011/images/"
for d in os.listdir(path):
    birds_labels.add(d)

len(birds_labels)

# print(birds_labels)
# Out:
# 200

# %%
birds_labels = list(birds_labels)
birds_labels.sort()
# birds_labels

# %%
import cv2
def load_and_preprocess_image(path):
    image = cv2.imread(path)
    image = cv2.resize(image, (448,448))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import numpy as np

def output(location, new_model):
    img = load_and_preprocess_image(location)
#     img = load_img(location, target_size = (224, 224, 3))
#     img = img_to_array(img)
#     img = img / 255
    img = np.expand_dims(img, axis=0)
    answer = new_model.predict(img)
    y_class = answer.argmax(axis = -1)
    
    top_3 = np.argsort(answer[0])[:-4:-1]
    # for i in range(3):
    #     print(" ({:.3})".format(answer[0][top_3[i]]))
    
    y = " ".join(str(x) for x in y_class)
    y = int(y)
    res = birds_labels[y]
    # print(res)
#     print(" ({:.3})".format(answer[0][top_3[0]]))
    pred_prob = answer[0][top_3[0]]
    return float(pred_prob), res

# %%
location = "./200-bird-species-with-11788-images/CUB_200_2011/images/004.Groove_billed_Ani/Groove_Billed_Ani_0087_1765.jpg"
output(location, model)

# %%
import ast
a_file = open("../input/resp-birds/Filt_Resp_Birds_BCNN.txt", "r")
# a_file = open("Gibbon_panda.txt", "r")
# a_file = open("Gimagenet_Test_2.txt", "r")


string_without_line_breaks = ""
for line in a_file:
    stripped_line = line.rstrip()
    string_without_line_breaks += stripped_line

import re
dict_Classes = ast.literal_eval(re.search('({.+})', string_without_line_breaks).group(0))

# for key, value in dict_Classes.items():
#     print ('classId', key)
#     print ('value', value)
a_file.close()
#print(dict_Classes)

# %%
import collections
od = collections.OrderedDict(sorted(dict_Classes.items()))
list_b=[]
for item in od:
    # print(item)
    list_b.append(item)

# %% [markdown]
# Original **model**

# %%
# import cv2
# import os
# from shutil import copyfile
# from pathlib import Path
# final_acc = 0
# folder = "/content/drive/My Drive/Colab Notebooks/Cub-200_BCNN/CUB_200_2011/CUB_200_2011/images/"
# print(len(os.listdir(folder + "001.Black_footed_Albatross")))
# imagesFileNames = []
# for filename in os.listdir(folder):    
#     correct_count_By_folder=0
#     print( len(os.listdir(folder+str(filename)) ))
#     for img in os.listdir(folder+filename):
#         if output(folder+filename+"/"+img, model)[1] ==  filename:
#             correct_count_By_folder+=1
#     final_accu_by_class = correct_count_By_folder/len(os.listdir(folder+filename))
#     print('correctly classified : ' ,filename, correct_count_By_folder)
#     print('accuracy for ' , filename , 'is ' , final_accu_by_class)
#     final_acc += final_accu_by_class
#     print('final_acc : ', final_acc/200) &

# #images = load_images_from_folder(folder)

# %% [markdown]
# # ** CauSim**

# %%
import cv2
import os
from shutil import copyfile
from pathlib import Path
final_acc = 0
folder = "./200-bird-species-with-11788-images/CUB_200_2011/images/"
print(len(os.listdir(folder + "001.Black_footed_Albatross")))
imagesFileNames = []
for filename in os.listdir(folder):
    for key, value in dict_Classes.items():      
        if key == filename: 
          print('key found:', key)
          weights_dic_Conv2_13= {}
          weights_dic_Conv2_13.update(value)
          weights_dic_Conv2_13 = sorted (weights_dic_Conv2_13.items ())
          arryWeights_last_After = []
          od = collections.OrderedDict(weights_dic_Conv2_13)
          for i in range(len(od)):
              if weights_dic_Conv2_13[i][1][0] >0:
                  arryWeights_last_After.append(1) 
              else:
                  arryWeights_last_After.append(0)

          new_model = build_model( arryWeights_last_After
                  # number of output classes, 200 for CUB200
                  ,no_class = NO_CLASS

                  # pretrained model specification, using VGG16
                  # "block5_conv3 "
                  ,no_last_layer_backbone = 18
                              # training parametes
                  ,rate_learning=1.0
                  ,rate_decay_weight=1e-8
                  ,flg_debug=True
              )

                      # now all layers are trainable
          for layer in new_model.layers:
                layer.trainable = True

          # change LR
          opt_sgd = tensorflow.keras.optimizers.SGD(
                          lr=1e-3
                          , decay=1e-9
                          , momentum=0.9
                          , nesterov=False
                      )
          new_model.compile(
              loss="categorical_crossentropy"
              , optimizer=opt_sgd
              , metrics=["categorical_accuracy"]
          )

          new_model.load_weights('../input/birds-weights/birds_200_weights.h5')

          K.clear_session ()
          break;
    correct_count_By_folder=0
    print( len(os.listdir(folder+str(filename)) ))
    for img in os.listdir(folder+filename):
        if output(folder+filename+"/"+img, new_model)[1] ==  filename:
            correct_count_By_folder+=1
    final_accu_by_class = correct_count_By_folder/len(os.listdir(folder+filename))
    print('correctly classified : ' ,filename, correct_count_By_folder)
    print('accuracy for ' , filename , 'is ' , final_accu_by_class)
    final_acc += final_accu_by_class
    print('final_acc : ', final_acc/200) 

#images = load_images_from_folder(folder)
# Out:
# 60
# key found: 028.Brown_Creeper
# 59
# correctly classified :  028.Brown_Creeper 59
# accuracy for  028.Brown_Creeper is  1.0
# final_acc :  0.005
# key found: 164.Cerulean_Warbler
# 60
# correctly classified :  164.Cerulean_Warbler 60
# accuracy for  164.Cerulean_Warbler is  1.0
# final_acc :  0.01
# key found: 177.Prothonotary_Warbler
# 60
# correctly classified :  177.Prothonotary_Warbler 60
# accuracy for  177.Prothonotary_Warbler is  1.0
# final_acc :  0.015
# key found: 109.American_Redstart
# 60
# correctly classified :  109.American_Redstart 54
# accuracy for  109.American_Redstart is  0.9
# final_acc :  0.0195
# key found: 068.Ruby_throated_Hummingbird
# 60
# correctly classified :  068.Ruby_throated_Hummingbird 57
# accuracy for  068.Ruby_throated_Hummingbird is  0.95
# final_acc :  0.024249999999999997
# key found: 064.Ring_billed_Gull
# 60
# correctly classified :  064.Ring_billed_Gull 54
# accuracy for  064.Ring_billed_Gull is  0.9
# final_acc :  0.02875
# key found: 119.Field_Sparrow
# 59
# correctly classified :  119.Field_Sparrow 55
# accuracy for  119.Field_Sparrow is  0.9322033898305084
# final_acc :  0.03341101694915254
# key found: 200.Common_Yellowthroat
# 60
# correctly classified :  200.Common_Yellowthroat 60
# accuracy for  200.Common_Yellowthroat is  1.0
# final_acc :  0.03841101694915254
# key found: 056.Pine_Grosbeak
# 60
# correctly classified :  056.Pine_Grosbeak 57
# accuracy for  056.Pine_Grosbeak is  0.95
# final_acc :  0.04316101694915254
# key found: 190.Red_cockaded_Woodpecker
# 58
# correctly classified :  190.Red_cockaded_Woodpecker 56
# accuracy for  190.Red_cockaded_Woodpecker is  0.9655172413793104
# final_acc :  0.04798860315604909
# key found: 188.Pileated_Woodpecker
# 60
# correctly classified :  188.Pileated_Woodpecker 60
# accuracy for  188.Pileated_Woodpecker is  1.0
# final_acc :  0.052988603156049086
# key found: 168.Kentucky_Warbler
# 59
# correctly classified :  168.Kentucky_Warbler 58
# accuracy for  168.Kentucky_Warbler is  0.9830508474576272
# final_acc :  0.05790385739333722
# key found: 022.Chuck_will_Widow
# 56
# correctly classified :  022.Chuck_will_Widow 51
# accuracy for  022.Chuck_will_Widow is  0.9107142857142857
# final_acc :  0.062457428821908655
# key found: 157.Yellow_throated_Vireo
# 59
# correctly classified :  157.Yellow_throated_Vireo 54
# accuracy for  157.Yellow_throated_Vireo is  0.9152542372881356
# final_acc :  0.06703370000834932
# key found: 001.Black_footed_Albatross
# 60
# correctly classified :  001.Black_footed_Albatross 52
# accuracy for  001.Black_footed_Albatross is  0.8666666666666667
# final_acc :  0.07136703334168266
# key found: 110.Geococcyx
# 60
# correctly classified :  110.Geococcyx 59
# accuracy for  110.Geococcyx is  0.9833333333333333
# final_acc :  0.07628370000834933
# key found: 125.Lincoln_Sparrow
# 59
# correctly classified :  125.Lincoln_Sparrow 55
# accuracy for  125.Lincoln_Sparrow is  0.9322033898305084
# final_acc :  0.08094471695750187
# key found: 048.European_Goldfinch
# 60
# correctly classified :  048.European_Goldfinch 59
# accuracy for  048.European_Goldfinch is  0.9833333333333333
# final_acc :  0.08586138362416854
# key found: 039.Least_Flycatcher
# 59
# correctly classified :  039.Least_Flycatcher 39
# accuracy for  039.Least_Flycatcher is  0.6610169491525424
# final_acc :  0.08916646836993125
# key found: 030.Fish_Crow
# 60
# correctly classified :  030.Fish_Crow 51
# accuracy for  030.Fish_Crow is  0.85
# final_acc :  0.09341646836993127
# key found: 191.Red_headed_Woodpecker
# 60
# correctly classified :  191.Red_headed_Woodpecker 57
# accuracy for  191.Red_headed_Woodpecker is  0.95
# final_acc :  0.09816646836993126
# key found: 129.Song_Sparrow
# 60
# correctly classified :  129.Song_Sparrow 48
# accuracy for  129.Song_Sparrow is  0.8
# final_acc :  0.10216646836993126
# key found: 015.Lazuli_Bunting
# 58
# correctly classified :  015.Lazuli_Bunting 54
# accuracy for  015.Lazuli_Bunting is  0.9310344827586207
# final_acc :  0.10682164078372436
# key found: 107.Common_Raven
# 59
# correctly classified :  107.Common_Raven 39
# accuracy for  107.Common_Raven is  0.6610169491525424
# final_acc :  0.11012672552948707
# key found: 075.Green_Jay
# 57
# correctly classified :  075.Green_Jay 52
# accuracy for  075.Green_Jay is  0.9122807017543859
# final_acc :  0.114688129038259
# key found: 058.Pigeon_Guillemot
# 58
# correctly classified :  058.Pigeon_Guillemot 47
# accuracy for  058.Pigeon_Guillemot is  0.8103448275862069
# final_acc :  0.11873985317619004
# key found: 141.Artic_Tern
# 58
# correctly classified :  141.Artic_Tern 53
# accuracy for  141.Artic_Tern is  0.9137931034482759
# final_acc :  0.12330881869343142
# key found: 072.Pomarine_Jaeger
# 60
# correctly classified :  072.Pomarine_Jaeger 48
# accuracy for  072.Pomarine_Jaeger is  0.8
# final_acc :  0.12730881869343144
# key found: 174.Palm_Warbler
# 60
# correctly classified :  174.Palm_Warbler 52
# accuracy for  174.Palm_Warbler is  0.8666666666666667
# final_acc :  0.13164215202676477
# key found: 097.Orchard_Oriole
# 59
# correctly classified :  097.Orchard_Oriole 49
# accuracy for  097.Orchard_Oriole is  0.8305084745762712
# final_acc :  0.13579469439964612
# key found: 088.Western_Meadowlark
# 60
# correctly classified :  088.Western_Meadowlark 58
# accuracy for  088.Western_Meadowlark is  0.9666666666666667
# final_acc :  0.14062802773297944
# key found: 044.Frigatebird
# 60
# correctly classified :  044.Frigatebird 57
# accuracy for  044.Frigatebird is  0.95
# final_acc :  0.14537802773297945
# key found: 013.Bobolink
# 60
# correctly classified :  013.Bobolink 50
# accuracy for  013.Bobolink is  0.8333333333333334
# final_acc :  0.1495446943996461
# key found: 156.White_eyed_Vireo
# 60
# correctly classified :  156.White_eyed_Vireo 59
# accuracy for  156.White_eyed_Vireo is  0.9833333333333333
# final_acc :  0.15446136106631278
# key found: 041.Scissor_tailed_Flycatcher
# 60
# correctly classified :  041.Scissor_tailed_Flycatcher 57
# accuracy for  041.Scissor_tailed_Flycatcher is  0.95
# final_acc :  0.15921136106631276
# key found: 016.Painted_Bunting
# 58
# correctly classified :  016.Painted_Bunting 56
# accuracy for  016.Painted_Bunting is  0.9655172413793104
# final_acc :  0.1640389472732093
# key found: 095.Baltimore_Oriole
# 60
# correctly classified :  095.Baltimore_Oriole 57
# accuracy for  095.Baltimore_Oriole is  0.95
# final_acc :  0.16878894727320934
# key found: 031.Black_billed_Cuckoo
# 60
# correctly classified :  031.Black_billed_Cuckoo 53
# accuracy for  031.Black_billed_Cuckoo is  0.8833333333333333
# final_acc :  0.173205613939876
# key found: 135.Bank_Swallow
# 59
# correctly classified :  135.Bank_Swallow 48
# accuracy for  135.Bank_Swallow is  0.8135593220338984
# final_acc :  0.17727341055004547
# key found: 017.Cardinal
# 57
# correctly classified :  017.Cardinal 57
# accuracy for  017.Cardinal is  1.0
# final_acc :  0.18227341055004548
# key found: 096.Hooded_Oriole
# 60
# correctly classified :  096.Hooded_Oriole 48
# accuracy for  096.Hooded_Oriole is  0.8
# final_acc :  0.18627341055004545
# key found: 063.Ivory_Gull
# 60
# correctly classified :  063.Ivory_Gull 58
# accuracy for  063.Ivory_Gull is  0.9666666666666667
# final_acc :  0.1911067438833788
# key found: 150.Sage_Thrasher
# 60
# correctly classified :  150.Sage_Thrasher 58
# accuracy for  150.Sage_Thrasher is  0.9666666666666667
# final_acc :  0.19594007721671214
# key found: 026.Bronzed_Cowbird
# 60
# correctly classified :  026.Bronzed_Cowbird 56
# accuracy for  026.Bronzed_Cowbird is  0.9333333333333333
# final_acc :  0.2006067438833788
# key found: 055.Evening_Grosbeak
# 60
# correctly classified :  055.Evening_Grosbeak 56
# accuracy for  055.Evening_Grosbeak is  0.9333333333333333
# final_acc :  0.20527341055004544
# key found: 148.Green_tailed_Towhee
# 60
# correctly classified :  148.Green_tailed_Towhee 59
# accuracy for  148.Green_tailed_Towhee is  0.9833333333333333
# final_acc :  0.21019007721671212
# key found: 178.Swainson_Warbler
# 56
# correctly classified :  178.Swainson_Warbler 54
# accuracy for  178.Swainson_Warbler is  0.9642857142857143
# final_acc :  0.21501150578814068
# key found: 040.Olive_sided_Flycatcher
# 60
# correctly classified :  040.Olive_sided_Flycatcher 56
# accuracy for  040.Olive_sided_Flycatcher is  0.9333333333333333
# final_acc :  0.21967817245480734
# key found: 094.White_breasted_Nuthatch
# 60
# correctly classified :  094.White_breasted_Nuthatch 58
# accuracy for  094.White_breasted_Nuthatch is  0.9666666666666667
# final_acc :  0.2245115057881407
# key found: 176.Prairie_Warbler
# 60
# correctly classified :  176.Prairie_Warbler 60
# accuracy for  176.Prairie_Warbler is  1.0
# final_acc :  0.2295115057881407
# key found: 079.Belted_Kingfisher
# 60
# correctly classified :  079.Belted_Kingfisher 56
# accuracy for  079.Belted_Kingfisher is  0.9333333333333333
# final_acc :  0.23417817245480735
# key found: 061.Heermann_Gull
# 60
# correctly classified :  061.Heermann_Gull 53
# accuracy for  061.Heermann_Gull is  0.8833333333333333
# final_acc :  0.238594839121474
# key found: 117.Clay_colored_Sparrow
# 59
# correctly classified :  117.Clay_colored_Sparrow 53
# accuracy for  117.Clay_colored_Sparrow is  0.8983050847457628
# final_acc :  0.24308636454520283
# key found: 059.California_Gull
# 60
# correctly classified :  059.California_Gull 59
# accuracy for  059.California_Gull is  0.9833333333333333
# final_acc :  0.2480030312118695
# key found: 067.Anna_Hummingbird
# 60
# correctly classified :  067.Anna_Hummingbird 50
# accuracy for  067.Anna_Hummingbird is  0.8333333333333334
# final_acc :  0.25216969787853616
# key found: 077.Tropical_Kingbird
# 60
# correctly classified :  077.Tropical_Kingbird 58
# accuracy for  077.Tropical_Kingbird is  0.9666666666666667
# final_acc :  0.2570030312118695
# key found: 108.White_necked_Raven
# 60
# correctly classified :  108.White_necked_Raven 54
# accuracy for  108.White_necked_Raven is  0.9
# final_acc :  0.2615030312118695
# key found: 034.Gray_crowned_Rosy_Finch
# 59
# correctly classified :  034.Gray_crowned_Rosy_Finch 55
# accuracy for  034.Gray_crowned_Rosy_Finch is  0.9322033898305084
# final_acc :  0.266164048161022
# key found: 082.Ringed_Kingfisher
# 60
# correctly classified :  082.Ringed_Kingfisher 54
# accuracy for  082.Ringed_Kingfisher is  0.9
# final_acc :  0.270664048161022
# key found: 025.Pelagic_Cormorant
# 60
# correctly classified :  025.Pelagic_Cormorant 56
# accuracy for  025.Pelagic_Cormorant is  0.9333333333333333
# final_acc :  0.27533071482768867
# key found: 036.Northern_Flicker
# 60
# correctly classified :  036.Northern_Flicker 58
# accuracy for  036.Northern_Flicker is  0.9666666666666667
# final_acc :  0.28016404816102203
# key found: 102.Western_Wood_Pewee
# 60
# correctly classified :  102.Western_Wood_Pewee 52
# accuracy for  102.Western_Wood_Pewee is  0.8666666666666667
# final_acc :  0.2844973814943554
# key found: 136.Barn_Swallow
# 60
# correctly classified :  136.Barn_Swallow 51
# accuracy for  136.Barn_Swallow is  0.85
# final_acc :  0.28874738149435536
# key found: 194.Cactus_Wren
# 60
# correctly classified :  194.Cactus_Wren 51
# accuracy for  194.Cactus_Wren is  0.85
# final_acc :  0.2929973814943554
# key found: 043.Yellow_bellied_Flycatcher
# 59
# correctly classified :  043.Yellow_bellied_Flycatcher 48
# accuracy for  043.Yellow_bellied_Flycatcher is  0.8135593220338984
# final_acc :  0.2970651781045249
# key found: 086.Pacific_Loon
# 60
# correctly classified :  086.Pacific_Loon 57
# accuracy for  086.Pacific_Loon is  0.95
# final_acc :  0.30181517810452485
# key found: 160.Black_throated_Blue_Warbler
# 59
# correctly classified :  160.Black_throated_Blue_Warbler 54
# accuracy for  160.Black_throated_Blue_Warbler is  0.9152542372881356
# final_acc :  0.30639144929096557
# key found: 147.Least_Tern
# 60
# correctly classified :  147.Least_Tern 51
# accuracy for  147.Least_Tern is  0.85
# final_acc :  0.31064144929096554
# key found: 090.Red_breasted_Merganser
# 60
# correctly classified :  090.Red_breasted_Merganser 56
# accuracy for  090.Red_breasted_Merganser is  0.9333333333333333
# final_acc :  0.3153081159576322
# key found: 120.Fox_Sparrow
# 60
# correctly classified :  120.Fox_Sparrow 52
# accuracy for  120.Fox_Sparrow is  0.8666666666666667
# final_acc :  0.31964144929096555
# key found: 004.Groove_billed_Ani
# 60
# correctly classified :  004.Groove_billed_Ani 59
# accuracy for  004.Groove_billed_Ani is  0.9833333333333333
# final_acc :  0.32455811595763223
# key found: 166.Golden_winged_Warbler
# 59
# correctly classified :  166.Golden_winged_Warbler 55
# accuracy for  166.Golden_winged_Warbler is  0.9322033898305084
# final_acc :  0.32921913290678473
# key found: 161.Blue_winged_Warbler
# 60
# correctly classified :  161.Blue_winged_Warbler 57
# accuracy for  161.Blue_winged_Warbler is  0.95
# final_acc :  0.33396913290678476
# key found: 192.Downy_Woodpecker
# 60
# correctly classified :  192.Downy_Woodpecker 58
# accuracy for  192.Downy_Woodpecker is  0.9666666666666667
# final_acc :  0.3388024662401181
# key found: 145.Elegant_Tern
# 60
# correctly classified :  145.Elegant_Tern 60
# accuracy for  145.Elegant_Tern is  1.0
# final_acc :  0.3438024662401181
# key found: 062.Herring_Gull
# 60
# correctly classified :  062.Herring_Gull 51
# accuracy for  062.Herring_Gull is  0.85
# final_acc :  0.3480524662401181
# key found: 183.Northern_Waterthrush
# 60
# correctly classified :  183.Northern_Waterthrush 56
# accuracy for  183.Northern_Waterthrush is  0.9333333333333333
# final_acc :  0.35271913290678475
# key found: 180.Wilson_Warbler
# 60
# correctly classified :  180.Wilson_Warbler 59
# accuracy for  180.Wilson_Warbler is  0.9833333333333333
# final_acc :  0.35763579957345143
# key found: 112.Great_Grey_Shrike
# 60
# correctly classified :  112.Great_Grey_Shrike 57
# accuracy for  112.Great_Grey_Shrike is  0.95
# final_acc :  0.36238579957345146
# key found: 073.Blue_Jay
# 60
# correctly classified :  073.Blue_Jay 57
# accuracy for  073.Blue_Jay is  0.95
# final_acc :  0.36713579957345144
# key found: 027.Shiny_Cowbird
# 60
# correctly classified :  027.Shiny_Cowbird 52
# accuracy for  027.Shiny_Cowbird is  0.8666666666666667
# final_acc :  0.37146913290678474
# key found: 114.Black_throated_Sparrow
# 60
# correctly classified :  114.Black_throated_Sparrow 54
# accuracy for  114.Black_throated_Sparrow is  0.9
# final_acc :  0.3759691329067848
# key found: 154.Red_eyed_Vireo
# 60
# correctly classified :  154.Red_eyed_Vireo 59
# accuracy for  154.Red_eyed_Vireo is  0.9833333333333333
# final_acc :  0.3808857995734515
# key found: 052.Pied_billed_Grebe
# 60
# correctly classified :  052.Pied_billed_Grebe 58
# accuracy for  052.Pied_billed_Grebe is  0.9666666666666667
# final_acc :  0.38571913290678483
# key found: 009.Brewer_Blackbird
# 59
# correctly classified :  009.Brewer_Blackbird 53
# accuracy for  009.Brewer_Blackbird is  0.8983050847457628
# final_acc :  0.3902106583305136
# key found: 051.Horned_Grebe
# 60
# correctly classified :  051.Horned_Grebe 57
# accuracy for  051.Horned_Grebe is  0.95
# final_acc :  0.39496065833051364
# key found: 182.Yellow_Warbler
# 60
# correctly classified :  182.Yellow_Warbler 57
# accuracy for  182.Yellow_Warbler is  0.95
# final_acc :  0.3997106583305136
# key found: 185.Bohemian_Waxwing
# 60
# correctly classified :  185.Bohemian_Waxwing 60
# accuracy for  185.Bohemian_Waxwing is  1.0
# final_acc :  0.4047106583305136
# key found: 053.Western_Grebe
# 60
# correctly classified :  053.Western_Grebe 60
# accuracy for  053.Western_Grebe is  1.0
# final_acc :  0.4097106583305136
# key found: 151.Black_capped_Vireo
# 51
# correctly classified :  151.Black_capped_Vireo 51
# accuracy for  151.Black_capped_Vireo is  1.0
# final_acc :  0.4147106583305136
# key found: 065.Slaty_backed_Gull
# 50
# correctly classified :  065.Slaty_backed_Gull 42
# accuracy for  065.Slaty_backed_Gull is  0.84
# final_acc :  0.41891065833051366
# key found: 159.Black_and_white_Warbler
# 60
# correctly classified :  159.Black_and_white_Warbler 59
# accuracy for  159.Black_and_white_Warbler is  0.9833333333333333
# final_acc :  0.4238273249971803
# key found: 099.Ovenbird
# 60
# correctly classified :  099.Ovenbird 58
# accuracy for  099.Ovenbird is  0.9666666666666667
# final_acc :  0.42866065833051364
# key found: 170.Mourning_Warbler
# 60
# correctly classified :  170.Mourning_Warbler 48
# accuracy for  170.Mourning_Warbler is  0.8
# final_acc :  0.43266065833051365
# key found: 089.Hooded_Merganser
# 60
# correctly classified :  089.Hooded_Merganser 55
# accuracy for  089.Hooded_Merganser is  0.9166666666666666
# final_acc :  0.437243991663847
# key found: 128.Seaside_Sparrow
# 60
# correctly classified :  128.Seaside_Sparrow 55
# accuracy for  128.Seaside_Sparrow is  0.9166666666666666
# final_acc :  0.44182732499718036
# key found: 037.Acadian_Flycatcher
# 59
# correctly classified :  037.Acadian_Flycatcher 51
# accuracy for  037.Acadian_Flycatcher is  0.864406779661017
# final_acc :  0.4461493588954854
# key found: 032.Mangrove_Cuckoo
# 53
# correctly classified :  032.Mangrove_Cuckoo 46
# accuracy for  032.Mangrove_Cuckoo is  0.8679245283018868
# final_acc :  0.45048898153699485
# key found: 011.Rusty_Blackbird
# 60
# correctly classified :  011.Rusty_Blackbird 50
# accuracy for  011.Rusty_Blackbird is  0.8333333333333334
# final_acc :  0.45465564820366144
# key found: 195.Carolina_Wren
# 60
# correctly classified :  195.Carolina_Wren 58
# accuracy for  195.Carolina_Wren is  0.9666666666666667
# final_acc :  0.4594889815369948
# key found: 158.Bay_breasted_Warbler
# 60
# correctly classified :  158.Bay_breasted_Warbler 52
# accuracy for  158.Bay_breasted_Warbler is  0.8666666666666667
# final_acc :  0.4638223148703281
# key found: 078.Gray_Kingbird
# 59
# correctly classified :  078.Gray_Kingbird 58
# accuracy for  078.Gray_Kingbird is  0.9830508474576272
# final_acc :  0.46873756910761627
# key found: 143.Caspian_Tern
# 60
# correctly classified :  143.Caspian_Tern 51
# accuracy for  143.Caspian_Tern is  0.85
# final_acc :  0.47298756910761625
# key found: 186.Cedar_Waxwing
# 60
# correctly classified :  186.Cedar_Waxwing 58
# accuracy for  186.Cedar_Waxwing is  0.9666666666666667
# final_acc :  0.4778209024409496
# key found: 029.American_Crow
# 60
# correctly classified :  029.American_Crow 51
# accuracy for  029.American_Crow is  0.85
# final_acc :  0.4820709024409496
# key found: 093.Clark_Nutcracker
# 60
# correctly classified :  093.Clark_Nutcracker 57
# accuracy for  093.Clark_Nutcracker is  0.95
# final_acc :  0.48682090244094955
# key found: 179.Tennessee_Warbler
# 59
# correctly classified :  179.Tennessee_Warbler 38
# accuracy for  179.Tennessee_Warbler is  0.6440677966101694
# final_acc :  0.49004124142400046
# key found: 023.Brandt_Cormorant
# 59
# correctly classified :  023.Brandt_Cormorant 52
# accuracy for  023.Brandt_Cormorant is  0.8813559322033898
# final_acc :  0.4944480210850174
# key found: 165.Chestnut_sided_Warbler
# 60
# correctly classified :  165.Chestnut_sided_Warbler 55
# accuracy for  165.Chestnut_sided_Warbler is  0.9166666666666666
# final_acc :  0.4990313544183508
# key found: 076.Dark_eyed_Junco
# 60
# correctly classified :  076.Dark_eyed_Junco 59
# accuracy for  076.Dark_eyed_Junco is  0.9833333333333333
# final_acc :  0.5039480210850175
# key found: 101.White_Pelican
# 50
# correctly classified :  101.White_Pelican 50
# accuracy for  101.White_Pelican is  1.0
# final_acc :  0.5089480210850175
# key found: 049.Boat_tailed_Grackle
# 60
# correctly classified :  049.Boat_tailed_Grackle 37
# accuracy for  049.Boat_tailed_Grackle is  0.6166666666666667
# final_acc :  0.5120313544183507
# key found: 083.White_breasted_Kingfisher
# 60
# correctly classified :  083.White_breasted_Kingfisher 57
# accuracy for  083.White_breasted_Kingfisher is  0.95
# final_acc :  0.5167813544183507
# key found: 038.Great_Crested_Flycatcher
# 60
# correctly classified :  038.Great_Crested_Flycatcher 58
# accuracy for  038.Great_Crested_Flycatcher is  0.9666666666666667
# final_acc :  0.5216146877516841
# key found: 162.Canada_Warbler
# 60
# correctly classified :  162.Canada_Warbler 55
# accuracy for  162.Canada_Warbler is  0.9166666666666666
# final_acc :  0.5261980210850175
# key found: 104.American_Pipit
# 60
# correctly classified :  104.American_Pipit 58
# accuracy for  104.American_Pipit is  0.9666666666666667
# final_acc :  0.5310313544183508
# key found: 131.Vesper_Sparrow
# 60
# correctly classified :  131.Vesper_Sparrow 59
# accuracy for  131.Vesper_Sparrow is  0.9833333333333333
# final_acc :  0.5359480210850175
# key found: 071.Long_tailed_Jaeger
# 60
# correctly classified :  071.Long_tailed_Jaeger 58
# accuracy for  071.Long_tailed_Jaeger is  0.9666666666666667
# final_acc :  0.5407813544183508
# key found: 045.Northern_Fulmar
# 60
# correctly classified :  045.Northern_Fulmar 58
# accuracy for  045.Northern_Fulmar is  0.9666666666666667
# final_acc :  0.5456146877516841
# key found: 010.Red_winged_Blackbird
# 60
# correctly classified :  010.Red_winged_Blackbird 56
# accuracy for  010.Red_winged_Blackbird is  0.9333333333333333
# final_acc :  0.5502813544183508
# key found: 021.Eastern_Towhee
# 60
# correctly classified :  021.Eastern_Towhee 53
# accuracy for  021.Eastern_Towhee is  0.8833333333333333
# final_acc :  0.5546980210850175
# key found: 066.Western_Gull
# 60
# correctly classified :  066.Western_Gull 56
# accuracy for  066.Western_Gull is  0.9333333333333333
# final_acc :  0.5593646877516842
# key found: 103.Sayornis
# 60
# correctly classified :  103.Sayornis 56
# accuracy for  103.Sayornis is  0.9333333333333333
# final_acc :  0.564031354418351
# key found: 172.Nashville_Warbler
# 60
# correctly classified :  172.Nashville_Warbler 59
# accuracy for  172.Nashville_Warbler is  0.9833333333333333
# final_acc :  0.5689480210850175
# key found: 008.Rhinoceros_Auklet
# 48
# correctly classified :  008.Rhinoceros_Auklet 44
# accuracy for  008.Rhinoceros_Auklet is  0.9166666666666666
# final_acc :  0.5735313544183509
# key found: 014.Indigo_Bunting
# 60
# correctly classified :  014.Indigo_Bunting 59
# accuracy for  014.Indigo_Bunting is  0.9833333333333333
# final_acc :  0.5784480210850176
# key found: 091.Mockingbird
# 60
# correctly classified :  091.Mockingbird 52
# accuracy for  091.Mockingbird is  0.8666666666666667
# final_acc :  0.5827813544183509
# key found: 130.Tree_Sparrow
# 60
# correctly classified :  130.Tree_Sparrow 48
# accuracy for  130.Tree_Sparrow is  0.8
# final_acc :  0.5867813544183509
# key found: 050.Eared_Grebe
# 60
# correctly classified :  050.Eared_Grebe 60
# accuracy for  050.Eared_Grebe is  1.0
# final_acc :  0.5917813544183509
# key found: 163.Cape_May_Warbler
# 60
# correctly classified :  163.Cape_May_Warbler 58
# accuracy for  163.Cape_May_Warbler is  0.9666666666666667
# final_acc :  0.5966146877516842
# key found: 007.Parakeet_Auklet
# 53
# correctly classified :  007.Parakeet_Auklet 53
# accuracy for  007.Parakeet_Auklet is  1.0
# final_acc :  0.6016146877516843
# key found: 121.Grasshopper_Sparrow
# 60
# correctly classified :  121.Grasshopper_Sparrow 58
# accuracy for  121.Grasshopper_Sparrow is  0.9666666666666667
# final_acc :  0.6064480210850176
# key found: 140.Summer_Tanager
# 60
# correctly classified :  140.Summer_Tanager 58
# accuracy for  140.Summer_Tanager is  0.9666666666666667
# final_acc :  0.611281354418351
# key found: 005.Crested_Auklet
# 44
# correctly classified :  005.Crested_Auklet 44
# accuracy for  005.Crested_Auklet is  1.0
# final_acc :  0.616281354418351
# key found: 123.Henslow_Sparrow
# 60
# correctly classified :  123.Henslow_Sparrow 38
# accuracy for  123.Henslow_Sparrow is  0.6333333333333333
# final_acc :  0.6194480210850176
# key found: 171.Myrtle_Warbler
# 60
# correctly classified :  171.Myrtle_Warbler 58
# accuracy for  171.Myrtle_Warbler is  0.9666666666666667
# final_acc :  0.624281354418351
# key found: 197.Marsh_Wren
# 60
# correctly classified :  197.Marsh_Wren 38
# accuracy for  197.Marsh_Wren is  0.6333333333333333
# final_acc :  0.6274480210850176
# key found: 184.Louisiana_Waterthrush
# 60
# correctly classified :  184.Louisiana_Waterthrush 59
# accuracy for  184.Louisiana_Waterthrush is  0.9833333333333333
# final_acc :  0.6323646877516843
# key found: 105.Whip_poor_Will
# 49
# correctly classified :  105.Whip_poor_Will 36
# accuracy for  105.Whip_poor_Will is  0.7346938775510204
# final_acc :  0.6360381571394395
# key found: 126.Nelson_Sharp_tailed_Sparrow
# 59
# correctly classified :  126.Nelson_Sharp_tailed_Sparrow 56
# accuracy for  126.Nelson_Sharp_tailed_Sparrow is  0.9491525423728814
# final_acc :  0.6407839198513038
# key found: 081.Pied_Kingfisher
# 60
# correctly classified :  081.Pied_Kingfisher 58
# accuracy for  081.Pied_Kingfisher is  0.9666666666666667
# final_acc :  0.6456172531846371
# key found: 006.Least_Auklet
# 41
# correctly classified :  006.Least_Auklet 40
# accuracy for  006.Least_Auklet is  0.975609756097561
# final_acc :  0.650495301965125
# key found: 111.Loggerhead_Shrike
# 60
# correctly classified :  111.Loggerhead_Shrike 59
# accuracy for  111.Loggerhead_Shrike is  0.9833333333333333
# final_acc :  0.6554119686317915
# key found: 118.House_Sparrow
# 60
# correctly classified :  118.House_Sparrow 50
# accuracy for  118.House_Sparrow is  0.8333333333333334
# final_acc :  0.6595786352984583
# key found: 193.Bewick_Wren
# 60
# correctly classified :  193.Bewick_Wren 54
# accuracy for  193.Bewick_Wren is  0.9
# final_acc :  0.6640786352984582
# key found: 084.Red_legged_Kittiwake
# 53
# correctly classified :  084.Red_legged_Kittiwake 53
# accuracy for  084.Red_legged_Kittiwake is  1.0
# final_acc :  0.6690786352984582
# key found: 149.Brown_Thrasher
# 59
# correctly classified :  149.Brown_Thrasher 54
# accuracy for  149.Brown_Thrasher is  0.9152542372881356
# final_acc :  0.673654906484899
# key found: 003.Sooty_Albatross
# 58
# correctly classified :  003.Sooty_Albatross 57
# accuracy for  003.Sooty_Albatross is  0.9827586206896551
# final_acc :  0.6785686995883472
# key found: 080.Green_Kingfisher
# 60
# correctly classified :  080.Green_Kingfisher 54
# accuracy for  080.Green_Kingfisher is  0.9
# final_acc :  0.6830686995883473
# key found: 092.Nighthawk
# 60
# correctly classified :  092.Nighthawk 59
# accuracy for  092.Nighthawk is  0.9833333333333333
# final_acc :  0.6879853662550138
# key found: 019.Gray_Catbird
# 59
# correctly classified :  019.Gray_Catbird 52
# accuracy for  019.Gray_Catbird is  0.8813559322033898
# final_acc :  0.6923921459160307
# key found: 187.American_Three_toed_Woodpecker
# 50
# correctly classified :  187.American_Three_toed_Woodpecker 45
# accuracy for  187.American_Three_toed_Woodpecker is  0.9
# final_acc :  0.6968921459160308
# key found: 138.Tree_Swallow
# 60
# correctly classified :  138.Tree_Swallow 52
# accuracy for  138.Tree_Swallow is  0.8666666666666667
# final_acc :  0.7012254792493642
# key found: 087.Mallard
# 60
# correctly classified :  087.Mallard 47
# accuracy for  087.Mallard is  0.7833333333333333
# final_acc :  0.7051421459160307
# key found: 134.Cape_Glossy_Starling
# 60
# correctly classified :  134.Cape_Glossy_Starling 59
# accuracy for  134.Cape_Glossy_Starling is  0.9833333333333333
# final_acc :  0.7100588125826974
# key found: 152.Blue_headed_Vireo
# 60
# correctly classified :  152.Blue_headed_Vireo 57
# accuracy for  152.Blue_headed_Vireo is  0.95
# final_acc :  0.7148088125826974
# key found: 167.Hooded_Warbler
# 60
# correctly classified :  167.Hooded_Warbler 55
# accuracy for  167.Hooded_Warbler is  0.9166666666666666
# final_acc :  0.7193921459160306
# key found: 020.Yellow_breasted_Chat
# 59
# correctly classified :  020.Yellow_breasted_Chat 59
# accuracy for  020.Yellow_breasted_Chat is  1.0
# final_acc :  0.7243921459160306
# key found: 024.Red_faced_Cormorant
# 52
# correctly classified :  024.Red_faced_Cormorant 49
# accuracy for  024.Red_faced_Cormorant is  0.9423076923076923
# final_acc :  0.729103684377569
# key found: 124.Le_Conte_Sparrow
# 59
# correctly classified :  124.Le_Conte_Sparrow 57
# accuracy for  124.Le_Conte_Sparrow is  0.9661016949152542
# final_acc :  0.7339341928521453
# key found: 060.Glaucous_winged_Gull
# 59
# correctly classified :  060.Glaucous_winged_Gull 58
# accuracy for  060.Glaucous_winged_Gull is  0.9830508474576272
# final_acc :  0.7388494470894336
# key found: 100.Brown_Pelican
# 60
# correctly classified :  100.Brown_Pelican 60
# accuracy for  100.Brown_Pelican is  1.0
# final_acc :  0.7438494470894335
# key found: 054.Blue_Grosbeak
# 60
# correctly classified :  054.Blue_Grosbeak 58
# accuracy for  054.Blue_Grosbeak is  0.9666666666666667
# final_acc :  0.7486827804227668
# key found: 042.Vermilion_Flycatcher
# 60
# correctly classified :  042.Vermilion_Flycatcher 53
# accuracy for  042.Vermilion_Flycatcher is  0.8833333333333333
# final_acc :  0.7530994470894334
# key found: 139.Scarlet_Tanager
# 60
# correctly classified :  139.Scarlet_Tanager 59
# accuracy for  139.Scarlet_Tanager is  0.9833333333333333
# final_acc :  0.7580161137561001
# key found: 142.Black_Tern
# 60
# correctly classified :  142.Black_Tern 48
# accuracy for  142.Black_Tern is  0.8
# final_acc :  0.7620161137561001
# key found: 155.Warbling_Vireo
# 60
# correctly classified :  155.Warbling_Vireo 55
# accuracy for  155.Warbling_Vireo is  0.9166666666666666
# final_acc :  0.7665994470894334
# key found: 098.Scott_Oriole
# 60
# correctly classified :  098.Scott_Oriole 55
# accuracy for  098.Scott_Oriole is  0.9166666666666666
# final_acc :  0.7711827804227667
# key found: 106.Horned_Puffin
# 60
# correctly classified :  106.Horned_Puffin 60
# accuracy for  106.Horned_Puffin is  1.0
# final_acc :  0.7761827804227667
# key found: 196.House_Wren
# 59
# correctly classified :  196.House_Wren 54
# accuracy for  196.House_Wren is  0.9152542372881356
# final_acc :  0.7807590516092074
# key found: 115.Brewer_Sparrow
# 59
# correctly classified :  115.Brewer_Sparrow 56
# accuracy for  115.Brewer_Sparrow is  0.9491525423728814
# final_acc :  0.7855048143210718
# key found: 033.Yellow_billed_Cuckoo
# 59
# correctly classified :  033.Yellow_billed_Cuckoo 58
# accuracy for  033.Yellow_billed_Cuckoo is  0.9830508474576272
# final_acc :  0.7904200685583599
# key found: 137.Cliff_Swallow
# 60
# correctly classified :  137.Cliff_Swallow 51
# accuracy for  137.Cliff_Swallow is  0.85
# final_acc :  0.7946700685583599
# key found: 070.Green_Violetear
# 60
# correctly classified :  070.Green_Violetear 60
# accuracy for  070.Green_Violetear is  1.0
# final_acc :  0.7996700685583599
# key found: 012.Yellow_headed_Blackbird
# 56
# correctly classified :  012.Yellow_headed_Blackbird 53
# accuracy for  012.Yellow_headed_Blackbird is  0.9464285714285714
# final_acc :  0.8044022114155028
# key found: 047.American_Goldfinch
# 60
# correctly classified :  047.American_Goldfinch 59
# accuracy for  047.American_Goldfinch is  0.9833333333333333
# final_acc :  0.8093188780821694
# key found: 122.Harris_Sparrow
# 60
# correctly classified :  122.Harris_Sparrow 44
# accuracy for  122.Harris_Sparrow is  0.7333333333333333
# final_acc :  0.812985544748836
# key found: 018.Spotted_Catbird
# 45
# correctly classified :  018.Spotted_Catbird 44
# accuracy for  018.Spotted_Catbird is  0.9777777777777777
# final_acc :  0.8178744336377249
# key found: 144.Common_Tern
# 60
# correctly classified :  144.Common_Tern 58
# accuracy for  144.Common_Tern is  0.9666666666666667
# final_acc :  0.8227077669710583
# key found: 057.Rose_breasted_Grosbeak
# 60
# correctly classified :  057.Rose_breasted_Grosbeak 58
# accuracy for  057.Rose_breasted_Grosbeak is  0.9666666666666667
# final_acc :  0.8275411003043917
# key found: 035.Purple_Finch
# 60
# correctly classified :  035.Purple_Finch 58
# accuracy for  035.Purple_Finch is  0.9666666666666667
# final_acc :  0.832374433637725
# key found: 046.Gadwall
# 60
# correctly classified :  046.Gadwall 58
# accuracy for  046.Gadwall is  0.9666666666666667
# final_acc :  0.8372077669710584
# key found: 133.White_throated_Sparrow
# 60
# correctly classified :  133.White_throated_Sparrow 54
# accuracy for  133.White_throated_Sparrow is  0.9
# final_acc :  0.8417077669710583
# key found: 153.Philadelphia_Vireo
# 59
# correctly classified :  153.Philadelphia_Vireo 56
# accuracy for  153.Philadelphia_Vireo is  0.9491525423728814
# final_acc :  0.8464535296829228
# key found: 146.Forsters_Tern
# 60
# correctly classified :  146.Forsters_Tern 55
# accuracy for  146.Forsters_Tern is  0.9166666666666666
# final_acc :  0.851036863016256
# key found: 069.Rufous_Hummingbird
# 60
# correctly classified :  069.Rufous_Hummingbird 53
# accuracy for  069.Rufous_Hummingbird is  0.8833333333333333
# final_acc :  0.8554535296829227
# key found: 085.Horned_Lark
# 60
# correctly classified :  085.Horned_Lark 60
# accuracy for  085.Horned_Lark is  1.0
# final_acc :  0.8604535296829227
# key found: 199.Winter_Wren
# 60
# correctly classified :  199.Winter_Wren 58
# accuracy for  199.Winter_Wren is  0.9666666666666667
# final_acc :  0.865286863016256
# key found: 002.Laysan_Albatross
# 60
# correctly classified :  002.Laysan_Albatross 54
# accuracy for  002.Laysan_Albatross is  0.9
# final_acc :  0.869786863016256
# key found: 198.Rock_Wren
# 60
# correctly classified :  198.Rock_Wren 56
# accuracy for  198.Rock_Wren is  0.9333333333333333
# final_acc :  0.8744535296829227
# key found: 181.Worm_eating_Warbler
# 59
# correctly classified :  181.Worm_eating_Warbler 57
# accuracy for  181.Worm_eating_Warbler is  0.9661016949152542
# final_acc :  0.879284038157499
# key found: 113.Baird_Sparrow
# 50
# correctly classified :  113.Baird_Sparrow 50
# accuracy for  113.Baird_Sparrow is  1.0
# final_acc :  0.884284038157499
# key found: 173.Orange_crowned_Warbler
# 60
# correctly classified :  173.Orange_crowned_Warbler 58
# accuracy for  173.Orange_crowned_Warbler is  0.9666666666666667
# final_acc :  0.8891173714908324
# key found: 074.Florida_Jay
# 60
# correctly classified :  074.Florida_Jay 60
# accuracy for  074.Florida_Jay is  1.0
# final_acc :  0.8941173714908324
# key found: 175.Pine_Warbler
# 60
# correctly classified :  175.Pine_Warbler 59
# accuracy for  175.Pine_Warbler is  0.9833333333333333
# final_acc :  0.8990340381574989
# key found: 127.Savannah_Sparrow
# 60
# correctly classified :  127.Savannah_Sparrow 54
# accuracy for  127.Savannah_Sparrow is  0.9
# final_acc :  0.903534038157499
# key found: 116.Chipping_Sparrow
# 60
# correctly classified :  116.Chipping_Sparrow 57
# accuracy for  116.Chipping_Sparrow is  0.95
# final_acc :  0.9082840381574989
# key found: 189.Red_bellied_Woodpecker
# 60
# correctly classified :  189.Red_bellied_Woodpecker 60
# accuracy for  189.Red_bellied_Woodpecker is  1.0
# final_acc :  0.9132840381574989
# key found: 132.White_crowned_Sparrow
# 60
# correctly classified :  132.White_crowned_Sparrow 57
# accuracy for  132.White_crowned_Sparrow is  0.95
# final_acc :  0.9180340381574988
# key found: 169.Magnolia_Warbler
# 59
# correctly classified :  169.Magnolia_Warbler 56
# accuracy for  169.Magnolia_Warbler is  0.9491525423728814
# final_acc :  0.9227798008693633
