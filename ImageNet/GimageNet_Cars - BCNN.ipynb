# %%
import ast
a_file = open("Filt_Resp_Cars_Crop.txt", "r")


string_without_line_breaks = ""
for line in a_file:
    stripped_line = line.rstrip()
    string_without_line_breaks += stripped_line

import re
dict_Classes = ast.literal_eval(re.search('({.+})', string_without_line_breaks).group(0))

# for key, value in dict_Classes.items():
#     print ('classId', key)
#     print ('value', value)
a_file.close()
print(len(dict_Classes))
# Out:
# 196

# %%
import collections
od = collections.OrderedDict(sorted(dict_Classes.items()))
list_b=[]
for item in od:
    # print(item)
    list_b.append(item)

# %%
import cv2
import os
from shutil import copyfile
from pathlib import Path


folder = "Cars_classes_top/"

last_fileName=""
#images = []
listBirds = []
for filename in os.listdir(folder):
    # for img in os.listdir(folder+filename):
    listBirds.append(filename)
    if filename not in list_b:
        print(filename)
# imagesFileNames.sort()
print(len(listBirds))

# %% [markdown]
# # Computing the similarity between classes; pearson or cosine distances might be used

# %%
from scipy.spatial import distance
import collections


import numpy as np
from keras import backend as K
import os
import scipy as sp

import matplotlib.pyplot as plt
import networkx as nx

# G = nx.Graph()
G = nx.Graph()
# draw_graph(G)
# thresh = 0.5
thresh = 1
# print(' length dict', len(dict_Classes))
class_index =0
adjacency_Matrix = []
for key, value in dict_Classes.items():
    list_of_close_nodes = []
    list_of_close_nodes_names = []
    list_of_close_nodes_sim = []
    simil_dict = {}
    listBirdsLabels =[]

#         list_of_close_nodes_sim.append(100)
    start_trans_sim = 100 #big value
#         print ('key: ',key )
    class_index +=1
    weights_dic_Conv2_13= {}
    weights_dic_Conv2_13.update(value)
    weights_dic_Conv2_13 = sorted (weights_dic_Conv2_13.items ())
    odList = []
    od = collections.OrderedDict(weights_dic_Conv2_13)
    for i in range(len(od)):
        if weights_dic_Conv2_13[i][1][0] >0:
            odList.append(weights_dic_Conv2_13[i][1][0]) 
        else:
#             odList.append(0)
            odList.append(weights_dic_Conv2_13[i][1][0]) 
    arry_by_object =[]
#     print("Top similar birds to", key)

    for key2, value2 in dict_Classes.items():
        if (key != key2 ):
            weights_dic_Conv2_13_2= {}
    #         print ('Key:', key)
    #         if key != key2 : #classs_Id 
            weights_dic_Conv2_13_2.update(value2)
            weights_dic_Conv2_13_2 = sorted (weights_dic_Conv2_13_2.items ())
    #         sorted (weights_dic_Conv2_13, key=lambda kv: kv[1], reverse=True)
    #         sorted (weights_dic_Conv2_13_2, key=lambda kv: kv[1], reverse=True)

            totalProb = 0
            totalProb2 = 0
            totalSimilarity = 0

            for i in range(len(weights_dic_Conv2_13)):
            #     print('value:', weights_dic_Conv2_13_Umb1[i][0])
                if weights_dic_Conv2_13[i][1][0] > 0:
                    totalProb =  totalProb + weights_dic_Conv2_13[i][1][0]
    #             print('tot prob1', totalProb)
#                 else:
#                     weights_dic_Conv2_13[i][1][0] = 0

            for i in range(len(weights_dic_Conv2_13_2)):
            #     print('value:', weights_dic_Conv2_13_Umb1[i][0])
                if weights_dic_Conv2_13_2[i][1][0] > 0:
                    totalProb2 =  totalProb2 + weights_dic_Conv2_13_2[i][1][0]
    #         print('total prob2', totalProb2)
#                 else:
#                     weights_dic_Conv2_13[i][1][0] = 0            
            od2 = collections.OrderedDict(weights_dic_Conv2_13_2)
            # ### Product
            # for i in range(len(od)):
            #     totalSimilarity += od[i][0] * od2[i][0]
            #### Distance
            od2List = []
            for i in range(len(od)):
                if weights_dic_Conv2_13_2[i][1][0] >0:
                    od2List.append(weights_dic_Conv2_13_2[i][1][0])
                else:
#                     od2List.append(0)
                    od2List.append(weights_dic_Conv2_13_2[i][1][0])
#             from scipy.spatial.distance import euclidean
#             if totalProb>0 and totalProb2>0:
#                 newList1 = [x / totalProb for x in odList]
#                 newList2 = [x / totalProb2 for x in od2List]
#                 totalSimilarity = euclidean(newList1, newList2)
                
#             totalSimilarity = distance.cosine(odList, od2List) # One edge value
            if totalProb>0 and totalProb2>0:
#                 for i in range(len(od)):
#                     totalSimilarity += abs((odList[i]/totalProb) - (od2List[i]/totalProb2))
    ################## pearson correlation
                from scipy.stats import pearsonr
                totalSimilarity, _ = pearsonr(odList, od2List)
    #                 print('Pearsons correlation: %.3f' % corr)
    ################# perason correlation
            if(totalSimilarity <= thresh):
#                     print('total sim between '+ key+ 'and '+ key2+ ':', totalSimilarity)                
                G.add_edge(key, key2, weight=round(totalSimilarity, 6), name = 'weight', title=round(totalSimilarity, 6))
#                     list_of_close_nodes.append(0,key2)
#                     list_of_close_nodes_sim.append(0,totalSimilarity)
                if weights_dic_Conv2_13_2[0][1][0] > 0:
                    simil_dict[key2]= totalSimilarity 
#     simil_dict = sorted(simil_dict.items(), key=lambda item: item[1])
    simil_dict = sorted(simil_dict.items(), key=lambda item: item[1], reverse=True)

#         dogs_file = open("list_imgnet_labels.txt", "r")
    if len(simil_dict)>0 :
        print("Top similar cars to", key)
        for k in range (3):            
#                 print(k+1 , "- " )
            print('sim value %.3f' % simil_dict[k][1])
            print( k+1 , "- ", simil_dict[k][0])
#                 print(k+1 , "- " ,simil_dict[k][1])
#         with open("Birds_Synset.txt", 'r') as read_obj:
#             for line in listBirds:
#                 print("line: ", line)
#                 print("dict", simil_dict[i][0])
#                 if(simil_dict[i][0] in line):
# #                         print(line.partition(stringToSplitAfter)[2])
#                     listBirdsLabels.append(line)
#                     break;
#     for i in range(len(listBirdsLabels)):
#          print( i+1, ". ", listBirdsLabels[i])
        print("---------------------------------------------")
# Out:
# Top similar cars to AM General Hummer SUV 2000
# sim value 0.312
# 1 -  Audi S4 Sedan 2012
# sim value 0.230
# 2 -  Volvo C30 Hatchback 2012
# sim value 0.193
# 3 -  Jeep Compass SUV 2012
# ---------------------------------------------
# Top similar cars to Acura Integra Type R 2001
# sim value 0.312
# 1 -  Chevrolet HHR SS 2010
# sim value 0.267
# 2 -  Dodge Dakota Crew Cab 2010
# sim value 0.244
# 3 -  BMW X3 SUV 2012
# ---------------------------------------------
# Top similar cars to Acura RL Sedan 2012
# sim value 0.346
# 1 -  Chevrolet Express Van 2007
# sim value 0.266
# 2 -  Acura ZDX Hatchback 2012
# sim value 0.266
# 3 -  Jeep Patriot SUV 2012
# ---------------------------------------------
# Top similar cars to Acura TL Sedan 2012
# sim value 0.288
# 1 -  Mitsubishi Lancer Sedan 2012
# sim value 0.267
# 2 -  Honda Odyssey Minivan 2012
# sim value 0.235
# 3 -  Lincoln Town Car Sedan 2011
# ---------------------------------------------
# Top similar cars to Acura TL Type-S 2008
# sim value 0.259
# 1 -  Acura RL Sedan 2012
# sim value 0.246
# 2 -  BMW 1 Series Coupe 2012
# sim value 0.240
# 3 -  Ram C/V Cargo Van Minivan 2012
# ---------------------------------------------
# Top similar cars to Acura TSX Sedan 2012
# sim value 0.384
# 1 -  Lamborghini Reventon Coupe 2008
# sim value 0.240
# 2 -  Suzuki Aerio Sedan 2007
# sim value 0.213
# 3 -  BMW 3 Series Sedan 2012
# ---------------------------------------------
# Top similar cars to Acura ZDX Hatchback 2012
# sim value 0.283
# 1 -  BMW X5 SUV 2007
# sim value 0.272
# 2 -  Mercedes-Benz Sprinter Van 2012
# sim value 0.266
# 3 -  Acura RL Sedan 2012
# ---------------------------------------------
# Top similar cars to Aston Martin V8 Vantage Convertible 2012
# sim value 0.351
# 1 -  Mercedes-Benz SL-Class Coupe 2009
# sim value 0.241
# 2 -  Dodge Durango SUV 2012
# sim value 0.211
# 3 -  Chrysler 300 SRT-8 2010
# ---------------------------------------------
# Top similar cars to Aston Martin V8 Vantage Coupe 2012
# sim value 0.299
# 1 -  Dodge Ram Pickup 3500 Quad Cab 2009
# sim value 0.275
# 2 -  Chrysler 300 SRT-8 2010
# sim value 0.263
# 3 -  Mercedes-Benz SL-Class Coupe 2009
# ---------------------------------------------
# Top similar cars to Aston Martin Virage Convertible 2012
# sim value 0.294
# 1 -  Mercedes-Benz SL-Class Coupe 2009
# sim value 0.243
# 2 -  Hyundai Tucson SUV 2012
# sim value 0.209
# 3 -  Chrysler 300 SRT-8 2010
# ---------------------------------------------
# Top similar cars to Aston Martin Virage Coupe 2012
# sim value 0.341
# 1 -  BMW 3 Series Sedan 2012
# sim value 0.141
# 2 -  Buick Regal GS 2012
# sim value 0.132
# 3 -  Hyundai Santa Fe SUV 2012
# ---------------------------------------------
# Top similar cars to Audi 100 Sedan 1994
# sim value 0.272
# 1 -  BMW 1 Series Coupe 2012
# sim value 0.256
# 2 -  Lamborghini Reventon Coupe 2008
# sim value 0.228
# 3 -  Dodge Challenger SRT8 2011
# ---------------------------------------------
# Top similar cars to Audi 100 Wagon 1994
# sim value 0.313
# 1 -  Chevrolet Tahoe Hybrid SUV 2012
# sim value 0.303
# 2 -  Audi V8 Sedan 1994
# sim value 0.288
# 3 -  Bentley Continental GT Coupe 2012
# ---------------------------------------------
# Top similar cars to Audi A5 Coupe 2012
# sim value 0.211
# 1 -  Audi V8 Sedan 1994
# sim value 0.209
# 2 -  Dodge Caliber Wagon 2007
# sim value 0.207
# 3 -  Audi S5 Convertible 2012
# ---------------------------------------------
# Top similar cars to Audi R8 Coupe 2012
# sim value 0.229
# 1 -  Audi S5 Coupe 2012
# sim value 0.226
# 2 -  Rolls-Royce Phantom Drophead Coupe Convertible 2012
# sim value 0.182
# 3 -  Ford Fiesta Sedan 2012
# ---------------------------------------------
# Top similar cars to Audi RS 4 Convertible 2008
# sim value 0.356
# 1 -  Cadillac CTS-V Sedan 2012
# sim value 0.313
# 2 -  Audi S4 Sedan 2007
# sim value 0.288
# 3 -  Volvo C30 Hatchback 2012
# ---------------------------------------------
# Top similar cars to Audi S4 Sedan 2007
# sim value 0.313
# 1 -  Audi RS 4 Convertible 2008
# sim value 0.257
# 2 -  Audi 100 Wagon 1994
# sim value 0.246
# 3 -  Lincoln Town Car Sedan 2011
# ---------------------------------------------
# Top similar cars to Audi S4 Sedan 2012
# sim value 0.234
# 1 -  Ford Expedition EL SUV 2009
# sim value 0.221
# 2 -  Dodge Challenger SRT8 2011
# sim value 0.218
# 3 -  Audi RS 4 Convertible 2008
# ---------------------------------------------
# Top similar cars to Audi S5 Convertible 2012
# sim value 0.374
# 1 -  Audi S5 Coupe 2012
# sim value 0.304
# 2 -  Audi V8 Sedan 1994
# sim value 0.241
# 3 -  BMW 3 Series Sedan 2012
# ---------------------------------------------
# Top similar cars to Audi S5 Coupe 2012
# sim value 0.374
# 1 -  Audi S5 Convertible 2012
# sim value 0.351
# 2 -  Rolls-Royce Phantom Drophead Coupe Convertible 2012
# sim value 0.305
# 3 -  Porsche Panamera Sedan 2012
# ---------------------------------------------
# Top similar cars to Audi S6 Sedan 2011
# sim value 0.409
# 1 -  Audi TT RS Coupe 2012
# sim value 0.380
# 2 -  Mercedes-Benz S-Class Sedan 2012
# sim value 0.332
# 3 -  Chrysler 300 SRT-8 2010
# ---------------------------------------------
# Top similar cars to Audi TT Hatchback 2011
# sim value 0.305
# 1 -  Buick Regal GS 2012
# sim value 0.288
# 2 -  Toyota 4Runner SUV 2012
# sim value 0.239
# 3 -  Audi S5 Coupe 2012
# ---------------------------------------------
# Top similar cars to Audi TT RS Coupe 2012
# sim value 0.216
# 1 -  Chrysler Crossfire Convertible 2008
# sim value 0.203
# 2 -  Hyundai Santa Fe SUV 2012
# sim value 0.203
# 3 -  Acura Integra Type R 2001
# ---------------------------------------------
# Top similar cars to Audi TTS Coupe 2012
# sim value 0.326
# 1 -  Chevrolet Tahoe Hybrid SUV 2012
# sim value 0.288
# 2 -  Mitsubishi Lancer Sedan 2012
# sim value 0.279
# 3 -  Hyundai Santa Fe SUV 2012
# ---------------------------------------------
# Top similar cars to Audi V8 Sedan 1994
# sim value 0.323
# 1 -  BMW M5 Sedan 2010
# sim value 0.321
# 2 -  Lamborghini Diablo Coupe 2001
# sim value 0.304
# 3 -  Audi S5 Convertible 2012
# ---------------------------------------------
# Top similar cars to Bentley Arnage Sedan 2009
# sim value 0.257
# 1 -  Buick Enclave SUV 2012
# sim value 0.173
# 2 -  Nissan Juke Hatchback 2012
# sim value 0.168
# 3 -  Maybach Landaulet Convertible 2012
# ---------------------------------------------
# Top similar cars to Bentley Continental Flying Spur Sedan 2007
# sim value 0.260
# 1 -  Bentley Continental GT Coupe 2007
# sim value 0.255
# 2 -  Mercedes-Benz C-Class Sedan 2012
# sim value 0.242
# 3 -  Audi RS 4 Convertible 2008
# ---------------------------------------------
# Top similar cars to Bentley Continental GT Coupe 2007
# sim value 0.399
# 1 -  Ford E-Series Wagon Van 2012
# sim value 0.346
# 2 -  Hyundai Veracruz SUV 2012
# sim value 0.310
# 3 -  Bentley Continental GT Coupe 2012
# ---------------------------------------------
# Top similar cars to Bentley Continental GT Coupe 2012
# sim value 0.310
# 1 -  Bentley Continental GT Coupe 2007
# sim value 0.289
# 2 -  Lamborghini Diablo Coupe 2001
# sim value 0.288
# 3 -  Audi 100 Wagon 1994
# ---------------------------------------------
# Top similar cars to Bentley Continental Supersports Conv. Convertible 2012
# sim value 0.210
# 1 -  Volkswagen Golf Hatchback 2012
# sim value 0.205
# 2 -  Chevrolet Express Cargo Van 2007
# sim value 0.202
# 3 -  Nissan Juke Hatchback 2012
# ---------------------------------------------
# Top similar cars to Bentley Mulsanne Sedan 2011
# sim value 0.241
# 1 -  Maybach Landaulet Convertible 2012
# sim value 0.237
# 2 -  Bentley Continental GT Coupe 2007
# sim value 0.207
# 3 -  Buick Verano Sedan 2012
# ---------------------------------------------
# Top similar cars to BMW 1 Series Convertible 2012
# sim value 0.261
# 1 -  Porsche Panamera Sedan 2012
# sim value 0.219
# 2 -  Mercedes-Benz SL-Class Coupe 2009
# sim value 0.215
# 3 -  Dodge Caravan Minivan 1997
# ---------------------------------------------
# Top similar cars to BMW 1 Series Coupe 2012
# sim value 0.304
# 1 -  BMW X5 SUV 2007
# sim value 0.270
# 2 -  BMW Z4 Convertible 2012
# sim value 0.246
# 3 -  Acura TL Type-S 2008
# ---------------------------------------------
# Top similar cars to BMW 3 Series Sedan 2012
# sim value 0.241
# 1 -  Audi S5 Convertible 2012
# sim value 0.213
# 2 -  Acura TSX Sedan 2012
# sim value 0.212
# 3 -  Audi S5 Coupe 2012
# ---------------------------------------------
# Top similar cars to BMW 3 Series Wagon 2012
# sim value 0.243
# 1 -  BMW M6 Convertible 2010
# sim value 0.168
# 2 -  BMW 6 Series Convertible 2007
# sim value 0.136
# 3 -  Acura TL Type-S 2008
# ---------------------------------------------
# Top similar cars to BMW 6 Series Convertible 2007
# sim value 0.270
# 1 -  Jeep Compass SUV 2012
# sim value 0.258
# 2 -  Honda Accord Sedan 2012
# sim value 0.234
# 3 -  Volvo C30 Hatchback 2012
# ---------------------------------------------
# Top similar cars to BMW ActiveHybrid 5 Sedan 2012
# sim value 0.267
# 1 -  Hyundai Elantra Sedan 2007
# sim value 0.247
# 2 -  Audi A5 Coupe 2012
# sim value 0.235
# 3 -  Fisker Karma Sedan 2012
# ---------------------------------------------
# Top similar cars to BMW M3 Coupe 2012
# sim value 0.327
# 1 -  Hyundai Elantra Sedan 2007
# sim value 0.316
# 2 -  Buick Rainier SUV 2007
# sim value 0.265
# 3 -  Honda Accord Sedan 2012
# ---------------------------------------------
# Top similar cars to BMW M5 Sedan 2010
# sim value 0.323
# 1 -  Audi V8 Sedan 1994
# sim value 0.263
# 2 -  Ford Ranger SuperCab 2011
# sim value 0.228
# 3 -  Jeep Grand Cherokee SUV 2012
# ---------------------------------------------
# Top similar cars to BMW M6 Convertible 2010
# sim value 0.234
# 1 -  BMW 1 Series Coupe 2012
# sim value 0.207
# 2 -  Mercedes-Benz Sprinter Van 2012
# sim value 0.202
# 3 -  Dodge Caravan Minivan 1997
# ---------------------------------------------
# Top similar cars to BMW X3 SUV 2012
# sim value 0.300
# 1 -  BMW X5 SUV 2007
# sim value 0.244
# 2 -  Acura Integra Type R 2001
# sim value 0.238
# 3 -  Chevrolet Tahoe Hybrid SUV 2012
# ---------------------------------------------
# Top similar cars to BMW X5 SUV 2007
# sim value 0.304
# 1 -  BMW 1 Series Coupe 2012
# sim value 0.300
# 2 -  BMW X3 SUV 2012
# sim value 0.283
# 3 -  Acura ZDX Hatchback 2012
# ---------------------------------------------
# Top similar cars to BMW X6 SUV 2012
# sim value 0.348
# 1 -  Jeep Liberty SUV 2012
# sim value 0.303
# 2 -  Toyota Sequoia SUV 2012
# sim value 0.272
# 3 -  Hyundai Azera Sedan 2012
# ---------------------------------------------
# Top similar cars to BMW Z4 Convertible 2012
# sim value 0.290
# 1 -  Fisker Karma Sedan 2012
# sim value 0.270
# 2 -  BMW 1 Series Coupe 2012
# sim value 0.232
# 3 -  BMW X5 SUV 2007
# ---------------------------------------------
# Top similar cars to Bugatti Veyron 16.4 Convertible 2009
# sim value 0.458
# 1 -  Bugatti Veyron 16.4 Coupe 2009
# sim value 0.305
# 2 -  Rolls-Royce Phantom Drophead Coupe Convertible 2012
# sim value 0.275
# 3 -  Volkswagen Golf Hatchback 2012
# ---------------------------------------------
# Top similar cars to Bugatti Veyron 16.4 Coupe 2009
# sim value 0.458
# 1 -  Bugatti Veyron 16.4 Convertible 2009
# sim value 0.277
# 2 -  Eagle Talon Hatchback 1998
# sim value 0.269
# 3 -  Volkswagen Golf Hatchback 2012
# ---------------------------------------------
# Top similar cars to Buick Enclave SUV 2012
# sim value 0.285
# 1 -  Mercedes-Benz SL-Class Coupe 2009
# sim value 0.263
# 2 -  BMW X6 SUV 2012
# sim value 0.257
# 3 -  Jeep Wrangler SUV 2012
# ---------------------------------------------
# Top similar cars to Buick Rainier SUV 2007
# sim value 0.354
# 1 -  Ford GT Coupe 2006
# sim value 0.353
# 2 -  Hyundai Elantra Sedan 2007
# sim value 0.316
# 3 -  BMW M3 Coupe 2012
# ---------------------------------------------
# Top similar cars to Buick Regal GS 2012
# sim value 0.302
# 1 -  Buick Verano Sedan 2012
# sim value 0.291
# 2 -  Suzuki SX4 Sedan 2012
# sim value 0.285
# 3 -  Mercedes-Benz S-Class Sedan 2012
# ---------------------------------------------
# Top similar cars to Buick Verano Sedan 2012
# sim value 0.302
# 1 -  Buick Regal GS 2012
# sim value 0.297
# 2 -  Chrysler Crossfire Convertible 2008
# sim value 0.266
# 3 -  Jeep Compass SUV 2012
# ---------------------------------------------
# Top similar cars to Cadillac CTS-V Sedan 2012
# sim value 0.356
# 1 -  Audi RS 4 Convertible 2008
# sim value 0.263
# 2 -  Chevrolet Corvette Ron Fellows Edition Z06 2007
# sim value 0.259
# 3 -  Cadillac SRX SUV 2012
# ---------------------------------------------
# Top similar cars to Cadillac Escalade EXT Crew Cab 2007
# sim value 0.286
# 1 -  Dodge Caliber Wagon 2007
# sim value 0.262
# 2 -  Cadillac SRX SUV 2012
# sim value 0.256
# 3 -  Ford Expedition EL SUV 2009
# ---------------------------------------------
# Top similar cars to Cadillac SRX SUV 2012
# sim value 0.262
# 1 -  Cadillac Escalade EXT Crew Cab 2007
# sim value 0.259
# 2 -  Cadillac CTS-V Sedan 2012
# sim value 0.247
# 3 -  Mercedes-Benz S-Class Sedan 2012
# ---------------------------------------------
# Top similar cars to Chevrolet Avalanche Crew Cab 2012
# sim value 0.315
# 1 -  Dodge Challenger SRT8 2011
# sim value 0.273
# 2 -  Jeep Wrangler SUV 2012
# sim value 0.267
# 3 -  Ford Focus Sedan 2007
# ---------------------------------------------
# Top similar cars to Chevrolet Camaro Convertible 2012
# sim value 0.310
# 1 -  Acura TSX Sedan 2012
# sim value 0.281
# 2 -  Ford Fiesta Sedan 2012
# sim value 0.281
# 3 -  Audi S5 Convertible 2012
# ---------------------------------------------
# Top similar cars to Chevrolet Cobalt SS 2010
# sim value 0.229
# 1 -  Fisker Karma Sedan 2012
# sim value 0.142
# 2 -  Porsche Panamera Sedan 2012
# sim value 0.133
# 3 -  Mercedes-Benz E-Class Sedan 2012
# ---------------------------------------------
# Top similar cars to Chevrolet Corvette Convertible 2012
# sim value 0.407
# 1 -  Suzuki Aerio Sedan 2007
# sim value 0.248
# 2 -  Mercedes-Benz Sprinter Van 2012
# sim value 0.226
# 3 -  Audi S5 Convertible 2012
# ---------------------------------------------
# Top similar cars to Chevrolet Corvette Ron Fellows Edition Z06 2007
# sim value 0.356
# 1 -  Fisker Karma Sedan 2012
# sim value 0.329
# 2 -  Hyundai Elantra Sedan 2007
# sim value 0.288
# 3 -  Mitsubishi Lancer Sedan 2012
# ---------------------------------------------
# Top similar cars to Chevrolet Corvette ZR1 2012
# sim value 0.330
# 1 -  Acura TL Type-S 2008
# sim value 0.283
# 2 -  Jeep Patriot SUV 2012
# sim value 0.224
# 3 -  Cadillac Escalade EXT Crew Cab 2007
# ---------------------------------------------
# Top similar cars to Chevrolet Express Cargo Van 2007
# sim value 0.357
# 1 -  Chevrolet TrailBlazer SS 2009
# sim value 0.332
# 2 -  Chevrolet HHR SS 2010
# sim value 0.268
# 3 -  Audi V8 Sedan 1994
# ---------------------------------------------
# Top similar cars to Chevrolet Express Van 2007
# sim value 0.346
# 1 -  Acura RL Sedan 2012
# sim value 0.245
# 2 -  Lincoln Town Car Sedan 2011
# sim value 0.226
# 3 -  Acura TL Sedan 2012
# ---------------------------------------------
# Top similar cars to Chevrolet HHR SS 2010
# sim value 0.365
# 1 -  GMC Savana Van 2012
# sim value 0.333
# 2 -  Toyota Sequoia SUV 2012
# sim value 0.332
# 3 -  Chevrolet Express Cargo Van 2007
# ---------------------------------------------
# Top similar cars to Chevrolet Impala Sedan 2007
# sim value 0.260
# 1 -  Hyundai Sonata Hybrid Sedan 2012
# sim value 0.190
# 2 -  Acura TL Type-S 2008
# sim value 0.168
# 3 -  smart fortwo Convertible 2012
# ---------------------------------------------
# Top similar cars to Chevrolet Malibu Hybrid Sedan 2010
# sim value 0.309
# 1 -  Audi 100 Wagon 1994
# sim value 0.306
# 2 -  Suzuki Aerio Sedan 2007
# sim value 0.292
# 3 -  Honda Accord Coupe 2012
# ---------------------------------------------
# Top similar cars to Chevrolet Malibu Sedan 2007
# sim value 0.262
# 1 -  Acura TL Type-S 2008
# sim value 0.233
# 2 -  Honda Odyssey Minivan 2012
# sim value 0.200
# 3 -  Dodge Challenger SRT8 2011
# ---------------------------------------------
# Top similar cars to Chevrolet Monte Carlo Coupe 2007
# sim value 0.201
# 1 -  BMW 3 Series Sedan 2012
# sim value 0.170
# 2 -  Suzuki SX4 Hatchback 2012
# sim value 0.164
# 3 -  Volvo XC90 SUV 2007
# ---------------------------------------------
# Top similar cars to Chevrolet Silverado 1500 Classic Extended Cab 2007
# sim value 0.246
# 1 -  GMC Acadia SUV 2012
# sim value 0.229
# 2 -  Buick Enclave SUV 2012
# sim value 0.225
# 3 -  Rolls-Royce Phantom Drophead Coupe Convertible 2012
# ---------------------------------------------
# Top similar cars to Chevrolet Silverado 1500 Extended Cab 2012
# sim value 0.320
# 1 -  Dodge Ram Pickup 3500 Quad Cab 2009
# sim value 0.175
# 2 -  Audi R8 Coupe 2012
# sim value 0.161
# 3 -  Toyota Sequoia SUV 2012
# ---------------------------------------------
# Top similar cars to Chevrolet Silverado 1500 Hybrid Crew Cab 2012
# sim value 0.294
# 1 -  Chevrolet HHR SS 2010
# sim value 0.259
# 2 -  Toyota Sequoia SUV 2012
# sim value 0.257
# 3 -  GMC Savana Van 2012
# ---------------------------------------------
# Top similar cars to Chevrolet Silverado 1500 Regular Cab 2012
# sim value 0.235
# 1 -  Jeep Liberty SUV 2012
# sim value 0.191
# 2 -  BMW Z4 Convertible 2012
# sim value 0.185
# 3 -  Isuzu Ascender SUV 2008
# ---------------------------------------------
# Top similar cars to Chevrolet Silverado 2500HD Regular Cab 2012
# sim value 0.265
# 1 -  Honda Accord Coupe 2012
# sim value 0.254
# 2 -  Ford Freestar Minivan 2007
# sim value 0.253
# 3 -  Hyundai Elantra Touring Hatchback 2012
# ---------------------------------------------
# Top similar cars to Chevrolet Sonic Sedan 2012
# sim value 0.234
# 1 -  Chevrolet Express Van 2007
# sim value 0.218
# 2 -  Chevrolet Silverado 1500 Classic Extended Cab 2007
# sim value 0.211
# 3 -  Chevrolet Tahoe Hybrid SUV 2012
# ---------------------------------------------
# Top similar cars to Chevrolet Tahoe Hybrid SUV 2012
# sim value 0.326
# 1 -  Audi TTS Coupe 2012
# sim value 0.313
# 2 -  Audi 100 Wagon 1994
# sim value 0.306
# 3 -  Suzuki SX4 Sedan 2012
# ---------------------------------------------
# Top similar cars to Chevrolet TrailBlazer SS 2009
# sim value 0.357
# 1 -  Chevrolet Express Cargo Van 2007
# sim value 0.246
# 2 -  Dodge Durango SUV 2007
# sim value 0.222
# 3 -  GMC Savana Van 2012
# ---------------------------------------------
# Top similar cars to Chevrolet Traverse SUV 2012
# sim value 0.323
# 1 -  Chevrolet TrailBlazer SS 2009
# sim value 0.253
# 2 -  Audi TTS Coupe 2012
# sim value 0.226
# 3 -  GMC Savana Van 2012
# ---------------------------------------------
# Top similar cars to Chrysler 300 SRT-8 2010
# sim value 0.311
# 1 -  Hyundai Veracruz SUV 2012
# sim value 0.277
# 2 -  Mercedes-Benz SL-Class Coupe 2009
# sim value 0.274
# 3 -  Toyota 4Runner SUV 2012
# ---------------------------------------------
# Top similar cars to Chrysler Aspen SUV 2009
# sim value 0.253
# 1 -  Hyundai Santa Fe SUV 2012
# sim value 0.224
# 2 -  Toyota Camry Sedan 2012
# sim value 0.224
# 3 -  Mercedes-Benz 300-Class Convertible 1993
# ---------------------------------------------
# Top similar cars to Chrysler Crossfire Convertible 2008
# sim value 0.409
# 1 -  Mercedes-Benz SL-Class Coupe 2009
# sim value 0.345
# 2 -  Jeep Wrangler SUV 2012
# sim value 0.297
# 3 -  Buick Verano Sedan 2012
# ---------------------------------------------
# Top similar cars to Chrysler PT Cruiser Convertible 2008
# sim value 0.298
# 1 -  Dodge Durango SUV 2012
# sim value 0.268
# 2 -  Rolls-Royce Phantom Drophead Coupe Convertible 2012
# sim value 0.260
# 3 -  Bentley Continental GT Coupe 2012
# ---------------------------------------------
# Top similar cars to Chrysler Sebring Convertible 2010
# sim value 0.245
# 1 -  Chrysler 300 SRT-8 2010
# sim value 0.200
# 2 -  Mercedes-Benz SL-Class Coupe 2009
# sim value 0.189
# 3 -  Dodge Durango SUV 2012
# ---------------------------------------------
# Top similar cars to Chrysler Town and Country Minivan 2012
# sim value 0.349
# 1 -  Chrysler Crossfire Convertible 2008
# sim value 0.301
# 2 -  Mercedes-Benz SL-Class Coupe 2009
# sim value 0.269
# 3 -  Hyundai Sonata Sedan 2012
# ---------------------------------------------
# Top similar cars to Daewoo Nubira Wagon 2002
# sim value 0.265
# 1 -  Isuzu Ascender SUV 2008
# sim value 0.219
# 2 -  Buick Rainier SUV 2007
# sim value 0.218
# 3 -  BMW 6 Series Convertible 2007
# ---------------------------------------------
# Top similar cars to Dodge Caliber Wagon 2007
# sim value 0.310
# 1 -  Dodge Durango SUV 2007
# sim value 0.286
# 2 -  Cadillac Escalade EXT Crew Cab 2007
# sim value 0.258
# 3 -  Ford GT Coupe 2006
# ---------------------------------------------
# Top similar cars to Dodge Caliber Wagon 2012
# sim value 0.231
# 1 -  Suzuki SX4 Hatchback 2012
# sim value 0.196
# 2 -  Dodge Charger Sedan 2012
# sim value 0.187
# 3 -  Volvo 240 Sedan 1993
# ---------------------------------------------
# Top similar cars to Dodge Caravan Minivan 1997
# sim value 0.298
# 1 -  Ford Expedition EL SUV 2009
# sim value 0.288
# 2 -  Isuzu Ascender SUV 2008
# sim value 0.256
# 3 -  Mercedes-Benz Sprinter Van 2012
# ---------------------------------------------
# Top similar cars to Dodge Challenger SRT8 2011
# sim value 0.227
# 1 -  GMC Acadia SUV 2012
# sim value 0.221
# 2 -  Audi S4 Sedan 2012
# sim value 0.218
# 3 -  Chrysler 300 SRT-8 2010
# ---------------------------------------------
# Top similar cars to Dodge Charger SRT-8 2009
# sim value 0.237
# 1 -  Buick Regal GS 2012
# sim value 0.230
# 2 -  Buick Verano Sedan 2012
# sim value 0.219
# 3 -  Lincoln Town Car Sedan 2011
# ---------------------------------------------
# Top similar cars to Dodge Charger Sedan 2012
# sim value 0.299
# 1 -  Mercedes-Benz Sprinter Van 2012
# sim value 0.210
# 2 -  Dodge Caravan Minivan 1997
# sim value 0.209
# 3 -  Audi S4 Sedan 2007
# ---------------------------------------------
# Top similar cars to Dodge Dakota Club Cab 2007
# sim value 0.289
# 1 -  Dodge Dakota Crew Cab 2010
# sim value 0.273
# 2 -  Hyundai Veracruz SUV 2012
# sim value 0.263
# 3 -  Cadillac Escalade EXT Crew Cab 2007
# ---------------------------------------------
# Top similar cars to Dodge Dakota Crew Cab 2010
# sim value 0.275
# 1 -  Ford E-Series Wagon Van 2012
# sim value 0.267
# 2 -  Acura Integra Type R 2001
# sim value 0.257
# 3 -  Isuzu Ascender SUV 2008
# ---------------------------------------------
# Top similar cars to Dodge Durango SUV 2007
# sim value 0.310
# 1 -  Dodge Caliber Wagon 2007
# sim value 0.281
# 2 -  Chevrolet Tahoe Hybrid SUV 2012
# sim value 0.246
# 3 -  Chevrolet TrailBlazer SS 2009
# ---------------------------------------------
# Top similar cars to Dodge Durango SUV 2012
# sim value 0.303
# 1 -  Chevrolet HHR SS 2010
# sim value 0.298
# 2 -  Chrysler PT Cruiser Convertible 2008
# sim value 0.218
# 3 -  Rolls-Royce Phantom Drophead Coupe Convertible 2012
# ---------------------------------------------
# Top similar cars to Dodge Journey SUV 2012
# sim value 0.249
# 1 -  Acura TL Type-S 2008
# sim value 0.222
# 2 -  Mercedes-Benz Sprinter Van 2012
# sim value 0.201
# 3 -  Audi R8 Coupe 2012
# ---------------------------------------------
# Top similar cars to Dodge Magnum Wagon 2008
# sim value 0.282
# 1 -  Acura TL Type-S 2008
# sim value 0.254
# 2 -  Toyota 4Runner SUV 2012
# sim value 0.239
# 3 -  Jeep Patriot SUV 2012
# ---------------------------------------------
# Top similar cars to Dodge Ram Pickup 3500 Crew Cab 2010
# sim value 0.313
# 1 -  Fisker Karma Sedan 2012
# sim value 0.247
# 2 -  Chevrolet Corvette Ron Fellows Edition Z06 2007
# sim value 0.227
# 3 -  Mazda Tribute SUV 2011
# ---------------------------------------------
# Top similar cars to Dodge Ram Pickup 3500 Quad Cab 2009
# sim value 0.248
# 1 -  Audi TTS Coupe 2012
# sim value 0.196
# 2 -  Chevrolet Tahoe Hybrid SUV 2012
# sim value 0.167
# 3 -  Audi TT RS Coupe 2012
# ---------------------------------------------
# Top similar cars to Dodge Sprinter Cargo Van 2009
# sim value 0.209
# 1 -  Isuzu Ascender SUV 2008
# sim value 0.173
# 2 -  Porsche Panamera Sedan 2012
# sim value 0.155
# 3 -  Dodge Durango SUV 2012
# ---------------------------------------------
# Top similar cars to Eagle Talon Hatchback 1998
# sim value 0.277
# 1 -  Bugatti Veyron 16.4 Coupe 2009
# sim value 0.228
# 2 -  Hyundai Elantra Sedan 2007
# sim value 0.221
# 3 -  Ford Freestar Minivan 2007
# ---------------------------------------------
# Top similar cars to FIAT 500 Abarth 2012
# sim value 0.277
# 1 -  Jeep Patriot SUV 2012
# sim value 0.204
# 2 -  Honda Accord Sedan 2012
# sim value 0.188
# 3 -  BMW X5 SUV 2007
# ---------------------------------------------
# Top similar cars to FIAT 500 Convertible 2012
# sim value 0.272
# 1 -  Mercedes-Benz Sprinter Van 2012
# sim value 0.213
# 2 -  Honda Accord Sedan 2012
# sim value 0.191
# 3 -  Suzuki Aerio Sedan 2007
# ---------------------------------------------
# Top similar cars to Ferrari 458 Italia Convertible 2012
# sim value 0.224
# 1 -  Mercedes-Benz S-Class Sedan 2012
# sim value 0.216
# 2 -  Chrysler Crossfire Convertible 2008
# sim value 0.212
# 3 -  BMW X5 SUV 2007
# ---------------------------------------------
# Top similar cars to Ferrari 458 Italia Coupe 2012
# sim value 0.181
# 1 -  Buick Regal GS 2012
# sim value 0.155
# 2 -  Dodge Durango SUV 2007
# sim value 0.129
# 3 -  Toyota Camry Sedan 2012
# ---------------------------------------------
# Top similar cars to Ferrari California Convertible 2012
# sim value 0.266
# 1 -  Lamborghini Gallardo LP 570-4 Superleggera 2012
# sim value 0.259
# 2 -  McLaren MP4-12C Coupe 2012
# sim value 0.221
# 3 -  Dodge Caliber Wagon 2012
# ---------------------------------------------
# Top similar cars to Ferrari FF Coupe 2012
# sim value 0.232
# 1 -  Cadillac CTS-V Sedan 2012
# sim value 0.196
# 2 -  Fisker Karma Sedan 2012
# sim value 0.195
# 3 -  Hyundai Genesis Sedan 2012
# ---------------------------------------------
# Top similar cars to Fisker Karma Sedan 2012
# sim value 0.356
# 1 -  Chevrolet Corvette Ron Fellows Edition Z06 2007
# sim value 0.313
# 2 -  Dodge Ram Pickup 3500 Crew Cab 2010
# sim value 0.290
# 3 -  BMW Z4 Convertible 2012
# ---------------------------------------------
# Top similar cars to Ford E-Series Wagon Van 2012
# sim value 0.399
# 1 -  Bentley Continental GT Coupe 2007
# sim value 0.292
# 2 -  Hyundai Azera Sedan 2012
# sim value 0.275
# 3 -  Dodge Dakota Crew Cab 2010
# ---------------------------------------------
# Top similar cars to Ford Edge SUV 2012
# sim value 0.214
# 1 -  Ford Freestar Minivan 2007
# sim value 0.213
# 2 -  Dodge Durango SUV 2012
# sim value 0.200
# 3 -  Mazda Tribute SUV 2011
# ---------------------------------------------
# Top similar cars to Ford Expedition EL SUV 2009
# sim value 0.298
# 1 -  Dodge Caravan Minivan 1997
# sim value 0.287
# 2 -  Toyota 4Runner SUV 2012
# sim value 0.273
# 3 -  Hyundai Santa Fe SUV 2012
# ---------------------------------------------
# Top similar cars to Ford F-150 Regular Cab 2007
# sim value 0.303
# 1 -  Toyota 4Runner SUV 2012
# sim value 0.241
# 2 -  Mercedes-Benz C-Class Sedan 2012
# sim value 0.227
# 3 -  Audi S5 Coupe 2012
# ---------------------------------------------
# Top similar cars to Ford F-150 Regular Cab 2012
# sim value 0.281
# 1 -  Ford Focus Sedan 2007
# sim value 0.185
# 2 -  Volvo 240 Sedan 1993
# sim value 0.174
# 3 -  Jeep Wrangler SUV 2012
# ---------------------------------------------
# Top similar cars to Ford F-450 Super Duty Crew Cab 2012
# sim value 0.241
# 1 -  Toyota Sequoia SUV 2012
# sim value 0.205
# 2 -  GMC Terrain SUV 2012
# sim value 0.205
# 3 -  Ford Focus Sedan 2007
# ---------------------------------------------
# Top similar cars to Ford Fiesta Sedan 2012
# sim value 0.255
# 1 -  Mazda Tribute SUV 2011
# sim value 0.216
# 2 -  Suzuki SX4 Hatchback 2012
# sim value 0.208
# 3 -  Ford Focus Sedan 2007
# ---------------------------------------------
# Top similar cars to Ford Focus Sedan 2007
# sim value 0.217
# 1 -  Bugatti Veyron 16.4 Convertible 2009
# sim value 0.210
# 2 -  Ford GT Coupe 2006
# sim value 0.210
# 3 -  Honda Odyssey Minivan 2012
# ---------------------------------------------
# Top similar cars to Ford Freestar Minivan 2007
# sim value 0.232
# 1 -  Ford GT Coupe 2006
# sim value 0.232
# 2 -  Nissan Juke Hatchback 2012
# sim value 0.225
# 3 -  Chevrolet Tahoe Hybrid SUV 2012
# ---------------------------------------------
# Top similar cars to Ford GT Coupe 2006
# sim value 0.354
# 1 -  Buick Rainier SUV 2007
# sim value 0.258
# 2 -  Dodge Caliber Wagon 2007
# sim value 0.232
# 3 -  Ford Freestar Minivan 2007
# ---------------------------------------------
# Top similar cars to Ford Mustang Convertible 2007
# sim value 0.252
# 1 -  Honda Odyssey Minivan 2012
# sim value 0.247
# 2 -  Mercedes-Benz Sprinter Van 2012
# sim value 0.237
# 3 -  Lincoln Town Car Sedan 2011
# ---------------------------------------------
# Top similar cars to Ford Ranger SuperCab 2011
# sim value 0.263
# 1 -  BMW M5 Sedan 2010
# sim value 0.221
# 2 -  Acura RL Sedan 2012
# sim value 0.218
# 3 -  Nissan 240SX Coupe 1998
# ---------------------------------------------
# Top similar cars to Geo Metro Convertible 1993
# sim value 0.353
# 1 -  Ford Freestar Minivan 2007
# sim value 0.262
# 2 -  Eagle Talon Hatchback 1998
# sim value 0.261
# 3 -  smart fortwo Convertible 2012
# ---------------------------------------------
# Top similar cars to GMC Acadia SUV 2012
# sim value 0.399
# 1 -  Toyota Sequoia SUV 2012
# sim value 0.314
# 2 -  Rolls-Royce Phantom Drophead Coupe Convertible 2012
# sim value 0.270
# 3 -  BMW X6 SUV 2012
# ---------------------------------------------
# Top similar cars to GMC Canyon Extended Cab 2012
# sim value 0.275
# 1 -  Dodge Durango SUV 2012
# sim value 0.262
# 2 -  Chevrolet TrailBlazer SS 2009
# sim value 0.242
# 3 -  Suzuki Aerio Sedan 2007
# ---------------------------------------------
# Top similar cars to GMC Savana Van 2012
# sim value 0.365
# 1 -  Chevrolet HHR SS 2010
# sim value 0.346
# 2 -  Lamborghini Diablo Coupe 2001
# sim value 0.271
# 3 -  Audi V8 Sedan 1994
# ---------------------------------------------
# Top similar cars to GMC Terrain SUV 2012
# sim value 0.264
# 1 -  Bentley Continental GT Coupe 2007
# sim value 0.237
# 2 -  Hyundai Azera Sedan 2012
# sim value 0.230
# 3 -  Jeep Patriot SUV 2012
# ---------------------------------------------
# Top similar cars to GMC Yukon Hybrid SUV 2012
# sim value 0.234
# 1 -  GMC Acadia SUV 2012
# sim value 0.192
# 2 -  Toyota Sequoia SUV 2012
# sim value 0.175
# 3 -  McLaren MP4-12C Coupe 2012
# ---------------------------------------------
# Top similar cars to HUMMER H2 SUT Crew Cab 2009
# sim value 0.428
# 1 -  Jeep Wrangler SUV 2012
# sim value 0.337
# 2 -  Jeep Liberty SUV 2012
# sim value 0.322
# 3 -  Jeep Compass SUV 2012
# ---------------------------------------------
# Top similar cars to HUMMER H3T Crew Cab 2010
# sim value 0.262
# 1 -  Jeep Patriot SUV 2012
# sim value 0.246
# 2 -  Cadillac SRX SUV 2012
# sim value 0.240
# 3 -  Jeep Grand Cherokee SUV 2012
# ---------------------------------------------
# Top similar cars to Honda Accord Coupe 2012
# sim value 0.296
# 1 -  Mercedes-Benz Sprinter Van 2012
# sim value 0.287
# 2 -  Honda Accord Sedan 2012
# sim value 0.263
# 3 -  Audi 100 Wagon 1994
# ---------------------------------------------
# Top similar cars to Honda Accord Sedan 2012
# sim value 0.322
# 1 -  Honda Odyssey Minivan 2012
# sim value 0.315
# 2 -  Hyundai Elantra Touring Hatchback 2012
# sim value 0.287
# 3 -  Honda Accord Coupe 2012
# ---------------------------------------------
# Top similar cars to Honda Odyssey Minivan 2007
# sim value 0.288
# 1 -  Honda Odyssey Minivan 2012
# sim value 0.234
# 2 -  Hyundai Sonata Hybrid Sedan 2012
# sim value 0.232
# 3 -  Audi A5 Coupe 2012
# ---------------------------------------------
# Top similar cars to Honda Odyssey Minivan 2012
# sim value 0.322
# 1 -  Honda Accord Sedan 2012
# sim value 0.313
# 2 -  Maybach Landaulet Convertible 2012
# sim value 0.277
# 3 -  Volvo XC90 SUV 2007
# ---------------------------------------------
# Top similar cars to Hyundai Accent Sedan 2012
# sim value 0.331
# 1 -  Hyundai Elantra Sedan 2007
# sim value 0.300
# 2 -  McLaren MP4-12C Coupe 2012
# sim value 0.230
# 3 -  Hyundai Genesis Sedan 2012
# ---------------------------------------------
# Top similar cars to Hyundai Azera Sedan 2012
# sim value 0.327
# 1 -  Toyota 4Runner SUV 2012
# sim value 0.312
# 2 -  Hyundai Tucson SUV 2012
# sim value 0.293
# 3 -  Porsche Panamera Sedan 2012
# ---------------------------------------------
# Top similar cars to Hyundai Elantra Sedan 2007
# sim value 0.353
# 1 -  Buick Rainier SUV 2007
# sim value 0.332
# 2 -  Hyundai Genesis Sedan 2012
# sim value 0.331
# 3 -  Hyundai Accent Sedan 2012
# ---------------------------------------------
# Top similar cars to Hyundai Elantra Touring Hatchback 2012
# sim value 0.315
# 1 -  Honda Accord Sedan 2012
# sim value 0.285
# 2 -  Mercedes-Benz Sprinter Van 2012
# sim value 0.260
# 3 -  Honda Accord Coupe 2012
# ---------------------------------------------
# Top similar cars to Hyundai Genesis Sedan 2012
# sim value 0.340
# 1 -  Hyundai Sonata Hybrid Sedan 2012
# sim value 0.332
# 2 -  Hyundai Elantra Sedan 2007
# sim value 0.314
# 3 -  Hyundai Tucson SUV 2012
# ---------------------------------------------
# Top similar cars to Hyundai Santa Fe SUV 2012
# sim value 0.279
# 1 -  Audi TTS Coupe 2012
# sim value 0.273
# 2 -  Ford Expedition EL SUV 2009
# sim value 0.259
# 3 -  Audi 100 Wagon 1994
# ---------------------------------------------
# Top similar cars to Hyundai Sonata Hybrid Sedan 2012
# sim value 0.340
# 1 -  Hyundai Genesis Sedan 2012
# sim value 0.219
# 2 -  Honda Odyssey Minivan 2012
# sim value 0.211
# 3 -  GMC Terrain SUV 2012
# ---------------------------------------------
# Top similar cars to Hyundai Sonata Sedan 2012
# sim value 0.352
# 1 -  Mercedes-Benz E-Class Sedan 2012
# sim value 0.338
# 2 -  Jeep Wrangler SUV 2012
# sim value 0.336
# 3 -  Hyundai Veracruz SUV 2012
# ---------------------------------------------
# Top similar cars to Hyundai Tucson SUV 2012
# sim value 0.339
# 1 -  Hyundai Veracruz SUV 2012
# sim value 0.331
# 2 -  Hyundai Sonata Sedan 2012
# sim value 0.314
# 3 -  Hyundai Genesis Sedan 2012
# ---------------------------------------------
# Top similar cars to Hyundai Veloster Hatchback 2012
# sim value 0.238
# 1 -  Suzuki SX4 Hatchback 2012
# sim value 0.204
# 2 -  Audi R8 Coupe 2012
# sim value 0.179
# 3 -  Daewoo Nubira Wagon 2002
# ---------------------------------------------
# Top similar cars to Hyundai Veracruz SUV 2012
# sim value 0.349
# 1 -  Mercedes-Benz S-Class Sedan 2012
# sim value 0.346
# 2 -  Bentley Continental GT Coupe 2007
# sim value 0.339
# 3 -  Hyundai Tucson SUV 2012
# ---------------------------------------------
# Top similar cars to Infiniti G Coupe IPL 2012
# sim value 0.257
# 1 -  Chevrolet Silverado 1500 Classic Extended Cab 2007
# sim value 0.243
# 2 -  Acura TL Sedan 2012
# sim value 0.216
# 3 -  Mercedes-Benz SL-Class Coupe 2009
# ---------------------------------------------
# Top similar cars to Infiniti QX56 SUV 2011
# sim value 0.273
# 1 -  Toyota 4Runner SUV 2012
# sim value 0.223
# 2 -  Jeep Patriot SUV 2012
# sim value 0.222
# 3 -  BMW X3 SUV 2012
# ---------------------------------------------
# Top similar cars to Isuzu Ascender SUV 2008
# sim value 0.288
# 1 -  Dodge Caravan Minivan 1997
# sim value 0.265
# 2 -  Daewoo Nubira Wagon 2002
# sim value 0.257
# 3 -  Dodge Dakota Crew Cab 2010
# ---------------------------------------------
# Top similar cars to Jaguar XK XKR 2012
# sim value 0.217
# 1 -  Porsche Panamera Sedan 2012
# sim value 0.193
# 2 -  BMW 3 Series Sedan 2012
# sim value 0.174
# 3 -  Hyundai Azera Sedan 2012
# ---------------------------------------------
# Top similar cars to Jeep Compass SUV 2012
# sim value 0.422
# 1 -  Jeep Grand Cherokee SUV 2012
# sim value 0.407
# 2 -  Jeep Wrangler SUV 2012
# sim value 0.391
# 3 -  Jeep Liberty SUV 2012
# ---------------------------------------------
# Top similar cars to Jeep Grand Cherokee SUV 2012
# sim value 0.422
# 1 -  Jeep Compass SUV 2012
# sim value 0.363
# 2 -  Jeep Liberty SUV 2012
# sim value 0.272
# 3 -  Jeep Patriot SUV 2012
# ---------------------------------------------
# Top similar cars to Jeep Liberty SUV 2012
# sim value 0.393
# 1 -  Jeep Patriot SUV 2012
# sim value 0.391
# 2 -  Jeep Compass SUV 2012
# sim value 0.363
# 3 -  Jeep Grand Cherokee SUV 2012
# ---------------------------------------------
# Top similar cars to Jeep Patriot SUV 2012
# sim value 0.393
# 1 -  Jeep Liberty SUV 2012
# sim value 0.326
# 2 -  Jeep Wrangler SUV 2012
# sim value 0.272
# 3 -  Jeep Grand Cherokee SUV 2012
# ---------------------------------------------
# Top similar cars to Jeep Wrangler SUV 2012
# sim value 0.407
# 1 -  Jeep Compass SUV 2012
# sim value 0.345
# 2 -  Chrysler Crossfire Convertible 2008
# sim value 0.338
# 3 -  Hyundai Sonata Sedan 2012
# ---------------------------------------------
# Top similar cars to Lamborghini Aventador Coupe 2012
# sim value 0.283
# 1 -  Chevrolet Tahoe Hybrid SUV 2012
# sim value 0.251
# 2 -  Audi TTS Coupe 2012
# sim value 0.240
# 3 -  Jeep Liberty SUV 2012
# ---------------------------------------------
# Top similar cars to Lamborghini Diablo Coupe 2001
# sim value 0.346
# 1 -  GMC Savana Van 2012
# sim value 0.321
# 2 -  Audi V8 Sedan 1994
# sim value 0.289
# 3 -  Bentley Continental GT Coupe 2012
# ---------------------------------------------
# Top similar cars to Lamborghini Gallardo LP 570-4 Superleggera 2012
# sim value 0.224
# 1 -  Lamborghini Reventon Coupe 2008
# sim value 0.189
# 2 -  Acura TSX Sedan 2012
# sim value 0.166
# 3 -  Audi S4 Sedan 2007
# ---------------------------------------------
# Top similar cars to Lamborghini Reventon Coupe 2008
# sim value 0.384
# 1 -  Acura TSX Sedan 2012
# sim value 0.224
# 2 -  Lamborghini Gallardo LP 570-4 Superleggera 2012
# sim value 0.211
# 3 -  Acura Integra Type R 2001
# ---------------------------------------------
# Top similar cars to Land Rover LR2 SUV 2012
# sim value 0.360
# 1 -  Chrysler 300 SRT-8 2010
# sim value 0.253
# 2 -  Toyota 4Runner SUV 2012
# sim value 0.250
# 3 -  Volvo C30 Hatchback 2012
# ---------------------------------------------
# Top similar cars to Land Rover Range Rover SUV 2012
# sim value 0.316
# 1 -  GMC Acadia SUV 2012
# sim value 0.255
# 2 -  Jeep Compass SUV 2012
# sim value 0.254
# 3 -  Honda Accord Coupe 2012
# ---------------------------------------------
# Top similar cars to Lincoln Town Car Sedan 2011
# sim value 0.246
# 1 -  Audi S4 Sedan 2007
# sim value 0.245
# 2 -  Chevrolet Express Van 2007
# sim value 0.241
# 3 -  Suzuki SX4 Sedan 2012
# ---------------------------------------------
# Top similar cars to Maybach Landaulet Convertible 2012
# sim value 0.313
# 1 -  Honda Odyssey Minivan 2012
# sim value 0.303
# 2 -  Hyundai Genesis Sedan 2012
# sim value 0.226
# 3 -  Lincoln Town Car Sedan 2011
# ---------------------------------------------
# Top similar cars to Mazda Tribute SUV 2011
# sim value 0.340
# 1 -  Toyota Sequoia SUV 2012
# sim value 0.301
# 2 -  Jeep Compass SUV 2012
# sim value 0.255
# 3 -  Ford Fiesta Sedan 2012
# ---------------------------------------------
# Top similar cars to McLaren MP4-12C Coupe 2012
# sim value 0.300
# 1 -  Hyundai Accent Sedan 2012
# sim value 0.270
# 2 -  Hyundai Elantra Sedan 2007
# sim value 0.259
# 3 -  smart fortwo Convertible 2012
# ---------------------------------------------
# Top similar cars to Mercedes-Benz 300-Class Convertible 1993
# sim value 0.233
# 1 -  Dodge Durango SUV 2007
# sim value 0.217
# 2 -  Ford Expedition EL SUV 2009
# sim value 0.171
# 3 -  Chrysler 300 SRT-8 2010
# ---------------------------------------------
# Top similar cars to Mercedes-Benz C-Class Sedan 2012
# sim value 0.276
# 1 -  Mercedes-Benz S-Class Sedan 2012
# sim value 0.268
# 2 -  Mercedes-Benz E-Class Sedan 2012
# sim value 0.259
# 3 -  Audi RS 4 Convertible 2008
# ---------------------------------------------
# Top similar cars to Mercedes-Benz E-Class Sedan 2012
# sim value 0.352
# 1 -  Hyundai Sonata Sedan 2012
# sim value 0.268
# 2 -  Mercedes-Benz C-Class Sedan 2012
# sim value 0.239
# 3 -  McLaren MP4-12C Coupe 2012
# ---------------------------------------------
# Top similar cars to Mercedes-Benz S-Class Sedan 2012
# sim value 0.373
# 1 -  Mercedes-Benz SL-Class Coupe 2009
# sim value 0.349
# 2 -  Hyundai Veracruz SUV 2012
# sim value 0.322
# 3 -  Hyundai Sonata Sedan 2012
# ---------------------------------------------
# Top similar cars to Mercedes-Benz SL-Class Coupe 2009
# sim value 0.409
# 1 -  Chrysler Crossfire Convertible 2008
# sim value 0.373
# 2 -  Mercedes-Benz S-Class Sedan 2012
# sim value 0.336
# 3 -  Hyundai Sonata Sedan 2012
# ---------------------------------------------
# Top similar cars to Mercedes-Benz Sprinter Van 2012
# sim value 0.340
# 1 -  Suzuki Aerio Sedan 2007
# sim value 0.299
# 2 -  Dodge Charger Sedan 2012
# sim value 0.296
# 3 -  Honda Accord Coupe 2012
# ---------------------------------------------
# Top similar cars to Mitsubishi Lancer Sedan 2012
# sim value 0.397
# 1 -  Nissan 240SX Coupe 1998
# sim value 0.288
# 2 -  Chevrolet Corvette Ron Fellows Edition Z06 2007
# sim value 0.288
# 3 -  Acura TL Sedan 2012
# ---------------------------------------------
# Top similar cars to MINI Cooper Roadster Convertible 2012
# sim value 0.250
# 1 -  Ford E-Series Wagon Van 2012
# sim value 0.244
# 2 -  Ford F-150 Regular Cab 2007
# sim value 0.233
# 3 -  Acura TL Type-S 2008
# ---------------------------------------------
# Top similar cars to Nissan 240SX Coupe 1998
# sim value 0.397
# 1 -  Mitsubishi Lancer Sedan 2012
# sim value 0.240
# 2 -  GMC Acadia SUV 2012
# sim value 0.218
# 3 -  Ford Ranger SuperCab 2011
# ---------------------------------------------
# Top similar cars to Nissan Juke Hatchback 2012
# sim value 0.271
# 1 -  GMC Savana Van 2012
# sim value 0.267
# 2 -  Chevrolet Express Cargo Van 2007
# sim value 0.232
# 3 -  Ford Freestar Minivan 2007
# ---------------------------------------------
# Top similar cars to Nissan Leaf Hatchback 2012
# sim value 0.323
# 1 -  Suzuki Kizashi Sedan 2012
# sim value 0.214
# 2 -  Infiniti QX56 SUV 2011
# sim value 0.214
# 3 -  smart fortwo Convertible 2012
# ---------------------------------------------
# Top similar cars to Nissan NV Passenger Van 2012
# sim value 0.219
# 1 -  Chevrolet Express Van 2007
# sim value 0.200
# 2 -  Eagle Talon Hatchback 1998
# sim value 0.198
# 3 -  Acura TL Sedan 2012
# ---------------------------------------------
# Top similar cars to Plymouth Neon Coupe 1999
# sim value 0.209
# 1 -  Acura TL Type-S 2008
# sim value 0.204
# 2 -  smart fortwo Convertible 2012
# sim value 0.203
# 3 -  Bugatti Veyron 16.4 Convertible 2009
# ---------------------------------------------
# Top similar cars to Porsche Panamera Sedan 2012
# sim value 0.305
# 1 -  Audi S5 Coupe 2012
# sim value 0.293
# 2 -  Hyundai Azera Sedan 2012
# sim value 0.189
# 3 -  Rolls-Royce Phantom Drophead Coupe Convertible 2012
# ---------------------------------------------
# Top similar cars to Ram C/V Cargo Van Minivan 2012
# sim value 0.240
# 1 -  Acura TL Type-S 2008
# sim value 0.228
# 2 -  Chevrolet HHR SS 2010
# sim value 0.223
# 3 -  Audi S4 Sedan 2007
# ---------------------------------------------
# Top similar cars to Rolls-Royce Ghost Sedan 2012
# sim value 0.307
# 1 -  Dodge Durango SUV 2012
# sim value 0.296
# 2 -  Rolls-Royce Phantom Drophead Coupe Convertible 2012
# sim value 0.198
# 3 -  GMC Acadia SUV 2012
# ---------------------------------------------
# Top similar cars to Rolls-Royce Phantom Drophead Coupe Convertible 2012
# sim value 0.351
# 1 -  Audi S5 Coupe 2012
# sim value 0.314
# 2 -  GMC Acadia SUV 2012
# sim value 0.305
# 3 -  Bugatti Veyron 16.4 Convertible 2009
# ---------------------------------------------
# Top similar cars to Rolls-Royce Phantom Sedan 2012
# sim value 0.336
# 1 -  Rolls-Royce Phantom Drophead Coupe Convertible 2012
# sim value 0.248
# 2 -  Audi S5 Coupe 2012
# sim value 0.246
# 3 -  Ford F-150 Regular Cab 2007
# ---------------------------------------------
# Top similar cars to Scion xD Hatchback 2012
# sim value 0.259
# 1 -  Toyota Sequoia SUV 2012
# sim value 0.258
# 2 -  Acura ZDX Hatchback 2012
# sim value 0.249
# 3 -  Audi 100 Wagon 1994
# ---------------------------------------------
# Top similar cars to smart fortwo Convertible 2012
# sim value 0.259
# 1 -  McLaren MP4-12C Coupe 2012
# sim value 0.234
# 2 -  Hyundai Genesis Sedan 2012
# sim value 0.222
# 3 -  Maybach Landaulet Convertible 2012
# ---------------------------------------------
# Top similar cars to Spyker C8 Convertible 2009
# sim value 0.233
# 1 -  Cadillac SRX SUV 2012
# sim value 0.206
# 2 -  Spyker C8 Coupe 2009
# sim value 0.184
# 3 -  Eagle Talon Hatchback 1998
# ---------------------------------------------
# Top similar cars to Spyker C8 Coupe 2009
# sim value 0.202
# 1 -  Cadillac SRX SUV 2012
# sim value 0.179
# 2 -  BMW Z4 Convertible 2012
# sim value 0.168
# 3 -  BMW X5 SUV 2007
# ---------------------------------------------
# Top similar cars to Suzuki Aerio Sedan 2007
# sim value 0.340
# 1 -  Mercedes-Benz Sprinter Van 2012
# sim value 0.260
# 2 -  Honda Accord Coupe 2012
# sim value 0.240
# 3 -  Acura TSX Sedan 2012
# ---------------------------------------------
# Top similar cars to Suzuki Kizashi Sedan 2012
# sim value 0.242
# 1 -  Buick Regal GS 2012
# sim value 0.192
# 2 -  Suzuki SX4 Sedan 2012
# sim value 0.181
# 3 -  Chrysler PT Cruiser Convertible 2008
# ---------------------------------------------
# Top similar cars to Suzuki SX4 Hatchback 2012
# sim value 0.231
# 1 -  Dodge Caliber Wagon 2012
# sim value 0.217
# 2 -  Volvo 240 Sedan 1993
# sim value 0.216
# 3 -  Ford Fiesta Sedan 2012
# ---------------------------------------------
# Top similar cars to Suzuki SX4 Sedan 2012
# sim value 0.306
# 1 -  Chevrolet Tahoe Hybrid SUV 2012
# sim value 0.291
# 2 -  Buick Regal GS 2012
# sim value 0.253
# 3 -  Bugatti Veyron 16.4 Convertible 2009
# ---------------------------------------------
# Top similar cars to Tesla Model S Sedan 2012
# sim value 0.214
# 1 -  Audi A5 Coupe 2012
# sim value 0.184
# 2 -  BMW X5 SUV 2007
# sim value 0.180
# 3 -  Acura ZDX Hatchback 2012
# ---------------------------------------------
# Top similar cars to Toyota 4Runner SUV 2012
# sim value 0.327
# 1 -  Hyundai Azera Sedan 2012
# sim value 0.303
# 2 -  Ford F-150 Regular Cab 2007
# sim value 0.287
# 3 -  Ford Expedition EL SUV 2009
# ---------------------------------------------
# Top similar cars to Toyota Camry Sedan 2012
# sim value 0.250
# 1 -  Mitsubishi Lancer Sedan 2012
# sim value 0.239
# 2 -  Acura TL Type-S 2008
# sim value 0.202
# 3 -  Hyundai Veracruz SUV 2012
# ---------------------------------------------
# Top similar cars to Toyota Corolla Sedan 2012
# sim value 0.245
# 1 -  Acura TL Type-S 2008
# sim value 0.230
# 2 -  Hyundai Sonata Hybrid Sedan 2012
# sim value 0.225
# 3 -  Toyota Camry Sedan 2012
# ---------------------------------------------
# Top similar cars to Toyota Sequoia SUV 2012
# sim value 0.399
# 1 -  GMC Acadia SUV 2012
# sim value 0.340
# 2 -  Mazda Tribute SUV 2011
# sim value 0.333
# 3 -  Chevrolet HHR SS 2010
# ---------------------------------------------
# Top similar cars to Volkswagen Beetle Hatchback 2012
# sim value 0.323
# 1 -  Acura TL Type-S 2008
# sim value 0.195
# 2 -  Toyota 4Runner SUV 2012
# sim value 0.178
# 3 -  smart fortwo Convertible 2012
# ---------------------------------------------
# Top similar cars to Volkswagen Golf Hatchback 1991
# sim value 0.289
# 1 -  Dodge Caliber Wagon 2012
# sim value 0.224
# 2 -  Hyundai Elantra Touring Hatchback 2012
# sim value 0.219
# 3 -  Dodge Caravan Minivan 1997
# ---------------------------------------------
# Top similar cars to Volkswagen Golf Hatchback 2012
# sim value 0.275
# 1 -  Bugatti Veyron 16.4 Convertible 2009
# sim value 0.269
# 2 -  Bugatti Veyron 16.4 Coupe 2009
# sim value 0.212
# 3 -  Honda Accord Coupe 2012
# ---------------------------------------------
# Top similar cars to Volvo 240 Sedan 1993
# sim value 0.217
# 1 -  Suzuki SX4 Hatchback 2012
# sim value 0.210
# 2 -  GMC Acadia SUV 2012
# sim value 0.198
# 3 -  Ford E-Series Wagon Van 2012
# ---------------------------------------------
# Top similar cars to Volvo C30 Hatchback 2012
# sim value 0.288
# 1 -  Audi RS 4 Convertible 2008
# sim value 0.280
# 2 -  Jeep Compass SUV 2012
# sim value 0.268
# 3 -  Honda Odyssey Minivan 2012
# ---------------------------------------------
# Top similar cars to Volvo XC90 SUV 2007
# sim value 0.281
# 1 -  Audi RS 4 Convertible 2008
# sim value 0.277
# 2 -  Honda Odyssey Minivan 2012
# sim value 0.184
# 3 -  Maybach Landaulet Convertible 2012
# ---------------------------------------------

# %%
import matplotlib.pyplot as plt
import networkx as nx

elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] > 0.9]
# esmall = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] <= 0.5]

pos = nx.spring_layout(G)  # positions for all nodes

# nodes
nx.draw_networkx_nodes(G, pos, node_size=700)

# edges
# edge_labels = nx.get_edge_attributes(G, 'name')
# nx.draw_networkx_edge_labels(G, pos, labels=edge_labels)
nx.draw_networkx_edge_labels(G, pos, edgelist=elarge, width=3)

# nx.draw_networkx_edges(G, pos, edgelist=elarge, width=3)
#delete edges with low similaaities
# nx.draw_networkx_edges(
#     G, pos, edgelist=esmall, width=3, alpha=0.5, edge_color="b", style="dashed"
# ) 


# labels
nx.draw_networkx_labels(G, pos, font_size=20, font_family="sans-serif")

plt.axis("off")
plt.show()

# %%
from pyvis.network import Network
net = Network(notebook= True)
# load the network graph
net.from_nx(G)
net.show("exampCarsClasses0_8.html")
# Out:
#         <iframe
#             width="500px"
#             height="500px"
#             src="exampDogsClasses0_8.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
