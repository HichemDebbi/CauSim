# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import cv2
def load_and_preprocess_image(path):
    image = cv2.imread(path)
    image = cv2.resize(image, (224,224))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

# %%
# Useful functions for bilinear product
def outer_product(x):
    return K.batch_dot(x[0], x[1], axes = [1, 1]) / x[0].get_shape().as_list()[1]
def signed_sqrt(x):
    return K.sign(x)*K.sqrt(K.abs(x) + 1e-9)
def l2_normalize(x, axis = -1):
    return K.l2_normalize(x, axis=axis)

# %%
def insert_intermediate_layer_in_keras(model, layer_id, new_layer):
    from keras.models import Model

    layers = [l for l in model.layers]

    x = layers[0].output
    for i in range(1, len(layers)):
        if i == layer_id:
            x = new_layer(x)
        x = layers[i](x)

    model = Model(inputs=layers[0].input, outputs=x) ### inputs instead of input in this version
    return model

# %%
from tensorflow.keras.initializers import glorot_normal
from keras.layers import Lambda
import tensorflow

# Model Architecture
def VGG16_outerproduct(filter_zero
                ,value_filter, classes, dropoutrate, model_name):
    K.clear_session()
    
    # VGG16 as base for extract features
#     base_model = VGG16(input_shape = (224, 224, 3), include_top = False, weights = "imagenet")
    
    tensor_input = tensorflow.keras.layers.Input(shape=[224,224,3])
    base_model = tensorflow.keras.applications.vgg16.VGG16(
                            input_tensor=tensor_input
                            , include_top=False
                            , weights='imagenet'
                        )
    
    
    arryWeights_last_After =[]
    for i in range(512):
      arryWeights_last_After.append(i)
    for i in range(512):
      arryWeights_last_After[i]=1
    
    arryWeights_last_After[filter_zero]=value_filter
    # print('filter' , filter_zero, "=", arryWeights_last_After[filter_zero])
    def custom_layer_last(tensor):
        return tensor * arryWeights_last_After
    lambda_layer = Lambda (custom_layer_last, name="lambda_New")

    base_model = insert_intermediate_layer_in_keras (base_model, 18, lambda_layer)
    # base_model.summary()
    
    # Get output from VGG16 end layer features
    feature_model_1 = base_model
    x1 = feature_model_1.layers[18].output
    x1_shape = feature_model_1.layers[18].output_shape
    
    feature_model_2 = base_model
    x2 = feature_model_2.layers[18].output
    x2_shape = feature_model_2.layers[18].output_shape
    
    # reshape to (batch_size, total_pixels, filter_size) for outer product
    x1 = Reshape(
        [x1_shape[1]*x1_shape[2], x1_shape[-1]])(x1)
    x2 = Reshape(
        [x2_shape[1]*x2_shape[2], x2_shape[-1]])(x2)
    
    # Outer product of VGG16 features
    x = Lambda(outer_product)([x1, x2])
    x = Reshape([x1_shape[-1]*x2_shape[-1]])(x)
    x = Lambda(signed_sqrt)(x)
    x = Lambda(l2_normalize)(x)
    
    # Final dense layer
    x = Dense(units=len(classes), kernel_initializer="glorot_uniform",
              kernel_regularizer=l2(1e-08),
             bias_initializer="glorot_uniform")(x)
    
    prediction = Activation(activation="softmax")(x)
    
    model = Model(inputs = base_model.input, outputs=prediction)
    
    ### added
    for layer in base_model.layers:
        layer.trainable = False
    ### added    
    return model

# %%
import scipy.io as sio

def load_data(path, data_type, data_class):
    raw = sio.loadmat(path)
    if data_class == "train":
        if data_type == "data":
            cars_data = [(row[5][0][:],row[4][0][0],row[0][0][0],row[1][0][0],row[2][0][0],row[3][0][0]) for row in raw['annotations'][0]]
            return cars_data

        if data_type == "class":
            cars_classes = [(row[0]) for row in raw['class_names'][0]]
            return cars_classes
        
    if data_class == "test":
        if data_type == "data":
            cars_data = [(row[4][0][:],"empty",row[0][0][0],row[1][0][0],row[2][0][0],row[3][0][0]) for row in raw['annotations'][0]]
            return cars_data

    # if data_class == "all":
    # 	if data_type == "class":
    # 		cars_classes = [(row[0]) for row in raw['class_names'][0]]
    # 		return cars_classes

# %%
classes = load_data("/content/drive/My Drive/Colab Notebooks/Cars/devkit/cars_meta.mat", "class", "train")

# %%
from keras.layers import Lambda
from keras import backend as K
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, MaxPool2D, Reshape, Dense, Activation

from keras.regularizers import l2
from keras.models import Model, model_from_json, load_model, Sequential

# hyperparameters for initial training
lr = 0.1
epochs = 500
dropout_rate  = 0.5
batch_size = 64
model_name = "VGG19"
paitence = 10
optimizer_name = "sgd"
decay = 1e-8

# load model
tensArry=[]
for i in range(512):
    tensArry.append(1)
    
model = VGG16_outerproduct(filter_zero=0
                    , value_filter=1, classes=classes,dropoutrate=dropout_rate,model_name=model_name)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step

# %%
# now all layers are trainable
for layer in model.layers:
    layer.trainable = True

# change LR
opt_sgd = tensorflow.keras.optimizers.SGD(
                lr=1e-3
                , decay=1e-9
                , momentum=0.9
                , nesterov=False
            )
model.compile(
    loss="categorical_crossentropy"
    , optimizer=opt_sgd
    , metrics=["categorical_accuracy"]
)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
model.load_weights("/content/drive/My Drive/Colab Notebooks/Cars/final_all_transfer_learning_VGG16.h5")

# %%
layer = model.layers[18]
layer.name
# Out:
# 'lambda_New'

# %%
# import os

# dogs_labels = set()

# path= "/content/drive/My Drive/Colab Notebooks/Data_Stanford_Dogs/images/Images"
# for d in os.listdir(path):
#     dogs_labels.add(d)

# len(dogs_labels)

# %%
# dogs_labels = list(classes)
# # dogs_labels.sort()
# classes

# dogs_labels = list(dogs_labels)
# dogs_labels_path = [path + s for s in dogs_labels]
# # dogs_labels
classes = list(classes)
classes.sort()
classes
# Out:
# ['AM General Hummer SUV 2000',
#  'Acura Integra Type R 2001',
#  'Acura RL Sedan 2012',
#  'Acura TL Sedan 2012',
#  'Acura TL Type-S 2008',
#  'Acura TSX Sedan 2012',
#  'Acura ZDX Hatchback 2012',
#  'Aston Martin V8 Vantage Convertible 2012',
#  'Aston Martin V8 Vantage Coupe 2012',
#  'Aston Martin Virage Convertible 2012',
#  'Aston Martin Virage Coupe 2012',
#  'Audi 100 Sedan 1994',
#  'Audi 100 Wagon 1994',
#  'Audi A5 Coupe 2012',
#  'Audi R8 Coupe 2012',
#  'Audi RS 4 Convertible 2008',
#  'Audi S4 Sedan 2007',
#  'Audi S4 Sedan 2012',
#  'Audi S5 Convertible 2012',
#  'Audi S5 Coupe 2012',
#  'Audi S6 Sedan 2011',
#  'Audi TT Hatchback 2011',
#  'Audi TT RS Coupe 2012',
#  'Audi TTS Coupe 2012',
#  'Audi V8 Sedan 1994',
#  'BMW 1 Series Convertible 2012',
#  'BMW 1 Series Coupe 2012',
#  'BMW 3 Series Sedan 2012',
#  'BMW 3 Series Wagon 2012',
#  'BMW 6 Series Convertible 2007',
#  'BMW ActiveHybrid 5 Sedan 2012',
#  'BMW M3 Coupe 2012',
#  'BMW M5 Sedan 2010',
#  'BMW M6 Convertible 2010',
#  'BMW X3 SUV 2012',
#  'BMW X5 SUV 2007',
#  'BMW X6 SUV 2012',
#  'BMW Z4 Convertible 2012',
#  'Bentley Arnage Sedan 2009',
#  'Bentley Continental Flying Spur Sedan 2007',
#  'Bentley Continental GT Coupe 2007',
#  'Bentley Continental GT Coupe 2012',
#  'Bentley Continental Supersports Conv. Convertible 2012',
#  'Bentley Mulsanne Sedan 2011',
#  'Bugatti Veyron 16.4 Convertible 2009',
#  'Bugatti Veyron 16.4 Coupe 2009',
#  'Buick Enclave SUV 2012',
#  'Buick Rainier SUV 2007',
#  'Buick Regal GS 2012',
#  'Buick Verano Sedan 2012',
#  'Cadillac CTS-V Sedan 2012',
#  'Cadillac Escalade EXT Crew Cab 2007',
#  'Cadillac SRX SUV 2012',
#  'Chevrolet Avalanche Crew Cab 2012',
#  'Chevrolet Camaro Convertible 2012',
#  'Chevrolet Cobalt SS 2010',
#  'Chevrolet Corvette Convertible 2012',
#  'Chevrolet Corvette Ron Fellows Edition Z06 2007',
#  'Chevrolet Corvette ZR1 2012',
#  'Chevrolet Express Cargo Van 2007',
#  'Chevrolet Express Van 2007',
#  'Chevrolet HHR SS 2010',
#  'Chevrolet Impala Sedan 2007',
#  'Chevrolet Malibu Hybrid Sedan 2010',
#  'Chevrolet Malibu Sedan 2007',
#  'Chevrolet Monte Carlo Coupe 2007',
#  'Chevrolet Silverado 1500 Classic Extended Cab 2007',
#  'Chevrolet Silverado 1500 Extended Cab 2012',
#  'Chevrolet Silverado 1500 Hybrid Crew Cab 2012',
#  'Chevrolet Silverado 1500 Regular Cab 2012',
#  'Chevrolet Silverado 2500HD Regular Cab 2012',
#  'Chevrolet Sonic Sedan 2012',
#  'Chevrolet Tahoe Hybrid SUV 2012',
#  'Chevrolet TrailBlazer SS 2009',
#  'Chevrolet Traverse SUV 2012',
#  'Chrysler 300 SRT-8 2010',
#  'Chrysler Aspen SUV 2009',
#  'Chrysler Crossfire Convertible 2008',
#  'Chrysler PT Cruiser Convertible 2008',
#  'Chrysler Sebring Convertible 2010',
#  'Chrysler Town and Country Minivan 2012',
#  'Daewoo Nubira Wagon 2002',
#  'Dodge Caliber Wagon 2007',
#  'Dodge Caliber Wagon 2012',
#  'Dodge Caravan Minivan 1997',
#  'Dodge Challenger SRT8 2011',
#  'Dodge Charger SRT-8 2009',
#  'Dodge Charger Sedan 2012',
#  'Dodge Dakota Club Cab 2007',
#  'Dodge Dakota Crew Cab 2010',
#  'Dodge Durango SUV 2007',
#  'Dodge Durango SUV 2012',
#  'Dodge Journey SUV 2012',
#  'Dodge Magnum Wagon 2008',
#  'Dodge Ram Pickup 3500 Crew Cab 2010',
#  'Dodge Ram Pickup 3500 Quad Cab 2009',
#  'Dodge Sprinter Cargo Van 2009',
#  'Eagle Talon Hatchback 1998',
#  'FIAT 500 Abarth 2012',
#  'FIAT 500 Convertible 2012',
#  'Ferrari 458 Italia Convertible 2012',
#  'Ferrari 458 Italia Coupe 2012',
#  'Ferrari California Convertible 2012',
#  'Ferrari FF Coupe 2012',
#  'Fisker Karma Sedan 2012',
#  'Ford E-Series Wagon Van 2012',
#  'Ford Edge SUV 2012',
#  'Ford Expedition EL SUV 2009',
#  'Ford F-150 Regular Cab 2007',
#  'Ford F-150 Regular Cab 2012',
#  'Ford F-450 Super Duty Crew Cab 2012',
#  'Ford Fiesta Sedan 2012',
#  'Ford Focus Sedan 2007',
#  'Ford Freestar Minivan 2007',
#  'Ford GT Coupe 2006',
#  'Ford Mustang Convertible 2007',
#  'Ford Ranger SuperCab 2011',
#  'GMC Acadia SUV 2012',
#  'GMC Canyon Extended Cab 2012',
#  'GMC Savana Van 2012',
#  'GMC Terrain SUV 2012',
#  'GMC Yukon Hybrid SUV 2012',
#  'Geo Metro Convertible 1993',
#  'HUMMER H2 SUT Crew Cab 2009',
#  'HUMMER H3T Crew Cab 2010',
#  'Honda Accord Coupe 2012',
#  'Honda Accord Sedan 2012',
#  'Honda Odyssey Minivan 2007',
#  'Honda Odyssey Minivan 2012',
#  'Hyundai Accent Sedan 2012',
#  'Hyundai Azera Sedan 2012',
#  'Hyundai Elantra Sedan 2007',
#  'Hyundai Elantra Touring Hatchback 2012',
#  'Hyundai Genesis Sedan 2012',
#  'Hyundai Santa Fe SUV 2012',
#  'Hyundai Sonata Hybrid Sedan 2012',
#  'Hyundai Sonata Sedan 2012',
#  'Hyundai Tucson SUV 2012',
#  'Hyundai Veloster Hatchback 2012',
#  'Hyundai Veracruz SUV 2012',
#  'Infiniti G Coupe IPL 2012',
#  'Infiniti QX56 SUV 2011',
#  'Isuzu Ascender SUV 2008',
#  'Jaguar XK XKR 2012',
#  'Jeep Compass SUV 2012',
#  'Jeep Grand Cherokee SUV 2012',
#  'Jeep Liberty SUV 2012',
#  'Jeep Patriot SUV 2012',
#  'Jeep Wrangler SUV 2012',
#  'Lamborghini Aventador Coupe 2012',
#  'Lamborghini Diablo Coupe 2001',
#  'Lamborghini Gallardo LP 570-4 Superleggera 2012',
#  'Lamborghini Reventon Coupe 2008',
#  'Land Rover LR2 SUV 2012',
#  'Land Rover Range Rover SUV 2012',
#  'Lincoln Town Car Sedan 2011',
#  'MINI Cooper Roadster Convertible 2012',
#  'Maybach Landaulet Convertible 2012',
#  'Mazda Tribute SUV 2011',
#  'McLaren MP4-12C Coupe 2012',
#  'Mercedes-Benz 300-Class Convertible 1993',
#  'Mercedes-Benz C-Class Sedan 2012',
#  'Mercedes-Benz E-Class Sedan 2012',
#  'Mercedes-Benz S-Class Sedan 2012',
#  'Mercedes-Benz SL-Class Coupe 2009',
#  'Mercedes-Benz Sprinter Van 2012',
#  'Mitsubishi Lancer Sedan 2012',
#  'Nissan 240SX Coupe 1998',
#  'Nissan Juke Hatchback 2012',
#  'Nissan Leaf Hatchback 2012',
#  'Nissan NV Passenger Van 2012',
#  'Plymouth Neon Coupe 1999',
#  'Porsche Panamera Sedan 2012',
#  'Ram C/V Cargo Van Minivan 2012',
#  'Rolls-Royce Ghost Sedan 2012',
#  'Rolls-Royce Phantom Drophead Coupe Convertible 2012',
#  'Rolls-Royce Phantom Sedan 2012',
#  'Scion xD Hatchback 2012',
#  'Spyker C8 Convertible 2009',
#  'Spyker C8 Coupe 2009',
#  'Suzuki Aerio Sedan 2007',
#  'Suzuki Kizashi Sedan 2012',
#  'Suzuki SX4 Hatchback 2012',
#  'Suzuki SX4 Sedan 2012',
#  'Tesla Model S Sedan 2012',
#  'Toyota 4Runner SUV 2012',
#  'Toyota Camry Sedan 2012',
#  'Toyota Corolla Sedan 2012',
#  'Toyota Sequoia SUV 2012',
#  'Volkswagen Beetle Hatchback 2012',
#  'Volkswagen Golf Hatchback 1991',
#  'Volkswagen Golf Hatchback 2012',
#  'Volvo 240 Sedan 1993',
#  'Volvo C30 Hatchback 2012',
#  'Volvo XC90 SUV 2007',
#  'smart fortwo Convertible 2012']

# %%
# dogs_labels = list(dogs_labels)
# dogs_labels.sort()
# dogs_labels

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import numpy as np

def output(location, new_model):
    img = load_and_preprocess_image(location)
    img = np.expand_dims(img, axis=0)
    answer = new_model.predict(img)
    y_class = answer.argmax(axis = -1)
    
    top_3 = np.argsort(answer[0])[:-4:-1]
    # for i in range(3):
    #     print(" ({:.3})".format(answer[0][top_3[i]]))
    
    y = " ".join(str(x) for x in y_class)
    y = int(y)
    res = classes[y]
    # print(res)
#     print(" ({:.3})".format(answer[0][top_3[0]]))
    pred_prob = answer[0][top_3[0]]
    return float(pred_prob), res

# %%
location = "/content/drive/My Drive/Colab Notebooks/Cars/cars_classes_top_cropped/Audi TT Hatchback 2011/00767.jpg"
output(location, model)

# %%
# %cd /content
# !wget http://ai.stanford.edu/~jkrause/car196/cars_train.tgz
# !wget http://ai.stanford.edu/~jkrause/car196/cars_test.tgz
# !wget https://ai.stanford.edu/~jkrause/cars/car_devkit.tgz
# !tar zxf car_devkit.tgz
# !tar zxf cars_train.tgz
# !tar zxf cars_test.tgz
# !wget http://imagenet.stanford.edu/internal/car196/cars_test_annos_withlabels.mat -O devkit/cars_test_annos_withlabels.mat
# Out:
# /content
# --2021-12-31 10:11:31--  http://ai.stanford.edu/~jkrause/car196/cars_train.tgz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 979269282 (934M) [application/x-gzip]
# Saving to: ‘cars_train.tgz’
#
# cars_train.tgz      100%[===================>] 933.90M  20.1MB/s    in 38s
#
# 2021-12-31 10:12:08 (24.9 MB/s) - ‘cars_train.tgz’ saved [979269282/979269282]
#
# --2021-12-31 10:12:08--  http://ai.stanford.edu/~jkrause/car196/cars_test.tgz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 977350468 (932M) [application/x-gzip]
# Saving to: ‘cars_test.tgz’
#
# cars_test.tgz       100%[===================>] 932.07M  18.7MB/s    in 68s
#
# 2021-12-31 10:13:17 (13.7 MB/s) - ‘cars_test.tgz’ saved [977350468/977350468]
#
# --2021-12-31 10:13:17--  https://ai.stanford.edu/~jkrause/cars/car_devkit.tgz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 330960 (323K) [application/x-gzip]
# Saving to: ‘car_devkit.tgz.1’
#
# car_devkit.tgz.1    100%[===================>] 323.20K   711KB/s    in 0.5s
#
# 2021-12-31 10:13:17 (711 KB/s) - ‘car_devkit.tgz.1’ saved [330960/330960]
#
# --2021-12-31 10:13:42--  http://imagenet.stanford.edu/internal/car196/cars_test_annos_withlabels.mat
# Resolving imagenet.stanford.edu (imagenet.stanford.edu)... 171.64.68.16
# Connecting to imagenet.stanford.edu (imagenet.stanford.edu)|171.64.68.16|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://image-net.org/internal/car196/cars_test_annos_withlabels.mat [following]
# --2021-12-31 10:13:42--  https://image-net.org/internal/car196/cars_test_annos_withlabels.mat
# Resolving image-net.org (image-net.org)... 171.64.68.16
# Connecting to image-net.org (image-net.org)|171.64.68.16|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-12-31 10:13:43 ERROR 404: Not Found.

# %% [markdown]
# # Identifying top prototypes cars

# %%
# import cv2
# import os
# from shutil import copyfile
# from pathlib import Path

# #folder="/content/drive/My Drive/Colab/1KDataSet_Part1"
# folder = "/content/cars_train/"
# folder_Copy = "/content/drive/My Drive/Colab Notebooks/Cars/Cars_classes_top/"

# last_fileName=""

# #images = []
# imagesFileNames = []
# # for filename in os.listdir(folder):
#     # if filename not in os.listdir(folder_Copy):
# for img in os.listdir(folder):
#   pred = output(folder+"/"+img, model)
#   if pred[0] >= 0.9 :
#       print(folder+"/"+img, model)
#       print('path', folder+"/"+img)
#       print('prob=', output(folder+"/"+img, model)[0])
#       src = folder+"/"+img
#       dst = folder_Copy+ pred[1]+"/"+img
#       # Path(folder_Copy+filename+"/").mkdir(parents=True, exist_ok=True)
#       # copyfile(src, dst)
#       print(pred[1])
# #             print(img)
#   if len(folder_Copy)==196:
#     break;
#   #     img = cv2.imread(os.path.join(folder,filename))
#   #     if img is not None:
#   #         #images.append(img)
#     imagesFileNames.append(pref[1])
# imagesFileNames.sort()        
# # print(imagesFileNames[0])
# #images = load_images_from_folder(folder)

# %%
import cv2
import os
from shutil import copyfile
from pathlib import Path


folder = "/content/drive/My Drive/Colab Notebooks/Cars/cars_classes_top_cropped/"

last_fileName=""
#images = []
imagesFileNames = []
for filename in os.listdir(folder):
    # for img in os.listdir(folder+filename):
    imagesFileNames.append(filename)
    print(filename)
imagesFileNames.sort()
print(len(imagesFileNames))

# %%
arryWeights_last_After =[]
for i in range(512):
  arryWeights_last_After.append(i)
for i in range(512):
  arryWeights_last_After[i]=1

def custom_layer_last(tensor):
    return tensor * arryWeights_last_After[i]
# vgg_weights = VGG16(    input_shape = IMAGE_SIZE + [3], weights = 'imagenet',
#     include_top = False).get_weights()

# %%
def insert_intermediate_layer_in_keras(model, layer_id, new_layer):
    from keras.models import Model

    layers = [l for l in model.layers]

    x = layers[0].output
    for i in range(1, len(layers)):
        if i == layer_id:
            x = new_layer(x)
        x = layers[i](x)

    model = Model(inputs=layers[0].input, outputs=x) ### inputs instead of input in this version
    return model

# %% [markdown]
# # This part for computing the CI and storing it into Dictionnary in tx file

# %%
from keras.layers import Lambda
from keras import backend as K
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D, MaxPool2D 

# from kerassurgeon import Surgeon
# from kerassurgeon import identify
# from kerassurgeon import utils
# from kerassurgeon.operations import delete_channels
# dctOfAllDictionClasses = {}

weights_dic = {}
NO_CLASS = 196
imgCount = 0
indexImg=0
# img_path = 'Mountain_Bike/[image-net.org][27]443691662_09f12b8e37.jpg'
for imgFileName in imagesFileNames:
    dctOfAllDictionClasses = {}
    imgPath = folder + imagesFileNames[indexImg] + "/" + os.listdir(folder + imagesFileNames[indexImg])[0]
    print(imgPath)
    res = output(imgPath, model)
    # print('res[0]', res[0])
    # print('res[1]', res[1])
    originalName = imgFileName
    # originalName = res[1]
    # if '.jpg' in originalName:
    #     originalName = originalName.replace('.jpg','')
    print('orign name:', originalName)
    class_Id = res[1]
    orig_acc = res[0]
    print('origin acc', orig_acc)
    from keras.layers import Lambda
    weights_dic = {}
    K.set_learning_phase(0)
    
    import time
    start_time = time.time()
    for i in range(512):
        print ('filt{}'.format (i))
        # arryWeights_last_After[i]=0
        # def custom_layer_last(tensor):
        #   return tensor * arryWeights_last_After[i]
        filt = i

        new_model = VGG16_outerproduct(filter_zero=i
                    , value_filter=0, classes=classes,dropoutrate=dropout_rate,model_name=model_name)

        # now all layers are trainable
        for layer in new_model.layers:
            layer.trainable = True

        # change LR
        opt_sgd = tensorflow.keras.optimizers.SGD(
                        lr=1e-3
                        , decay=1e-9
                        , momentum=0.9
                        , nesterov=False
                    )
        new_model.compile(
            loss="categorical_crossentropy"
            , optimizer=opt_sgd
            , metrics=["categorical_accuracy"]
        )

        new_model.load_weights('/content/drive/My Drive/Colab Notebooks/Cars/final_all_transfer_learning_VGG16.h5')

        new_res = output(imgPath, new_model)
        # print('res[0]', new_res[0])
        # print('res[1]', new_res[1])
    
        New_accu = new_res[0]
        print(" ({:.3})".format(New_accu))
        print('label name:', new_res[1])
        print ('acc after purning (%.2f%%)', New_accu)
        print('difference: ', (orig_acc - New_accu))
        #weights_dic[filt][0] = 1/(k+1)  # resp
        tuple = orig_acc - New_accu, 1
        #weights_dic[filt] = original_loss[1] - loss[1]  # prob
        weights_dic[filt] = tuple
        # arryWeights_last_After[i]=1
        K.clear_session ()

    weights_dic_sort = sorted (weights_dic.items (), key=lambda kv: kv[1], reverse=True)
    #     print ('Resp and loss for conv layer {}\n'.format (1), weights_dic_sort)
    # arryOfDictFiltByLayer.append(weights_dic_sort)
    #K.backend.clear_session ()
    print("--- %s seconds ---" % (time.time() - start_time))
    pairKeyValue = { originalName: weights_dic_sort}
    dctOfAllDictionClasses = {}
    dctOfAllDictionClasses.update(pairKeyValue)
    print('pair ley:', pairKeyValue)
    import json
    #     with open('FIltersRespAll', 'w') as fout:
    #         json.dump(str(lstOfAllDictionClasses), fout)
    # with open('/content/drive/My Drive/Colab Notebooks/Cub-200_BCNN/Filt_Resp_Birds_BCNN.txt', 'a') as fout:
    with open('/content/drive/My Drive/Colab Notebooks/Cars/Filt_Resp_Cars_Crop.txt', 'a') as fout:

        fout.write("\n" + str(dctOfAllDictionClasses) + "\n") 
        print('Last Image ID:', imagesFileNames[imgCount])
    imgCount+=1
    indexImg+=1
# Out:
# /content/drive/My Drive/Colab Notebooks/Cars/cars_classes_top_cropped/Bentley Arnage Sedan 2009/01076.jpg
# orign name: Bentley Arnage Sedan 2009
# origin acc 0.9610258340835571
# filt0
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:414: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Streaming output truncated to the last 5000 lines.
# difference:  -0.0001246333122253418
# filt26
#  (0.902)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9024918675422668
# difference:  0.0007460117340087891
# filt27
#  (0.902)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.902341902256012
# difference:  0.0008959770202636719
# filt28
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt29
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9038646817207336
# difference:  -0.0006268024444580078
# filt30
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt31
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt32
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8987672328948975
# difference:  0.004470646381378174
# filt33
#  (0.9)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9001865386962891
# difference:  0.0030513405799865723
# filt34
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt35
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt36
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt37
#  (0.902)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9018778204917908
# difference:  0.0013600587844848633
# filt38
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt39
#  (0.9)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8999614119529724
# difference:  0.0032764673233032227
# filt40
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9027262330055237
# difference:  0.0005116462707519531
# filt41
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8992478847503662
# difference:  0.003989994525909424
# filt42
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt43
#  (0.905)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9053679704666138
# difference:  -0.0021300911903381348
# filt44
#  (0.898)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8977422118186951
# difference:  0.005495667457580566
# filt45
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt46
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9039215445518494
# difference:  -0.0006836652755737305
# filt47
#  (0.902)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.902337372303009
# difference:  0.0009005069732666016
# filt48
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9037029147148132
# difference:  -0.00046503543853759766
# filt49
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt50
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt51
#  (0.905)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9045369625091553
# difference:  -0.0012990832328796387
# filt52
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9033425450325012
# difference:  -0.00010466575622558594
# filt53
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt54
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8992820382118225
# difference:  0.003955841064453125
# filt55
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9008152484893799
# difference:  0.002422630786895752
# filt56
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.901368260383606
# difference:  0.0018696188926696777
# filt57
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.902532696723938
# difference:  0.0007051825523376465
# filt58
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8991233706474304
# difference:  0.004114508628845215
# filt59
#  (0.896)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8962231874465942
# difference:  0.0070146918296813965
# filt60
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8987813591957092
# difference:  0.004456520080566406
# filt61
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9007672071456909
# difference:  0.002470672130584717
# filt62
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt63
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt64
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9007359743118286
# difference:  0.0025019049644470215
# filt65
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt66
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt67
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032370448112488
# difference:  8.344650268554688e-07
# filt68
#  (0.905)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9045642018318176
# difference:  -0.0013263225555419922
# filt69
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt70
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9034862518310547
# difference:  -0.00024837255477905273
# filt71
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt72
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt73
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9027265310287476
# difference:  0.0005113482475280762
# filt74
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9035334587097168
# difference:  -0.0002955794334411621
# filt75
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt76
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt77
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9042409658432007
# difference:  -0.0010030865669250488
# filt78
#  (0.9)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8999020457267761
# difference:  0.0033358335494995117
# filt79
#  (0.898)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8984219431877136
# difference:  0.004815936088562012
# filt80
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8988892436027527
# difference:  0.004348635673522949
# filt81
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt82
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.903388261795044
# difference:  -0.00015038251876831055
# filt83
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt84
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt85
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9025753140449524
# difference:  0.0006625652313232422
# filt86
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.903248131275177
# difference:  -1.0251998901367188e-05
# filt87
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9036831855773926
# difference:  -0.00044530630111694336
# filt88
#  (0.898)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8983548879623413
# difference:  0.004882991313934326
# filt89
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt90
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt91
#  (0.9)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9001260995864868
# difference:  0.0031117796897888184
# filt92
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9014219045639038
# difference:  0.0018159747123718262
# filt93
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt94
#  (0.905)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.904967188835144
# difference:  -0.0017293095588684082
# filt95
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt96
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt97
#  (0.896)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8956893086433411
# difference:  0.00754857063293457
# filt98
#  (0.897)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8966708779335022
# difference:  0.0065670013427734375
# filt99
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9007998704910278
# difference:  0.0024380087852478027
# filt100
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8985289931297302
# difference:  0.00470888614654541
# filt101
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt102
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9030502438545227
# difference:  0.0001876354217529297
# filt103
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt104
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt105
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt106
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt107
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9036798477172852
# difference:  -0.0004419684410095215
# filt108
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt109
#  (0.897)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8967797756195068
# difference:  0.006458103656768799
# filt110
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt111
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt112
#  (0.902)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9017101526260376
# difference:  0.0015277266502380371
# filt113
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt114
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt115
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9008984565734863
# difference:  0.0023394227027893066
# filt116
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt117
#  (0.9)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8999847173690796
# difference:  0.003253161907196045
# filt118
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt119
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt120
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9034423828125
# difference:  -0.00020450353622436523
# filt121
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032570719718933
# difference:  -1.919269561767578e-05
# filt122
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt123
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt124
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt125
#  (0.898)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8977265954017639
# difference:  0.005511283874511719
# filt126
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9035041928291321
# difference:  -0.0002663135528564453
# filt127
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt128
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9035069942474365
# difference:  -0.00026911497116088867
# filt129
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt130
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt131
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9009702801704407
# difference:  0.002267599105834961
# filt132
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9030912518501282
# difference:  0.00014662742614746094
# filt133
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt134
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt135
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt136
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt137
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9008919596672058
# difference:  0.0023459196090698242
# filt138
#  (0.902)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9023627042770386
# difference:  0.0008751749992370605
# filt139
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt140
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9034025073051453
# difference:  -0.0001646280288696289
# filt141
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8992955088615417
# difference:  0.003942370414733887
# filt142
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9025893807411194
# difference:  0.00064849853515625
# filt143
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt144
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9042213559150696
# difference:  -0.0009834766387939453
# filt145
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt146
#  (0.898)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8980337977409363
# difference:  0.0052040815353393555
# filt147
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9025782346725464
# difference:  0.000659644603729248
# filt148
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032367467880249
# difference:  1.1324882507324219e-06
# filt149
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt150
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8985950946807861
# difference:  0.004642784595489502
# filt151
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt152
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.898726761341095
# difference:  0.004511117935180664
# filt153
#  (0.898)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8977398872375488
# difference:  0.005497992038726807
# filt154
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8989470601081848
# difference:  0.00429081916809082
# filt155
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt156
#  (0.898)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8981114625930786
# difference:  0.0051264166831970215
# filt157
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt158
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt159
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9030405282974243
# difference:  0.00019735097885131836
# filt160
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8992378115653992
# difference:  0.004000067710876465
# filt161
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt162
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9035635590553284
# difference:  -0.0003256797790527344
# filt163
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt164
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt165
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt166
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt167
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt168
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt169
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt170
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt171
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt172
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt173
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt174
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt175
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt176
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9031966924667358
# difference:  4.118680953979492e-05
# filt177
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9007604122161865
# difference:  0.0024774670600891113
# filt178
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt179
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt180
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9034889936447144
# difference:  -0.0002511143684387207
# filt181
#  (0.9)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.899683952331543
# difference:  0.003553926944732666
# filt182
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt183
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9026078581809998
# difference:  0.0006300210952758789
# filt184
#  (0.9)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9003251791000366
# difference:  0.0029127001762390137
# filt185
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt186
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt187
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt188
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9031465649604797
# difference:  9.131431579589844e-05
# filt189
#  (0.893)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8926545977592468
# difference:  0.010583281517028809
# filt190
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt191
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt192
#  (0.89)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8901063799858093
# difference:  0.013131499290466309
# filt193
#  (0.896)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8962658047676086
# difference:  0.006972074508666992
# filt194
#  (0.896)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8964740633964539
# difference:  0.006763815879821777
# filt195
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9033282399177551
# difference:  -9.036064147949219e-05
# filt196
#  (0.902)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9024701714515686
# difference:  0.0007677078247070312
# filt197
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9040960073471069
# difference:  -0.0008581280708312988
# filt198
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.903148353099823
# difference:  8.952617645263672e-05
# filt199
#  (0.896)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8956748843193054
# difference:  0.007562994956970215
# filt200
#  (0.897)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8969813585281372
# difference:  0.006256520748138428
# filt201
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.904039740562439
# difference:  -0.0008018612861633301
# filt202
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt203
#  (0.9)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8998716473579407
# difference:  0.003366231918334961
# filt204
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9033832550048828
# difference:  -0.00014537572860717773
# filt205
#  (0.902)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9019616842269897
# difference:  0.0012761950492858887
# filt206
#  (0.902)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9021569490432739
# difference:  0.001080930233001709
# filt207
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt208
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt209
#  (0.9)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9003814458847046
# difference:  0.002856433391571045
# filt210
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9031368494033813
# difference:  0.00010102987289428711
# filt211
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt212
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt213
#  (0.897)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8973467946052551
# difference:  0.005891084671020508
# filt214
#  (0.897)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8970975875854492
# difference:  0.006140291690826416
# filt215
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt216
#  (0.905)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.904777467250824
# difference:  -0.0015395879745483398
# filt217
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9033350944519043
# difference:  -9.721517562866211e-05
# filt218
#  (0.896)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.896157443523407
# difference:  0.007080435752868652
# filt219
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8993839621543884
# difference:  0.003853917121887207
# filt220
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9031665325164795
# difference:  7.134675979614258e-05
# filt221
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9027336239814758
# difference:  0.0005042552947998047
# filt222
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9010246396064758
# difference:  0.0022132396697998047
# filt223
#  (0.895)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8949403762817383
# difference:  0.008297502994537354
# filt224
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt225
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt226
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt227
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9010694622993469
# difference:  0.002168416976928711
# filt228
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9027283787727356
# difference:  0.0005095005035400391
# filt229
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt230
#  (0.905)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.904675304889679
# difference:  -0.0014374256134033203
# filt231
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt232
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt233
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt234
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt235
#  (0.896)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8955182433128357
# difference:  0.007719635963439941
# filt236
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt237
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt238
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9029279351234436
# difference:  0.00030994415283203125
# filt239
#  (0.902)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9019916653633118
# difference:  0.0012462139129638672
# filt240
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9012367725372314
# difference:  0.0020011067390441895
# filt241
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt242
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt243
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt244
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt245
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.901360809803009
# difference:  0.0018770694732666016
# filt246
#  (0.898)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8979323506355286
# difference:  0.00530552864074707
# filt247
#  (0.897)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8974303603172302
# difference:  0.00580751895904541
# filt248
#  (0.9)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9000940322875977
# difference:  0.0031438469886779785
# filt249
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9029257297515869
# difference:  0.0003121495246887207
# filt250
#  (0.898)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8979605436325073
# difference:  0.0052773356437683105
# filt251
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt252
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8988174200057983
# difference:  0.004420459270477295
# filt253
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9027696847915649
# difference:  0.00046819448471069336
# filt254
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt255
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt256
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt257
#  (0.887)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8866024613380432
# difference:  0.016635417938232422
# filt258
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9006381034851074
# difference:  0.002599775791168213
# filt259
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt260
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt261
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9005013704299927
# difference:  0.002736508846282959
# filt262
#  (0.9)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8995170593261719
# difference:  0.0037208199501037598
# filt263
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9026055335998535
# difference:  0.0006323456764221191
# filt264
#  (0.902)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9017175436019897
# difference:  0.0015203356742858887
# filt265
#  (0.9)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.89991694688797
# difference:  0.003320932388305664
# filt266
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8993557691574097
# difference:  0.003882110118865967
# filt267
#  (0.898)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8984211683273315
# difference:  0.004816710948944092
# filt268
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt269
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt270
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt271
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt272
#  (0.9)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9000589847564697
# difference:  0.003178894519805908
# filt273
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9030684232711792
# difference:  0.00016945600509643555
# filt274
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt275
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9025377035140991
# difference:  0.0007001757621765137
# filt276
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt277
#  (0.902)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9021782875061035
# difference:  0.0010595917701721191
# filt278
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt279
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt280
#  (0.9)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9001572132110596
# difference:  0.0030806660652160645
# filt281
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9044256806373596
# difference:  -0.0011878013610839844
# filt282
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt283
#  (0.897)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8968666195869446
# difference:  0.006371259689331055
# filt284
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt285
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8987494111061096
# difference:  0.004488468170166016
# filt286
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt287
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt288
#  (0.905)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9053859114646912
# difference:  -0.0021480321884155273
# filt289
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9013188481330872
# difference:  0.0019190311431884766
# filt290
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032192230224609
# difference:  1.8656253814697266e-05
# filt291
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt292
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt293
#  (0.902)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9023022055625916
# difference:  0.000935673713684082
# filt294
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9033417701721191
# difference:  -0.00010389089584350586
# filt295
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt296
#  (0.9)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9002951383590698
# difference:  0.0029427409172058105
# filt297
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt298
#  (0.898)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8976911902427673
# difference:  0.005546689033508301
# filt299
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt300
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9030137658119202
# difference:  0.00022411346435546875
# filt301
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9035952687263489
# difference:  -0.0003573894500732422
# filt302
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9033690094947815
# difference:  -0.00013113021850585938
# filt303
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9028218388557434
# difference:  0.00041604042053222656
# filt304
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9041480422019958
# difference:  -0.0009101629257202148
# filt305
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8989461064338684
# difference:  0.0042917728424072266
# filt306
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt307
#  (0.892)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.892119824886322
# difference:  0.011118054389953613
# filt308
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt309
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt310
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt311
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9044266939163208
# difference:  -0.001188814640045166
# filt312
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt313
#  (0.897)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8972935676574707
# difference:  0.005944311618804932
# filt314
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8989291191101074
# difference:  0.004308760166168213
# filt315
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt316
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt317
#  (0.892)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8921321630477905
# difference:  0.011105716228485107
# filt318
#  (0.902)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.901703417301178
# difference:  0.0015344619750976562
# filt319
#  (0.898)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8981500267982483
# difference:  0.005087852478027344
# filt320
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt321
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9040746092796326
# difference:  -0.0008367300033569336
# filt322
#  (0.9)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8998439311981201
# difference:  0.0033939480781555176
# filt323
#  (0.902)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9023188352584839
# difference:  0.000919044017791748
# filt324
#  (0.905)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9047622084617615
# difference:  -0.0015243291854858398
# filt325
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt326
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9008185863494873
# difference:  0.00241929292678833
# filt327
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt328
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt329
#  (0.898)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8978217244148254
# difference:  0.005416154861450195
# filt330
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt331
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8991032242774963
# difference:  0.004134654998779297
# filt332
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9034861922264099
# difference:  -0.00024831295013427734
# filt333
#  (0.902)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9021192193031311
# difference:  0.0011186599731445312
# filt334
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt335
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.902831494808197
# difference:  0.0004063844680786133
# filt336
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9028569459915161
# difference:  0.0003809332847595215
# filt337
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt338
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt339
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt340
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032515287399292
# difference:  -1.3649463653564453e-05
# filt341
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.900741457939148
# difference:  0.0024964213371276855
# filt342
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt343
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt344
#  (0.902)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9019401669502258
# difference:  0.0012977123260498047
# filt345
#  (0.9)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.89964359998703
# difference:  0.0035942792892456055
# filt346
#  (0.898)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8981260657310486
# difference:  0.005111813545227051
# filt347
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9039840698242188
# difference:  -0.0007461905479431152
# filt348
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt349
#  (0.905)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9045014381408691
# difference:  -0.0012635588645935059
# filt350
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt351
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8994354605674744
# difference:  0.0038024187088012695
# filt352
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt353
#  (0.895)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8953188061714172
# difference:  0.007919073104858398
# filt354
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8990280628204346
# difference:  0.0042098164558410645
# filt355
#  (0.902)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9015582203865051
# difference:  0.0016796588897705078
# filt356
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9035448431968689
# difference:  -0.0003069639205932617
# filt357
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt358
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9036197066307068
# difference:  -0.00038182735443115234
# filt359
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt360
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt361
#  (0.905)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9046047329902649
# difference:  -0.0013668537139892578
# filt362
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.901434600353241
# difference:  0.001803278923034668
# filt363
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt364
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt365
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt366
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9008823037147522
# difference:  0.0023555755615234375
# filt367
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt368
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9029273986816406
# difference:  0.00031048059463500977
# filt369
#  (0.902)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9016262292861938
# difference:  0.0016116499900817871
# filt370
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt371
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt372
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt373
#  (0.9)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8997529149055481
# difference:  0.003484964370727539
# filt374
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt375
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt376
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9028805494308472
# difference:  0.0003573298454284668
# filt377
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt378
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9038969874382019
# difference:  -0.0006591081619262695
# filt379
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt380
#  (0.899)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.8990433812141418
# difference:  0.004194498062133789
# filt381
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt382
#  (0.901)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.901430606842041
# difference:  0.0018072724342346191
# filt383
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt384
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt385
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9031506776809692
# difference:  8.720159530639648e-05
# filt386
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt387
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9033092856407166
# difference:  -7.140636444091797e-05
# filt388
#  (0.904)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9037051796913147
# difference:  -0.0004673004150390625
# filt389
#  (0.903)
# label name: Bentley Mulsanne Sedan 2011
# acc after purning (%.2f%%) 0.9032378792762756
# difference:  0.0
# filt390
#  (0.903)
# ...
# difference:  0.007421553134918213
# filt424
#  (0.907)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9065610766410828
# difference:  0.012234389781951904
# filt425
#  (0.914)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9141433238983154
# difference:  0.004652142524719238
# filt426
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt427
#  (0.918)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9182173609733582
# difference:  0.0005781054496765137
# filt428
#  (0.913)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.913148045539856
# difference:  0.005647420883178711
# filt429
#  (0.916)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.915614664554596
# difference:  0.0031808018684387207
# filt430
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9190370440483093
# difference:  -0.0002415776252746582
# filt431
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187092185020447
# difference:  8.624792098999023e-05
# filt432
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt433
#  (0.915)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9154183268547058
# difference:  0.0033771395683288574
# filt434
#  (0.909)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9091952443122864
# difference:  0.009600222110748291
# filt435
#  (0.915)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9153649806976318
# difference:  0.003430485725402832
# filt436
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt437
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt438
#  (0.915)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9151864051818848
# difference:  0.0036090612411499023
# filt439
#  (0.909)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9091136455535889
# difference:  0.0096818208694458
# filt440
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9185755252838135
# difference:  0.0002199411392211914
# filt441
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt442
#  (0.921)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.920748770236969
# difference:  -0.001953303813934326
# filt443
#  (0.918)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.917752742767334
# difference:  0.0010427236557006836
# filt444
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt445
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9186985492706299
# difference:  9.691715240478516e-05
# filt446
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9188410639762878
# difference:  -4.559755325317383e-05
# filt447
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9189600348472595
# difference:  -0.00016456842422485352
# filt448
#  (0.918)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9177187085151672
# difference:  0.0010767579078674316
# filt449
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9191257357597351
# difference:  -0.00033026933670043945
# filt450
#  (0.906)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9063085317611694
# difference:  0.012486934661865234
# filt451
#  (0.918)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.918438732624054
# difference:  0.0003567337989807129
# filt452
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9185674786567688
# difference:  0.00022798776626586914
# filt453
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt454
#  (0.914)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9138020873069763
# difference:  0.00499337911605835
# filt455
#  (0.918)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9179142117500305
# difference:  0.0008812546730041504
# filt456
#  (0.918)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9177443981170654
# difference:  0.0010510683059692383
# filt457
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9185377955436707
# difference:  0.00025767087936401367
# filt458
#  (0.916)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9160234928131104
# difference:  0.0027719736099243164
# filt459
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9189695119857788
# difference:  -0.00017404556274414062
# filt460
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9193137288093567
# difference:  -0.0005182623863220215
# filt461
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt462
#  (0.918)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9184209704399109
# difference:  0.0003744959831237793
# filt463
#  (0.917)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9171983599662781
# difference:  0.0015971064567565918
# filt464
#  (0.915)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9147046208381653
# difference:  0.004090845584869385
# filt465
#  (0.92)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.919725239276886
# difference:  -0.0009297728538513184
# filt466
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9191203117370605
# difference:  -0.0003248453140258789
# filt467
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9189034700393677
# difference:  -0.00010800361633300781
# filt468
#  (0.909)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9086783528327942
# difference:  0.010117113590240479
# filt469
#  (0.918)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9180320501327515
# difference:  0.0007634162902832031
# filt470
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9189417958259583
# difference:  -0.00014632940292358398
# filt471
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.91946941614151
# difference:  -0.0006739497184753418
# filt472
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9186041951179504
# difference:  0.00019127130508422852
# filt473
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9193257093429565
# difference:  -0.000530242919921875
# filt474
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt475
#  (0.918)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9177355766296387
# difference:  0.001059889793395996
# filt476
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187613129615784
# difference:  3.415346145629883e-05
# filt477
#  (0.915)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9150682091712952
# difference:  0.003727257251739502
# filt478
#  (0.918)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9175317287445068
# difference:  0.001263737678527832
# filt479
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.918978214263916
# difference:  -0.00018274784088134766
# filt480
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187251329421997
# difference:  7.033348083496094e-05
# filt481
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt482
#  (0.918)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9177160859107971
# difference:  0.0010793805122375488
# filt483
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt484
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9193118214607239
# difference:  -0.000516355037689209
# filt485
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt486
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt487
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9193896651268005
# difference:  -0.0005941987037658691
# filt488
#  (0.915)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9148610234260559
# difference:  0.00393444299697876
# filt489
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187963604927063
# difference:  -8.940696716308594e-07
# filt490
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt491
#  (0.918)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9182851910591125
# difference:  0.0005102753639221191
# filt492
#  (0.916)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9163520932197571
# difference:  0.002443373203277588
# filt493
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt494
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9190853834152222
# difference:  -0.0002899169921875
# filt495
#  (0.913)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9128854274749756
# difference:  0.005910038948059082
# filt496
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt497
#  (0.911)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9112067222595215
# difference:  0.007588744163513184
# filt498
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt499
#  (0.918)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9183971881866455
# difference:  0.00039827823638916016
# filt500
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt501
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9189592003822327
# difference:  -0.00016373395919799805
# filt502
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt503
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt504
#  (0.918)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9181972742080688
# difference:  0.0005981922149658203
# filt505
#  (0.918)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9184917211532593
# difference:  0.0003037452697753906
# filt506
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt507
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt508
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt509
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt510
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9187954664230347
# difference:  0.0
# filt511
#  (0.919)
# label name: smart fortwo Convertible 2012
# acc after purning (%.2f%%) 0.9188612699508667
# difference:  -6.580352783203125e-05
# --- 1142.2080850601196 seconds ---
# pair ley: {'smart fortwo Convertible 2012': [(450, (0.012486934661865234, 1)), (424, (0.012234389781951904, 1)), (97, (0.01198655366897583, 1)), (468, (0.010117113590240479, 1)), (121, (0.010058104991912842, 1)), (134, (0.009948253631591797, 1)), (439, (0.0096818208694458, 1)), (336, (0.00963050127029419, 1)), (415, (0.009615600109100342, 1)), (434, (0.009600222110748291, 1)), (245, (0.008795320987701416, 1)), (409, (0.008353710174560547, 1)), (359, (0.008009254932403564, 1)), (408, (0.007981181144714355, 1)), (316, (0.007656574249267578, 1)), (497, (0.007588744163513184, 1)), (21, (0.00756382942199707, 1)), (423, (0.007421553134918213, 1)), (197, (0.007383525371551514, 1)), (249, (0.007368266582489014, 1)), (182, (0.0067482590675354, 1)), (395, (0.006728112697601318, 1)), (186, (0.006684780120849609, 1)), (308, (0.006659328937530518, 1)), (322, (0.0062844157218933105, 1)), (217, (0.006266593933105469, 1)), (368, (0.005939185619354248, 1)), (246, (0.005925238132476807, 1)), (495, (0.005910038948059082, 1)), (366, (0.005807816982269287, 1)), (363, (0.005798220634460449, 1)), (376, (0.0057564377784729, 1)), (317, (0.005720853805541992, 1)), (428, (0.005647420883178711, 1)), (379, (0.0056015849113464355, 1)), (72, (0.005456328392028809, 1)), (7, (0.005408585071563721, 1)), (285, (0.005250453948974609, 1)), (11, (0.0052490234375, 1)), (110, (0.005188882350921631, 1)), (69, (0.005158424377441406, 1)), (108, (0.005023837089538574, 1)), (454, (0.00499337911605835, 1)), (306, (0.0049607157707214355, 1)), (216, (0.00484853982925415, 1)), (425, (0.004652142524719238, 1)), (126, (0.0045716166496276855, 1)), (23, (0.004515409469604492, 1)), (302, (0.0044800639152526855, 1)), (226, (0.004463315010070801, 1)), (60, (0.004385888576507568, 1)), (106, (0.004301130771636963, 1)), (422, (0.004247903823852539, 1)), (464, (0.004090845584869385, 1)), (488, (0.00393444299697876, 1)), (342, (0.003792107105255127, 1)), (387, (0.0037665367126464844, 1)), (477, (0.003727257251739502, 1)), (12, (0.0037247538566589355, 1)), (40, (0.0037013888359069824, 1)), (438, (0.0036090612411499023, 1)), (402, (0.003502964973449707, 1)), (435, (0.003430485725402832, 1)), (433, (0.0033771395683288574, 1)), (367, (0.0032508373260498047, 1)), (9, (0.0031813979148864746, 1)), (429, (0.0031808018684387207, 1)), (195, (0.0030101537704467773, 1)), (47, (0.002961397171020508, 1)), (407, (0.0029036998748779297, 1)), (94, (0.0028511881828308105, 1)), (458, (0.0027719736099243164, 1)), (71, (0.0027375221252441406, 1)), (222, (0.002638578414916992, 1)), (212, (0.0026130080223083496, 1)), (48, (0.002465665340423584, 1)), (83, (0.0024626851081848145, 1)), (492, (0.002443373203277588, 1)), (102, (0.0024274587631225586, 1)), (133, (0.002306818962097168, 1)), (356, (0.002227604389190674, 1)), (403, (0.002205371856689453, 1)), (235, (0.002199828624725342, 1)), (227, (0.0021932125091552734, 1)), (127, (0.0021602511405944824, 1)), (91, (0.00212252140045166, 1)), (162, (0.002110123634338379, 1)), (264, (0.0020303726196289062, 1)), (299, (0.001990973949432373, 1)), (188, (0.0019730329513549805, 1)), (122, (0.001959681510925293, 1)), (128, (0.0019455552101135254, 1)), (337, (0.0018880367279052734, 1)), (29, (0.0018110871315002441, 1)), (397, (0.0018022656440734863, 1)), (201, (0.0017531514167785645, 1)), (87, (0.0016765594482421875, 1)), (241, (0.001659095287322998, 1)), (144, (0.001635134220123291, 1)), (22, (0.0016311407089233398, 1)), (378, (0.0016144514083862305, 1)), (463, (0.0015971064567565918, 1)), (104, (0.0015262365341186523, 1)), (270, (0.0015256404876708984, 1)), (0, (0.0015230774879455566, 1)), (35, (0.0014857053756713867, 1)), (255, (0.0014219880104064941, 1)), (276, (0.0014202594757080078, 1)), (348, (0.0013574957847595215, 1)), (177, (0.0013475418090820312, 1)), (327, (0.0013153553009033203, 1)), (5, (0.0013134479522705078, 1)), (478, (0.001263737678527832, 1)), (230, (0.0011529326438903809, 1)), (67, (0.00113677978515625, 1)), (163, (0.0011281371116638184, 1)), (31, (0.0010 ...
# Last Image ID: smart fortwo Convertible 2012
